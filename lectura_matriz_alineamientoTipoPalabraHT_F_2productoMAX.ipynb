# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Lectura de matriz de alineamiento

# %%
df = pd.read_pickle("data/prueba100.pickle")
df
# Out:
#     Main index                                               Text  \
# 0            0  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, we...
# 1            1  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, dr...
# 2            2  [NULL{null,PROPN}, a{a,DET}, young{young,ADJ},...
# 3            3  [NULL{null,NOUN}, an{an,DET}, asian{asian,ADJ}...
# 4            4  [NULL{null,PROPN}, a{a,DET}, child{child,NOUN}...
# ..         ...                                                ...
# 95          95  [NULL{null,PROPN}, a{a,DET}, group{group,NOUN}...
# 96          96  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 97          97  [NULL{null,PROPN}, a{a,DET}, skateboarding{ska...
# 98          98  [NULL{null,ADJ}, four{four,NUM}, children{chil...
# 99          99  [NULL{null,ADJ}, three{three,NUM}, men{man,NOU...
#
#                                             Hipotesis  \
# 0   [NULL{null,PROPN}, a{a,DET}, person{person,NOU...
# 1   [NULL{null,PROPN}, a{a,DET}, guy{guy,NOUN}, in...
# 2   [NULL{null,PROPN}, a{a,DET}, boy{boy,NOUN}, sl...
# 3   [NULL{null,PROPN}, nobody{nobody,NOUN}, is{be,...
# 4   [NULL{null,PROPN}, the{the,DET}, child{child,N...
# ..                                                ...
# 95  [NULL{null,PROPN}, a{a,DET}, bunch{bunch,NOUN}...
# 96  [NULL{null,ADJ}, woman{woman,NOUN}, holds{hold...
# 97  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, pa...
# 98  [NULL{null,PROPN}, the{the,DET}, children{chil...
# 99  [NULL{null,ADJ}, one{one,NUM}, of{of,ADP}, the...
#
#                                                R_Text  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                                 R_Hip  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                               M_Align  \
# 0   [[2.760008, 0.060492776, 0.7027438, 0.20296031...
# 1   [[2.760008, 0.060492776, 0.64837056, 0.2029603...
# 2   [[2.760008, 0.060492776, 0.4078711, 2.2245083,...
# 3   [[2.760008, 1.9305927, 0.10360007, 0.8346571, ...
# 4   [[2.760008, 0.033035405, 0.5160244, 0.10360007...
# ..                                                ...
# 95  [[2.760008, 0.060492776, 0.41359743, 0.0717519...
# 96  [[2.760008, 0.475788, 0.8695118, 0.72379255, 0...
# 97  [[2.760008, 0.060492776, 0.43997452, 1.9583746...
# 98  [[2.760008, 0.033035405, 0.44769567, 0.0726737...
# 99  [[2.760008, 0.38066497, 0.07175191, 0.03303540...
#
#                                   Prediction       Gold_label
# 0      [0.4928643, 0.50155383, 0.0055818837]  [1.0, 0.0, 0.0]
# 1         [0.4695498, 0.3973312, 0.13311893]  [1.0, 0.0, 0.0]
# 2   [1.4341879e-06, 8.787866e-05, 0.9999107]  [0.0, 0.0, 1.0]
# 3      [0.033964496, 0.008023773, 0.9580117]  [0.0, 0.0, 1.0]
# 4    [0.0027733932, 0.9895504, 0.0076761814]  [0.0, 1.0, 0.0]
# ..                                       ...              ...
# 95      [0.8000752, 0.17865694, 0.021267932]  [1.0, 0.0, 0.0]
# 96       [0.7528739, 0.18234292, 0.06478321]  [1.0, 0.0, 0.0]
# 97  [7.513892e-05, 0.0013085654, 0.99861634]  [0.0, 0.0, 1.0]
# 98     [0.034316223, 0.83774996, 0.12793382]  [0.0, 0.0, 1.0]
# 99     [0.0035314807, 0.5047337, 0.49173486]  [0.0, 0.0, 1.0]
#
# [100 rows x 8 columns]

# %%
indice=4

# %%
t=pd.DataFrame(df.at[indice,"Text"][1:])
h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
print(len(t))
print(len(h))
# Out:
# 12
# 9

# %%
texto1 = df.at[indice,"R_Text"]
hipotesis1 = df.at[indice,"R_Hip"]

# %%
#ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
ma=pd.DataFrame(np.dot(texto1[:len(t)],hipotesis1[:len(h)].T),index=t,columns=h)
ma
# Out:
#                             (the{the,DET},)  (child{child,NOUN},)  \
# (a{a,DET},)                        1.000000             -0.051328
# (child{child,NOUN},)              -0.004055              0.592583
# (in{in,ADP},)                      0.092199              0.356418
# (a{a,DET},)                       -0.032085              0.555486
# (maroon{maroon,ADJ},)             -0.004055              0.592583
# (shirt{shirt,NOUN},)              -0.028509              0.076979
# (playing{play,VERB},)             -0.063612              0.207241
# (next{next,ADV},)                 -0.052467              0.338178
# (to{to,ADP},)                      0.030670              0.615341
# (a{a,DET},)                        0.016558              0.587738
# (fountain{fountain,NOUN},)        -0.004055              0.592583
# (.{.,PUNCT},)                     -0.020751              0.258244
#
#                             (is{be,VERB},)  (getting{get,VERB},)  \
# (a{a,DET},)                       0.092199              0.059661
# (child{child,NOUN},)              0.395472              0.635047
# (in{in,ADP},)                     1.000000              0.386440
# (a{a,DET},)                       0.332690              0.421470
# (maroon{maroon,ADJ},)             0.395472              0.635047
# (shirt{shirt,NOUN},)              0.090822              0.030187
# (playing{play,VERB},)             0.214158              0.256434
# (next{next,ADV},)                 0.274601              0.325514
# (to{to,ADP},)                     0.353080              0.454186
# (a{a,DET},)                       0.401760              0.405486
# (fountain{fountain,NOUN},)        0.395472              0.635047
# (.{.,PUNCT},)                     0.143708              0.233714
#
#                             (wet{wet,NOUN},)  (from{from,ADP},)  \
# (a{a,DET},)                        -0.019785          -0.069286
# (child{child,NOUN},)                0.453539           0.292145
# (in{in,ADP},)                       0.358259           0.199049
# (a{a,DET},)                         0.366236           0.270731
# (maroon{maroon,ADJ},)               0.453539           0.292145
# (shirt{shirt,NOUN},)                0.058698           0.159212
# (playing{play,VERB},)               0.281335           0.326803
# (next{next,ADV},)                   0.482399           0.242746
# (to{to,ADP},)                       0.532281           0.294777
# (a{a,DET},)                         0.442979           0.262394
# (fountain{fountain,NOUN},)          0.453539           0.292145
# (.{.,PUNCT},)                       0.165309           0.259916
#
#                             (the{the,DET},)  (fountain{fountain,NOUN},)  \
# (a{a,DET},)                       -0.040693                   -0.051328
# (child{child,NOUN},)               0.364275                    0.592583
# (in{in,ADP},)                      0.296287                    0.356418
# (a{a,DET},)                        0.458216                    0.555486
# (maroon{maroon,ADJ},)              0.364275                    0.592583
# (shirt{shirt,NOUN},)               0.015186                    0.076979
# (playing{play,VERB},)              0.189128                    0.207241
# (next{next,ADV},)                  0.246129                    0.338178
# (to{to,ADP},)                      0.357690                    0.615341
# (a{a,DET},)                        0.507419                    0.587738
# (fountain{fountain,NOUN},)         0.364275                    0.592583
# (.{.,PUNCT},)                      0.149354                    0.258244
#
#                             (.{.,PUNCT},)
# (a{a,DET},)                     -0.020751
# (child{child,NOUN},)             0.245613
# (in{in,ADP},)                    0.143708
# (a{a,DET},)                      0.194855
# (maroon{maroon,ADJ},)            0.245613
# (shirt{shirt,NOUN},)             0.135726
# (playing{play,VERB},)            0.142237
# (next{next,ADV},)                0.146186
# (to{to,ADP},)                    0.179694
# (a{a,DET},)                      0.157663
# (fountain{fountain,NOUN},)       0.245613
# (.{.,PUNCT},)                    1.000000

# %%
print(ma.max())
print(ma.idxmax())
# Out:
# (the{the,DET},)               1.000000
# (child{child,NOUN},)          0.615341
# (is{be,VERB},)                1.000000
# (getting{get,VERB},)          0.635047
# (wet{wet,NOUN},)              0.532281
# (from{from,ADP},)             0.326803
# (the{the,DET},)               0.507419
# (fountain{fountain,NOUN},)    0.615341
# (.{.,PUNCT},)                 1.000000
# dtype: float32
# (the{the,DET},)                         (a{a,DET},)
# (child{child,NOUN},)                  (to{to,ADP},)
# (is{be,VERB},)                        (in{in,ADP},)
# (getting{get,VERB},)           (child{child,NOUN},)
# (wet{wet,NOUN},)                      (to{to,ADP},)
# (from{from,ADP},)             (playing{play,VERB},)
# (the{the,DET},)                         (a{a,DET},)
# (fountain{fountain,NOUN},)            (to{to,ADP},)
# (.{.,PUNCT},)                         (.{.,PUNCT},)
# dtype: object

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(ma, center=0, cmap='Blues_r', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Texto -> Hipótesis, tomando la longitud de la hipótesis en [NOUN,VERB,ADJ,ADV]

# %%
maximo=0
columna_v=""
indice_v=""
for c in ma.columns:
    if("VERB" in str(c)):
        if maximo<ma[c].max():
            maximo=ma[c].max()
            columna_v=str(c).split('\'')[1].split("{")[0]
            indice_v=str(ma[c].idxmax()).split('\'')[1].split("{")[0]
        #print(ma[c].max(),c,ma[c].idxmax())v
print(maximo, columna_v,indice_v)
# Out:
# 0.9999998807907104 is in

# %%
ma.sum().sum()/ma.shape[0]*ma.shape[1]
# Out:
# 23.91029405593872

# %%
ma.quantile(0.25).values
# Out:
# array([-0.02284683,  0.22088867,  0.22355682,  0.19496795,  0.19332446,
#         0.06478363,  0.18942625,  0.1917536 ,  0.28645037,  0.12869236])

# %%
def getRelacionesMA_corte(indice,df):
    indices=[]
    todas_relaciones=[]
    todas_relacionest=[]
    print(len(df.at[indice,"Text"]),len(df.at[indice,"Hipotesis"]))
    if len(df.at[indice,"Text"]) > 42 and len(df.at[indice,"Hipotesis"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        #ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h[:41],index=t[:41])
        texto = df.at[indice,"R_Text"]
        hipotesis = df.at[indice,"R_Hip"]
        ma = pd.DataFrame(np.dot(texto[:len(t)],hipotesis[:len(h)].T),index=t[:42],columns=h[:42])
    elif len(df.at[indice,"Text"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        #ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t[:41])
        texto = df.at[indice,"R_Text"]
        hipotesis = df.at[indice,"R_Hip"]
        ma = pd.DataFrame(np.dot(texto[:len(t)],hipotesis[:len(h)].T),index=t[:42],columns=h)
    elif len(df.at[indice,"Hipotesis"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        texto = df.at[indice,"R_Text"]
        hipotesis = df.at[indice,"R_Hip"]
        ma = pd.DataFrame(np.dot(texto[:len(t)],hipotesis[:len(h)].T),index=t,columns=h[:42])
        #ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h[:41],index=t)
    else:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        texto = df.at[indice,"R_Text"]
        hipotesis = df.at[indice,"R_Hip"]
        ma = pd.DataFrame(np.dot(texto[:len(t)],hipotesis[:len(h)].T),index=t,columns=h)
        #ma=pd.DataFrame(df.at[indice,"Text"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
    #ma=ma/(ma.sum()).sum()
    #print(ma)
    informacion=ma.sum().sum()/ma.shape[0]*ma.shape[1]
    c=ma.mean().values #.quantile(corte).values
    print(c)
    for index,strings in ma.iterrows():
        #print(index)
        for l in range(len(c)):
            if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):
                if 'NOUN' in str(ma.columns[l]) or 'VERB' in str(ma.columns[l]) or 'ADJ' in str(ma.columns[l]) or 'PRON' in str(ma.columns[l]) or 'ADV' in str(ma.columns[l]):
                    #print("columnna:",col,strings[col])
                    #print("umbral",c[l],strings[l])
                    if strings[l] >= c[l]:# >=1:
                        todas_relaciones.append((index,ma.columns[l],strings[l]))
                    #elif strings[l] < 0.3 and strings[l] > 0:
                    #    todas_relaciones.append((index,ma.columns[l],strings[l]))
    maximo=0
    indice_v=""
    columna_v=""
    c=ma.max()
    for l in range(len(c)):
        for index,strings in ma.iterrows():
            if("VERB" in str(index)):
                if("VERB" in str(ma.columns[l])):
                    if maximo<c[l]:
                        maximo=c[l]
                        columna_v=str(ma.columns[l]).split('\'')[1].split("{")[0]
                        indice_v=str(index).split('\'')[1].split("{")[0]
    #Dirección contraria
    mat=ma.transpose()
    #print(ma)
    #print(ma.shape)
    #print(mat)
    #print(mat.shape)
    c1=mat.mean().values #.quantile(corte).values
    for index,strings in mat.iterrows():
        for l in range(len(c1)):
            if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):                
                if 'NOUN' in str(mat.columns[l]) or 'VERB' in str(mat.columns[l]) or 'ADJ' in str(mat.columns[l]) or 'PRON' in str(mat.columns[l]) or 'ADV' in str(mat.columns[l]):
                    #print("columnna:",col,strings[col])
                    #print("umbral",c[l])
                    if strings[l] >= c1[l]:# >=1:
                        todas_relacionest.append((index,mat.columns[l],strings[l]))
                    #elif strings[l] < 0.3 and strings[l] > 0:
                    #    todas_relacionest.append((index,mat.columns[l],strings[l]))
    labels=["NOUN","ADJ","VERB","ADV"]
    diccionarioTW = {}
    diccionarioTWT ={}
    print(todas_relaciones)
    #todas_relaciones=list(set(todas_relaciones))
    for l1 in labels[:]:
        for l2 in labels[:]:
            diccionarioTW[l1+"_"+l2]=[]
            diccionarioTWT[l1+"_"+l2]=[]
    for tr in todas_relaciones:
        #print(tr[0],"-",tr[1])
        t_=str(tr[0]).split(",")
        pt=t_[1].split("}")[0]
        h_=str(tr[1]).split(",")
        #print(t_,h_,"h0",h_[0])
        ph=h_[1].split("}")[0]
        if pt=="PRON":
            pt="NOUN"
        if ph=="PRON":
            ph="NOUN"
        #diccionarioTW[pt+"_"+ph].append(tr[2])
        if pt+"_"+ph in diccionarioTW:
            diccionarioTW[pt+"_"+ph].append(tr[2])
    for tr in todas_relacionest:
        #print(tr[0],"-",tr[1])
        t_=str(tr[0]).split(",")
        pt=t_[1].split("}")[0]
        h_=str(tr[1]).split(",")
        #print(t_,h_,"h0",h_[0])
        ph=h_[1].split("}")[0]
        if pt=="PRON":
            pt="NOUN"
        if ph=="PRON":
            ph="NOUN"
        #diccionarioTW[pt+"_"+ph].append(tr[2])
        if pt+"_"+ph in diccionarioTW:
            diccionarioTWT[pt+"_"+ph].append(tr[2])
    
    diccionarioTW_mean={}
    diccionarioTW_meanT={}
    diccionarioTW_mean_n={}
    diccionarioTW_rel={}
    for k in diccionarioTWT:
        if len(diccionarioTWT[k])!=0:
            diccionarioTW_meanT[k]=sum(diccionarioTWT[k])/len(diccionarioTWT[k])
        else:
            diccionarioTW_meanT[k]=0
    for k in diccionarioTW:
        if len(diccionarioTW[k])!=0:
            diccionarioTW_mean[k]=sum(diccionarioTW[k])#/len(diccionarioTW[k])
            diccionarioTW_mean_n[k+"_"]=len(diccionarioTW[k])#/ma.shape[0]
            diccionarioTW_rel[k+"_r"]=sum(diccionarioTW[k])/len(diccionarioTW[k])#/ma.shape[0]
        else:
            diccionarioTW_mean[k]=0
            diccionarioTW_mean_n[k+"_"]=0
            diccionarioTW_rel[k+"_r"]=0
    print("todas",todas_relaciones) 
    print("todas",todas_relacionest) 
    return diccionarioTW_mean,diccionarioTW_mean_n,todas_relaciones,todas_relacionest,diccionarioTW_rel,indice_v,columna_v,informacion#diccionarioTW_meanT

# %% [markdown]
# # Lectura de los 100 pares de T y H (muestreo)

# %%
prueba=pd.read_csv("prueba.csv")

# %%
textos = prueba["sentence1"].to_list()
hipotesis = prueba["sentence2"].to_list()
print(textos)
print(hipotesis)
# Out:
# ['A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.', 'A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.', 'A young boy runs across a road in front of a sky blue building with barred windows.', 'An Asian woman is standing on a path with a basket on her head looking into a mirror she is holding in her hand.', 'A child in a maroon shirt playing next to a fountain.', 'man dressed in orange clothing with face covered seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall.', 'An old man with a package poses in front of an advertisement.', 'People dressed in traditional Japanese garb walk in a procession through a courtyard paved with paving stones.', 'Two children play in the snow by the side of the road.', 'Blond-haired girl wearing a bicycle helmet, a black t-shirt that reads "Twizzlers" and a printed dog tag necklace around her neck.', 'A fat woman wearing faint blue top is blowing soap bubble.', 'A father and his daughter are riding a lawn mover down a street while dressed in American colors.', 'Two men are drumming, one is standing and one is sitting down.', 'Three men are carrying a red bag into a boat with another person and boat in the background.', 'A woman wearing a red coat stands on a wood floor in front of several paintings while two girls sit on the floor at her feet.', 'The sun breaks through the trees as a child rides a swing.', 'A man wearing a shite short-sleeved shirt kisses a woman wearing a light pink jacket while standing on a public street.', 'Someone splashing in the water.', 'An elderly lady holding a scruffy dog and smiling contently.', 'An Asian woman in a purple shirt preparing a bowl of food for the younger Asian boy sitting near buy, while an Asian man eats a roll and prepares to take some food up with his chopsticks.', 'A woman is holding a microphone in one hand and her mouth is open.', 'A young girl in a white t-shirt and a blue skirt wearing a light colored hat stands in a river next to a big rock.', 'A gymnast using a set of paralleled bars.', 'A guy with a football, a crowd watching him.', 'Seven young girls are being creative and making posters.', 'An old man in a baseball hat and an old woman in a jean jacket are standing outside, but are covered mostly in shadow.', 'A man is throwing a small white ball at some red cups.', 'Several street vehicles pass by a traditional architecture style of Thailand.', 'Man and a woman at the side of a table covered in books.', 'A group of people wait to cross the street in new york', 'Two guys in blue shirts talking.', 'The child is hanging upside down with his legs over a pole.', 'Four young men stare up at a basketball hoop with no net, in an outdoor, urban basketball court.', 'A group of people celebrating in the street.', 'A man and a woman stand in front of a Christmas tree contemplating a single thought.', 'A casually dressed young blond woman is looking away sadly as couple near her are kissing.', 'Girls giving a presentation for a school class.', 'A man and a child painting a post.', 'A young boy holding a red toy wearing green snowman and reindeer pajamas with an older woman on a couch behind him.', 'A lady with blue jeans and a brown shirt is speaking on her cellphone on the second floor of the mall.', 'A person obscured in shadow in a gymnasium.', 'African woman walking through field.', 'Men are playing rugby while covered in mud.', 'A child with curly blond-hair looks at another child with long brown hair while sitting on a bench.', 'A shirtless man with cropped hair smokes a cigarette and ties a plastic bag.', 'A group of people stares at a wall that is filled with drawings in a building.', 'A girl with curly hair and wearing a patriotic shirt is looking at a monarch butterfly sitting on her left index finger.', 'The blue kayak is being ridden over a small waterfall.', 'A person in a large pink  ...
# ['A person in appropriate institution protection works with meals.', 'a guy in a red top and tie makes a speech', 'A boy sleeps in his bed.', 'Nobody is standing', 'The child is getting wet from the fountain.', 'Two clowns are performing at a mall.', 'A man poses in front of an ad for beer.', 'People dressed in Japanese clothing walk through a courtyard.', 'Kids are enjoying the cold weather.', 'a girl with a helmet wears a dog tag', 'A fat woman is wearing pants.', 'two men cut grass by hand', 'Two people are drumming.', 'A person drives away in a winnebago.', 'Woman takes a break at a museum while her children sit by her feet.', 'The child on the swing is a girl.', 'A man is kissing a woman', 'Someone is having a picnic near the lake.', 'a woman holding a scruffy cat', 'A woman is preparing food for a child.', 'A woman standing at a microphone', 'A girl is wearing a hat.', 'A young gymnast is performing.', 'There is a guy with a basketball.', 'Girls are making posters.', 'An old woman has a light jean jacket.', 'The man playing a game.', 'Vehicles are going down a street in Thailand.', 'People near a lot of reading materials.', 'Some of the people are wearing sunglasses.', 'Two men complimenting each other on their blue shirts.', 'There is an adult upside down.', 'A group of women playing basketball in a gym.', 'There is a celebration going on', 'Two people talk loudly in front of a cactus.', 'A woman looks away after recognizing her ex-boyfriend kissing his new girl.', 'The girls are inside a school.', 'The father and son are repairing the sign.', 'The older woman behind the young boy is his mother.', 'the lady is talking on her phne', 'The person is trying to be sneaky.', 'The african woman is looking for someone in the fields.', 'The men are perfectly free of mud.', 'The school kids are relaxing during recess.', 'The man is not wearing a shirt.', 'A group of people analyze art together', 'A girl captures a butterfly for a science fair project', 'A kayak is being ridden.', 'The person is alone in the middle of the ocean.', 'Young children open presents under a large Christmas tree.', 'A boy pitches the ball.', 'A raven haired woman is seen by the crowd holding a white opened umbrella.', 'A recently engaged couple embrace on the street.', 'A person rides a skateboard.', 'A girl jumping rope on Mars.', 'A woman rises from a chair', 'Three people in nature.', 'A bird is looking for food on a lake.', 'a singer is on american idol', 'An older man is sweeping his patio while a passerby enters a building', 'Two people are in a bike race.', 'The person is a woman.', 'Women are looking at books on sale at a library.', 'The dog is outside.', 'A woman in green opening a box while a half concealed man manipulates a handheld device.', 'The woman is not going to finish the race.', 'A man is making pottery.', 'A guy is riding the bus.', 'A person with a great tatto', 'A woman is wearing a mask', 'Four kids pose on a beach.', 'A woman is putting on mascara.', 'A man eats a hamburger while his friend asks for a bite.', 'The boy sitting on top of his dads truck.', 'A young couple is very much in love.', 'A man in red is holding out his hand.', 'A boy is running outside.', 'A woman is singing on stage.', 'The boy is walking outside.', 'The sports fans are wearing yellow.', 'A wide reciever is trying to make a catch.', 'A man has damaged something.', 'There are people outside.', 'A women observing a camera', 'A girl is playing the piano in her living room.', 'A boy dressed for summer in a green shirt and kahki shorts', 'A dog is on the beach.', 'A skier preparing a trick', 'Two fathers maneuver their baby strollers into a foyer.', 'The man has blue sunglasses.', 'A child does a cannonball into a pool.', 'Laura Bush is giving a talk about the importance of literacy to young people.', 'Men are in wetsuits', 'The batsman is on a different team than the others around the pitching mound.', 'A boy is watching a movie in his living room.', 'a bunch  ...

# %%
import nltk, re, os
from nltk.corpus import wordnet as wn
import networkx as nx
from matplotlib import pyplot as plt

# %% [markdown]
# # Antonimia e hiponimia

# %%
def revision_ant_hipo(relaciones_alineadas,wn):
    sinonimos_words=[]
    antonimos_words=[]
    hyperonyms_words=[]
    hyponyms_words=[]
    relaciones_fuertes=[]
    verbos=[]
    for r_a in relaciones_alineadas[:]:
        sim=0
        sim_h=0
        cam_sh=0
        max_lch=0
        pal_sim_a=""
        pal_sim_b=""
        # pal_simp_a=""
        # pal_simp_b=""
        # pal_simsp_a=""
        # pal_simsp_b=""
        # pal_simlch_a=""
        # pal_simlch_b=""
        print(r_a[0],"a",r_a[1])
        word_t = str(r_a[0]).split('\'')[1]
        wt = word_t.split('{')[0]
        #lt = word_t.split('}')[0].split(',')[0].split('{')[1]
        print(word_t)
        print(word_t.split('}')[0].split(','))
        if len(word_t.split('}')[0].split(','))==2:
            pt = word_t.split('}')[0].split(',')[1]
        else:
            pt=""
        print(pt)
        w_in_text= wt + "," + pt
        #print(wt,lt,pt)
        word_h = str(r_a[1]).split('\'')[1]
        wh = word_h.split('{')[0] #palabra tal cual
        #lh = word_h.split('}')[0].split(',')[0].split('{')[1] #palabra lematizada
        print(word_h)
        if len(word_h.split('}')[0].split(','))==2:
            ph = word_h.split('}')[0].split(',')[1] # pos de la palabra
        else:
            ph=""
        print(ph)
        word = wh + "," + ph # palabra con el pos correspondiente
        #print(wh,lh,ph)
        ## buscamos medidas de las relaciones alineadas a traves de wordnet
        if pt == "NOUN" or pt=="PRON":
            w1_=wn.synsets(wt,wn.NOUN)
        elif pt == "VERB":
            w1_=wn.synsets(wt,wn.VERB)
        elif pt == "ADJ":
            w1_=wn.synsets(wt,wn.ADJ)
        elif pt == "ADV":
            w1_=wn.synsets(wt,wn.ADV)
        else:
            w1_=wn.synsets(wt)
        if ph == "NOUN" or ph=="PRON":
            w2_=wn.synsets(wh,wn.NOUN)
        elif ph == "VERB":
            w2_=wn.synsets(wh,wn.VERB)
        elif ph == "ADJ":
            w2_=wn.synsets(wh,wn.ADJ)
        elif ph == "ADV":
            w2_=wn.synsets(wh,wn.ADV)
        else:
            w2_=wn.synsets(wh)
        for a in w1_:
            for b in w2_:
                if pt==ph:            
                    #print(w_in_text,word)
                    #Busqueda en las definiciones
                    # defiiniciones=[]
                    # if wh in a.definition().split():
                    #     print("yes:",wh,a.definition().split())
                    if a.wup_similarity(b)>sim:
                        sim=a.wup_similarity(b)
                        pal_sim_a=a
                        pal_sim_b=b
                        
                    # if a.path_similarity(b, simulate_root=False)!=None:
                    #     if a.path_similarity(b, simulate_root=False)>sim_h:
                    #         sim_h=b.path_similarity(a, simulate_root=False)
                    #         pal_simp_a=a
                    #         pal_simp_b=b
                    # if a.shortest_path_distance(b)!=None:
                    #     if a.shortest_path_distance(b)>cam_sh:
                    #         cam_sh=a.shortest_path_distance(b)
                    #         pal_simsp_a=a
                    #         pal_simsp_b=b
                    # if a.pos()==b.pos():
                    #     if a.lch_similarity(b)>max_lch:
                    #         max_lch=a.lch_similarity(b)
                    #         pal_simlch_a=a
                    #         pal_simlch_b=b
        if pt==ph:
            if pt=="VERB":
                verbos.append((wt,wh,sim))
            if sim!=0:
                print("wup_sim:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,sim)
                if pal_sim_a.path_similarity(pal_sim_b, simulate_root=False)!=None:
                    print("path_sim:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.path_similarity(pal_sim_b, simulate_root=False))
                if pal_sim_a.shortest_path_distance(pal_sim_b)!=None:
                    print("spath:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.shortest_path_distance(pal_sim_b))
                if pal_sim_a.pos()==pal_sim_b.pos():
                    print("lch:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.lch_similarity(pal_sim_b))
                
                #relaciones fuertes combinando las medidas de wordnet
                #wup nos ayuda a filtrar que tan similares son
                #distancia más corta nos ayuda a identificar que no se encuentren muy lejos en el arbol de wordnet
                #lch similarity ayuda a identificar que en la taxonomia no se encunetren alejados, para los que
                #tienen unj hiperonimo en comun

                if sim>0.5:
                    if pal_sim_a.shortest_path_distance(pal_sim_b)!=None:
                        if pal_sim_a.shortest_path_distance(pal_sim_b)<=7:
                            #if pal_sim_a.pos()==pal_sim_b.pos():
                                #if pal_sim_a.lch_similarity(pal_sim_b)<2.0:
                                    relaciones_fuertes.append((pal_sim_a,pal_sim_b))
                #else:
                #    relaciones_debiles.append((pal_sim_a,pal_sim_b,-sim))
                #Busqueda de relaciones de sinonimia y antonimia
                synonyms=[]
                antonyms=[]   
                for l in pal_sim_a.lemmas():
                    synonyms.append(l.name())
                    #print(l)
                    if l.antonyms():
                        #print(l.antonyms()[0])
                        antonyms.append(l.antonyms()[0].name())
                if wh in synonyms:
                    print("Sinonimo: ",wt,wh)
                    sinonimos_words.append((wt,wh))
                if wh in antonyms:
                    print("Antonimo: ",wt,wh)
                    antonimos_words.append((wt,wh))
                #Busqueda de relaciones de hiperonimia e hiponimia
                hyperonyms=pal_sim_a.hypernym_paths()
                for p in hyperonyms:
                    if pal_sim_b in p:
                        if(pal_sim_a.shortest_path_distance(pal_sim_b)!=0):
                            print("hiperonimo:",pal_sim_a,pal_sim_b,pal_sim_a.shortest_path_distance(pal_sim_b))
                            hyperonyms_words.append((wt,wh))
                        else:
                            sinonimos_words.append((wt,wh))
                hyponyms=pal_sim_b.hypernym_paths()
                for p in hyponyms:
                    if pal_sim_a in p:
                        if pal_sim_a.shortest_path_distance(pal_sim_b)!=0:
                            print("Hiponimo:",pal_sim_a,pal_sim_b,pal_sim_b.shortest_path_distance(pal_sim_a))
                            hyponyms_words.append((wt,wh))
                for lh in pal_sim_a.lowest_common_hypernyms(pal_sim_b):
                    print("minimos hyper",lh)
                    print("a->H",pal_sim_a.shortest_path_distance(lh))
                    print("b->H",pal_sim_b.shortest_path_distance(lh))
                print()
    print("sinonimos",len(set(sinonimos_words)),sinonimos_words)
    print("antonimos",len(set(antonimos_words)),antonimos_words)
    print("hyperonyms",len(set(hyperonyms_words)),hyperonyms_words)
    print("hyponyms",len(set(hyponyms_words)),hyponyms_words)
    print("relaciones fuertes:",relaciones_fuertes)
    #print("relaciones debiles:",relaciones_debiles)
    print("verbos: ",verbos)
    maxv=0
    for v in verbos:
        print(v)
        if(float(v[2])>=maxv):
            maxv=v[2]
            v1=v[0]
            v2=v[1]
    #print(v1,v2)    
    return [len(set(sinonimos_words)),len(set(antonimos_words)),len(set(hyperonyms_words)),len(set(hyponyms_words)),maxv]

# %%
import spacy

nlp = spacy.load("en_core_web_md")
doc = nlp("A man is not dressed in orange clothing seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r=token.text
print(r)
# Out:
# c:\Users\Ninja\anaconda3\lib\site-packages\torch\__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\tensor\python_tensor.cpp:453.)
#   _C._set_default_tensor_type(t)
# A a DET DT det X True True
# man man NOUN NN nsubjpass xxx True False
# is be AUX VBZ auxpass xx True True
# not not PART RB neg xxx True True
# dressed dress VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# orange orange ADJ JJ amod xxxx True False
# clothing clothing NOUN NN pobj xxxx True False
# seemingly seemingly ADV RB advmod xxxx True False
# balancing balance VERB VBG advcl xxxx True False
# on on ADP IN prep xx True True
# a a DET DT det x True True
# cane cane NOUN NN pobj xxxx True False
# being be AUX VBG auxpass xxxx True True
# held hold VERB VBN acl xxxx True False
# be be AUX VB conj xx True True
# a a DET DT det x True True
# similarly similarly ADV RB advmod xxxx True False
# dressed dress VERB VBN amod xxxx True False
# man man NOUN NN attr xxx True False
# sitting sit VERB VBG acl xxxx True False
# crossed cross VERB VBD acl xxxx True False
# legged legged ADJ JJ oprd xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# ground ground NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# a a DET DT det x True True
# shopping shopping NOUN NN compound xxxx True False
# mall mall NOUN NN pobj xxxx True False
# dressed

# %%
import spacy
from spacy import displacy

# nlp = spacy.load("en_core_web_md")
# doc = nlp("A man is not dressed in orange clothing seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall")
# displacy.serve(doc, style="dep")

# %%
nlp = spacy.load("en_core_web_md")  # make sure to use larger package!
doc1 = nlp("An old man runs in front of an advertisement.")
doc2 = nlp("A man sleeps in front of an ad for beer.")
for token in doc1:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r_t=token
print(r_t)
for token in doc2:
    #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
    #        token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r_h=token
print(r_h)
# Similarity of two documents
print(doc1, "<->", doc2, doc1.similarity(doc2))
# Similarity of tokens and spans
french_fries = r_t
burgers = r_h
print(french_fries, "<->", burgers, french_fries.similarity(burgers))
# Out:
# An an DET DT det Xx True True
# old old ADJ JJ amod xxx True False
# man man NOUN NN nsubj xxx True False
# runs run VERB VBZ ROOT xxxx True False
# in in ADP IN prep xx True True
# front front NOUN NN pobj xxxx True True
# of of ADP IN prep xx True True
# an an DET DT det xx True True
# advertisement advertisement NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# runs
# sleeps
# An old man runs in front of an advertisement. <-> A man sleeps in front of an ad for beer. 0.9374918953004442
# runs <-> sleeps 0.30534598231315613

# %%
from sentence_transformers import SentenceTransformer, util, InputExample, losses
#Load the model(here we use minilm)
model = SentenceTransformer('all-MiniLM-L6-v2')
#We get the embeddings by calling model.encode()

# %% [markdown]
# # prueba

# %%
features=[]
length=len(textos)
for i in range(length):
#length=[0,1,2,3,4]
#for i in length:
    print(i)
    print("Texto: ",textos[i])
    print("Hipótesis: ",hipotesis[i])
    #print("similaridad: ",doc1.similarity(doc2))
    todas_relaciones,todos_conteos,relaciones_alineadas,relaciones_alineadast,relatip_num,tverb,hverb,informa=getRelacionesMA_corte(i,df)
    doc1 = nlp(textos[i])
    for token in doc1:
        #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        #        token.shape_, token.is_alpha, token.is_stop)
        if token.text==tverb:
            r_t=token
    doc2 = nlp(hipotesis[i])
    for token in doc2:
        if token.text==hverb:
            r_h=token
    print(todas_relaciones)
    print("Relaciones",len(relaciones_alineadas),len(relaciones_alineadast))
    rel_semanticas=revision_ant_hipo(relaciones_alineadas,wn)
    print("semanticas",rel_semanticas)
    emb1 = model.encode(tverb)
    emb2 = model.encode(hverb)
    #Get the cosine similarity score between sentences
    cos_sim = util.cos_sim(emb1, emb2)
    similitud_verbos=float(cos_sim[0][0])
    print("verbos a comparar",tverb,hverb)
    if len(relaciones_alineadast)==0:
        total=0
    else:
        total=len(relaciones_alineadas)/len(relaciones_alineadast)
    features.append(list(todas_relaciones.values())+list(todos_conteos.values())+rel_semanticas+[similitud_verbos,informa])#+list(todas_relacionesT.values()))
    #len((set(textos[i].split()).intersection(set(hipotesis[i]))))/len(set(textos[i].split()).union(set(hipotesis[i])))]) 
    #+rel_semanticast)#[doc1.similarity(doc2)]+)
# Out:
# 0
# Texto:  A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.
# Hipótesis:  A person in appropriate institution protection works with meals.
# 23 11
# [0.05195193 0.41490972 0.30828097 0.31621194 0.27880117 0.16438212
#  0.21818553 0.25916344 0.36078468 0.19052766]
# [(('man{man,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('man{man,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('man{man,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('man{man,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('man{man,NOUN}',), ('works{work,VERB}',), 0.25911367), (('man{man,NOUN}',), ('meals{meal,NOUN}',), 0.5552681), (('wearing{wear,VERB}',), ('person{person,NOUN}',), 0.43656164), (('wearing{wear,VERB}',), ('appropriate{appropriate,ADJ}',), 0.36109936), (('wearing{wear,VERB}',), ('protection{protection,NOUN}',), 0.23045689), (('wearing{wear,VERB}',), ('meals{meal,NOUN}',), 0.36198434), (('blue{blue,ADJ}',), ('person{person,NOUN}',), 1.0000002), (('blue{blue,ADJ}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('blue{blue,ADJ}',), ('institution{institution,NOUN}',), 0.4250537), (('blue{blue,ADJ}',), ('protection{protection,NOUN}',), 0.34479138), (('blue{blue,ADJ}',), ('works{work,VERB}',), 0.25911367), (('blue{blue,ADJ}',), ('meals{meal,NOUN}',), 0.5552681), (('apron{apron,NOUN}',), ('meals{meal,NOUN}',), 0.40719426), (('mask{mask,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('mask{mask,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('mask{mask,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('mask{mask,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('mask{mask,NOUN}',), ('works{work,VERB}',), 0.25911367), (('mask{mask,NOUN}',), ('meals{meal,NOUN}',), 0.5552681), (('is{be,VERB}',), ('institution{institution,NOUN}',), 0.28339255), (('is{be,VERB}',), ('works{work,VERB}',), 0.29310945), (('handling{handle,VERB}',), ('person{person,NOUN}',), 0.63504684), (('handling{handle,VERB}',), ('appropriate{appropriate,ADJ}',), 0.42146954), (('handling{handle,VERB}',), ('institution{institution,NOUN}',), 0.3802162), (('handling{handle,VERB}',), ('protection{protection,NOUN}',), 0.389892), (('handling{handle,VERB}',), ('works{work,VERB}',), 0.30958527), (('handling{handle,VERB}',), ('meals{meal,NOUN}',), 0.4570232), (('food{food,NOUN}',), ('institution{institution,NOUN}',), 0.45354372), (('food{food,NOUN}',), ('protection{protection,NOUN}',), 0.18879904), (('food{food,NOUN}',), ('works{work,VERB}',), 0.3716899), (('food{food,NOUN}',), ('meals{meal,NOUN}',), 0.37640375), (('tray{tray,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('tray{tray,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('tray{tray,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('tray{tray,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('tray{tray,NOUN}',), ('works{work,VERB}',), 0.25911367), (('tray{tray,NOUN}',), ('meals{meal,NOUN}',), 0.5552681)]
# todas [(('man{man,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('man{man,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('man{man,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('man{man,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('man{man,NOUN}',), ('works{work,VERB}',), 0.25911367), (('man{man,NOUN}',), ('meals{meal,NOUN}',), 0.5552681), (('wearing{wear,VERB}',), ('person{person,NOUN}',), 0.43656164), (('wearing{wear,VERB}',), ('appropriate{appropriate,ADJ}',), 0.36109936), (('wearing{wear,VERB}',), ('protection{protection,NOUN}',), 0.23045689), (('wearing{wear,VERB}',), ('meals{meal,NOUN}',), 0.36198434), (('blue{blue,ADJ}',), ('person{person,NOUN}',), 1.0000002), (('blue{blue,ADJ}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('blue{blue,ADJ}',), ('institution{institution,NOUN}',), 0.4250537), (('blue{blue,ADJ}',), ('protection{protection,NOUN}',), 0.34479138), (('blue{blue,ADJ}',), ('works{work,VERB}',), 0.25911367), (('blue{blue,ADJ}',), ('meals{meal,NOUN}',), 0.5552681), (('apron{apron,NOUN}',), ('meals{meal,NOUN}',), 0.40719426), (('mask{mask,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('mask{mask,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('mask{mask,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('mask{mask,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('mask{mask,NOUN}',), ('works{work,VERB}',), 0.25911367), (('mask{mask,NOUN}',), ('meals{meal,NOUN}',), 0.5552681), (('is{be,VERB}',), ('institution{institution,NOUN}',), 0.28339255), (('is{be,VERB}',), ('works{work,VERB}',), 0.29310945), (('handling{handle,VERB}',), ('person{person,NOUN}',), 0.63504684), (('handling{handle,VERB}',), ('appropriate{appropriate,ADJ}',), 0.42146954), (('handling{handle,VERB}',), ('institution{institution,NOUN}',), 0.3802162), (('handling{handle,VERB}',), ('protection{protection,NOUN}',), 0.389892), (('handling{handle,VERB}',), ('works{work,VERB}',), 0.30958527), (('handling{handle,VERB}',), ('meals{meal,NOUN}',), 0.4570232), (('food{food,NOUN}',), ('institution{institution,NOUN}',), 0.45354372), (('food{food,NOUN}',), ('protection{protection,NOUN}',), 0.18879904), (('food{food,NOUN}',), ('works{work,VERB}',), 0.3716899), (('food{food,NOUN}',), ('meals{meal,NOUN}',), 0.37640375), (('tray{tray,NOUN}',), ('person{person,NOUN}',), 1.0000002), (('tray{tray,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.45452675), (('tray{tray,NOUN}',), ('institution{institution,NOUN}',), 0.4250537), (('tray{tray,NOUN}',), ('protection{protection,NOUN}',), 0.34479138), (('tray{tray,NOUN}',), ('works{work,VERB}',), 0.25911367), (('tray{tray,NOUN}',), ('meals{meal,NOUN}',), 0.5552681)]
# todas [(('person{person,NOUN}',), ('man{man,NOUN}',), 1.0000002), (('person{person,NOUN}',), ('wearing{wear,VERB}',), 0.43656164), (('person{person,NOUN}',), ('blue{blue,ADJ}',), 1.0000002), (('person{person,NOUN}',), ('shirt{shirt,NOUN}',), 0.32184687), (('person{person,NOUN}',), ('black{black,ADJ}',), 0.22088867), (('person{person,NOUN}',), ('apron{apron,NOUN}',), 0.3527977), (('person{person,NOUN}',), ('eyeglasses{eyeglass,NOUN}',), 0.22088867), (('person{person,NOUN}',), ('mask{mask,NOUN}',), 1.0000002), (('person{person,NOUN}',), ('is{be,VERB}',), 0.2587508), (('person{person,NOUN}',), ('handling{handle,VERB}',), 0.63504684), (('person{person,NOUN}',), ('tray{tray,NOUN}',), 1.0000002), (('appropriate{appropriate,ADJ}',), ('man{man,NOUN}',), 0.45452675), (('appropriate{appropriate,ADJ}',), ('wearing{wear,VERB}',), 0.36109936), (('appropriate{appropriate,ADJ}',), ('blue{blue,ADJ}',), 0.45452675), (('appropriate{appropriate,ADJ}',), ('shirt{shirt,NOUN}',), 0.26666284), (('appropriate{appropriate,ADJ}',), ('black{black,ADJ}',), 0.30180514), (('appropriate{appropriate,ADJ}',), ('apron{apron,NOUN}',), 0.26739785), (('appropriate{appropriate,ADJ}',), ('eyeglasses{eyeglass,NOUN}',), 0.30180514), (('appropriate{appropriate,ADJ}',), ('mask{mask,NOUN}',), 0.45452675), (('appropriate{appropriate,ADJ}',), ('handling{handle,VERB}',), 0.42146954), (('appropriate{appropriate,ADJ}',), ('tray{tray,NOUN}',), 0.45452675), (('institution{institution,NOUN}',), ('man{man,NOUN}',), 0.4250537), (('institution{institution,NOUN}',), ('blue{blue,ADJ}',), 0.4250537), (('institution{institution,NOUN}',), ('shirt{shirt,NOUN}',), 0.20044723), (('institution{institution,NOUN}',), ('black{black,ADJ}',), 0.20182349), (('institution{institution,NOUN}',), ('eyeglasses{eyeglass,NOUN}',), 0.20182349), (('institution{institution,NOUN}',), ('mask{mask,NOUN}',), 0.4250537), (('institution{institution,NOUN}',), ('is{be,VERB}',), 0.28339255), (('institution{institution,NOUN}',), ('food{food,NOUN}',), 0.45354372), (('institution{institution,NOUN}',), ('tray{tray,NOUN}',), 0.4250537), (('protection{protection,NOUN}',), ('handling{handle,VERB}',), 0.389892), (('works{work,VERB}',), ('shirt{shirt,NOUN}',), 0.18690631), (('works{work,VERB}',), ('is{be,VERB}',), 0.29310945), (('works{work,VERB}',), ('food{food,NOUN}',), 0.3716899), (('meals{meal,NOUN}',), ('man{man,NOUN}',), 0.5552681), (('meals{meal,NOUN}',), ('wearing{wear,VERB}',), 0.36198434), (('meals{meal,NOUN}',), ('blue{blue,ADJ}',), 0.5552681), (('meals{meal,NOUN}',), ('shirt{shirt,NOUN}',), 0.3429978), (('meals{meal,NOUN}',), ('black{black,ADJ}',), 0.307459), (('meals{meal,NOUN}',), ('apron{apron,NOUN}',), 0.40719426), (('meals{meal,NOUN}',), ('eyeglasses{eyeglass,NOUN}',), 0.307459), (('meals{meal,NOUN}',), ('mask{mask,NOUN}',), 0.5552681), (('meals{meal,NOUN}',), ('is{be,VERB}',), 0.22973013), (('meals{meal,NOUN}',), ('handling{handle,VERB}',), 0.4570232), (('meals{meal,NOUN}',), ('food{food,NOUN}',), 0.37640375), (('meals{meal,NOUN}',), ('tray{tray,NOUN}',), 0.5552681)]
# {'NOUN_NOUN': 8.401281014084816, 'NOUN_ADJ': 1.3635802567005157, 'NOUN_VERB': 1.1490308940410614, 'NOUN_ADV': 0, 'ADJ_NOUN': 2.3251134157180786, 'ADJ_ADJ': 0.45452675223350525, 'ADJ_VERB': 0.2591136693954468, 'ADJ_ADV': 0, 'VERB_NOUN': 3.174573689699173, 'VERB_ADJ': 0.7825689017772675, 'VERB_VERB': 0.6026947200298309, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 41 46
# ('man{man,NOUN}',) a ('person{person,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 0.8
# path_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 0.5
# spath: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 1
# lch: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 2.9444389791664407
# hiperonimo: Synset('man.n.03') Synset('person.n.01') 1
# hiperonimo: Synset('man.n.03') Synset('person.n.01') 1
# minimos hyper Synset('person.n.01')
# a->H 1
# b->H 0
#
# ('man{man,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('man{man,NOUN}',) a ('institution{institution,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 0.6
# path_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 0.2
# spath: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 4
# lch: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 2.0281482472922856
# minimos hyper Synset('group.n.01')
# a->H 1
# b->H 3
#
# ('man{man,NOUN}',) a ('protection{protection,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.10') Palabra2: Synset('protective_covering.n.01') 0.625
# path_sim: Palabra1:  Synset('man.n.10') Palabra2: Synset('protective_covering.n.01') 0.14285714285714285
# spath: Palabra1:  Synset('man.n.10') Palabra2: Synset('protective_covering.n.01') 6
# lch: Palabra1:  Synset('man.n.10') Palabra2: Synset('protective_covering.n.01') 1.6916760106710724
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 2
#
# ('man{man,NOUN}',) a ('works{work,VERB}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('man{man,NOUN}',) a ('meals{meal,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('meal.n.01') 0.3333333333333333
# path_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('meal.n.01') 0.1111111111111111
# spath: Palabra1:  Synset('man.n.03') Palabra2: Synset('meal.n.01') 8
# lch: Palabra1:  Synset('man.n.03') Palabra2: Synset('meal.n.01') 1.4403615823901665
# minimos hyper Synset('physical_entity.n.01')
# a->H 3
# b->H 5
#
# ('wearing{wear,VERB}',) a ('person{person,NOUN}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# person{person,NOUN}
# NOUN
# ('wearing{wear,VERB}',) a ('appropriate{appropriate,ADJ}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# appropriate{appropriate,ADJ}
# ADJ
# ('wearing{wear,VERB}',) a ('protection{protection,NOUN}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# protection{protection,NOUN}
# NOUN
# ('wearing{wear,VERB}',) a ('meals{meal,NOUN}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# meals{meal,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('person{person,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# person{person,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('appropriate{appropriate,ADJ}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# appropriate{appropriate,ADJ}
# ADJ
# wup_sim: Palabra1:  Synset('blue.s.01') Palabra2: Synset('appropriate.a.01') 0.5
#
# ('blue{blue,ADJ}',) a ('institution{institution,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# institution{institution,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('protection{protection,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# protection{protection,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('works{work,VERB}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# works{work,VERB}
# VERB
# ('blue{blue,ADJ}',) a ('meals{meal,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# meals{meal,NOUN}
# NOUN
# ('apron{apron,NOUN}',) a ('meals{meal,NOUN}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 0.25
# path_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 12
# lch: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 1.072636802264849
# minimos hyper Synset('physical_entity.n.01')
# a->H 7
# b->H 5
#
# ('mask{mask,NOUN}',) a ('person{person,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('person.n.01') 0.5714285714285714
# path_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('person.n.01') 0.14285714285714285
# spath: Palabra1:  Synset('mask.n.01') Palabra2: Synset('person.n.01') 6
# lch: Palabra1:  Synset('mask.n.01') Palabra2: Synset('person.n.01') 1.6916760106710724
# minimos hyper Synset('whole.n.02')
# a->H 3
# b->H 3
#
# ('mask{mask,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('mask{mask,NOUN}',) a ('institution{institution,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 0.6666666666666666
# path_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 0.16666666666666666
# spath: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 5
# lch: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 1.845826690498331
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 3
#
# ('mask{mask,NOUN}',) a ('protection{protection,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 0.9333333333333333
# path_sim: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 0.5
# spath: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 1
# lch: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 2.9444389791664407
# hiperonimo: Synset('mask.n.04') Synset('protective_covering.n.01') 1
# minimos hyper Synset('protective_covering.n.01')
# a->H 1
# b->H 0
#
# ('mask{mask,NOUN}',) a ('works{work,VERB}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('mask{mask,NOUN}',) a ('meals{meal,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 0.2857142857142857
# path_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 0.09090909090909091
# spath: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 10
# lch: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 1.2396908869280152
# minimos hyper Synset('physical_entity.n.01')
# a->H 5
# b->H 5
#
# ('is{be,VERB}',) a ('institution{institution,NOUN}',)
# is{be,VERB}
# ['is{be', 'VERB']
# VERB
# institution{institution,NOUN}
# NOUN
# ('is{be,VERB}',) a ('works{work,VERB}',)
# is{be,VERB}
# ['is{be', 'VERB']
# VERB
# works{work,VERB}
# VERB
# wup_sim: Palabra1:  Synset('be.v.01') Palabra2: Synset('work.v.14') 0.6666666666666666
# path_sim: Palabra1:  Synset('be.v.01') Palabra2: Synset('work.v.14') 0.5
# spath: Palabra1:  Synset('be.v.01') Palabra2: Synset('work.v.14') 1
# lch: Palabra1:  Synset('be.v.01') Palabra2: Synset('work.v.14') 2.5649493574615367
# Hiponimo: Synset('be.v.01') Synset('work.v.14') 1
# minimos hyper Synset('be.v.01')
# a->H 0
# b->H 1
#
# ('handling{handle,VERB}',) a ('person{person,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# person{person,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('appropriate{appropriate,ADJ}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# appropriate{appropriate,ADJ}
# ADJ
# ('handling{handle,VERB}',) a ('institution{institution,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# institution{institution,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('protection{protection,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# protection{protection,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('works{work,VERB}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# works{work,VERB}
# VERB
# wup_sim: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 0.8
# path_sim: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 0.5
# spath: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 1
# lch: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 2.5649493574615367
# Hiponimo: Synset('manage.v.02') Synset('work.v.17') 1
# minimos hyper Synset('manage.v.02')
# a->H 0
# b->H 1
#
# ('handling{handle,VERB}',) a ('meals{meal,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# meals{meal,NOUN}
# NOUN
# ('food{food,NOUN}',) a ('institution{institution,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 0.6153846153846154
# path_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 0.16666666666666666
# spath: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 5
# lch: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 1.845826690498331
# minimos hyper Synset('cognition.n.01')
# a->H 2
# b->H 3
#
# ('food{food,NOUN}',) a ('protection{protection,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 0.46153846153846156
# path_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 0.125
# spath: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 7
# lch: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 1.55814461804655
# minimos hyper Synset('psychological_feature.n.01')
# a->H 3
# b->H 4
#
# ('food{food,NOUN}',) a ('works{work,VERB}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('food{food,NOUN}',) a ('meals{meal,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 0.8333333333333334
# path_sim: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 0.3333333333333333
# spath: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 2
# lch: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 2.538973871058276
# Hiponimo: Synset('food.n.01') Synset('meal.n.01') 2
# minimos hyper Synset('food.n.01')
# a->H 0
# b->H 2
#
# ('tray{tray,NOUN}',) a ('person{person,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('person.n.01') 0.5
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('person.n.01') 0.1111111111111111
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('person.n.01') 8
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('person.n.01') 1.4403615823901665
# minimos hyper Synset('whole.n.02')
# a->H 5
# b->H 3
#
# ('tray{tray,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('tray{tray,NOUN}',) a ('institution{institution,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 0.5882352941176471
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 0.125
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 7
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 3
#
# ('tray{tray,NOUN}',) a ('protection{protection,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('protective_covering.n.01') 0.625
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('protective_covering.n.01') 0.14285714285714285
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('protective_covering.n.01') 6
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('protective_covering.n.01') 1.6916760106710724
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 2
#
# ('tray{tray,NOUN}',) a ('works{work,VERB}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('tray{tray,NOUN}',) a ('meals{meal,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 0.25
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 12
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 1.072636802264849
# minimos hyper Synset('physical_entity.n.01')
# a->H 7
# b->H 5
#
# sinonimos 0 []
# antonimos 0 []
# hyperonyms 2 [('man', 'person'), ('man', 'person'), ('mask', 'protection')]
# hyponyms 3 [('is', 'works'), ('handling', 'works'), ('food', 'meals')]
# relaciones fuertes: [(Synset('man.n.03'), Synset('person.n.01')), (Synset('world.n.08'), Synset('institution.n.01')), (Synset('man.n.10'), Synset('protective_covering.n.01')), (Synset('mask.n.01'), Synset('person.n.01')), (Synset('mask.n.01'), Synset('institution.n.02')), (Synset('mask.n.04'), Synset('protective_covering.n.01')), (Synset('be.v.01'), Synset('work.v.14')), (Synset('manage.v.02'), Synset('work.v.17')), (Synset('food.n.03'), Synset('institution.n.03')), (Synset('food.n.01'), Synset('meal.n.01')), (Synset('tray.n.01'), Synset('institution.n.02')), (Synset('tray.n.01'), Synset('protective_covering.n.01'))]
# verbos:  [('is', 'works', 0.6666666666666666), ('handling', 'works', 0.8)]
# ('is', 'works', 0.6666666666666666)
# ('handling', 'works', 0.8)
# semanticas [0, 0, 2, 3, 0.8]
# verbos a comparar wearing works
# 1
# Texto:  A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.
# Hipótesis:  a guy in a red top and tie makes a speech
# 22 12
# [0.02292145 0.4707365  0.35584572 0.36204326 0.4707365  0.35701588
#  0.33923605 0.38525042 0.3369102  0.37023786 0.4707365 ]
# [(('man{man,NOUN}',), ('guy{guy,NOUN}',), 1.0000002), (('man{man,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('man{man,NOUN}',), ('tie{tie,NOUN}',), 0.39939716), (('man{man,NOUN}',), ('speech{speech,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('guy{guy,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('red{red,ADJ}',), 1.0000002), (('red{red,ADJ}',), ('tie{tie,NOUN}',), 0.39939716), (('red{red,ADJ}',), ('speech{speech,NOUN}',), 1.0000002), (('shirt{shirt,NOUN}',), ('top{top,NOUN}',), 1.0000001), (('shirt{shirt,NOUN}',), ('makes{make,VERB}',), 0.4382779), (('black{black,ADJ}',), ('tie{tie,NOUN}',), 0.99999976), (('tie{tie,NOUN}',), ('top{top,NOUN}',), 0.7397857), (('tie{tie,NOUN}',), ('makes{make,VERB}',), 0.38195562), (('stands{stand,VERB}',), ('top{top,NOUN}',), 0.4382779), (('stands{stand,VERB}',), ('makes{make,VERB}',), 0.9999999), (('wedding{wedding,NOUN}',), ('guy{guy,NOUN}',), 1.0000002), (('wedding{wedding,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('wedding{wedding,NOUN}',), ('tie{tie,NOUN}',), 0.39939716), (('wedding{wedding,NOUN}',), ('speech{speech,NOUN}',), 1.0000002), (('make{make,VERB}',), ('guy{guy,NOUN}',), 0.5058919), (('make{make,VERB}',), ('red{red,ADJ}',), 0.5058919), (('make{make,VERB}',), ('tie{tie,NOUN}',), 0.5523725), (('make{make,VERB}',), ('speech{speech,NOUN}',), 0.5058919), (('speech{speech,NOUN}',), ('guy{guy,NOUN}',), 1.0000001), (('speech{speech,NOUN}',), ('red{red,ADJ}',), 1.0000001), (('speech{speech,NOUN}',), ('tie{tie,NOUN}',), 0.39939725), (('speech{speech,NOUN}',), ('speech{speech,NOUN}',), 1.0000001)]
# todas [(('man{man,NOUN}',), ('guy{guy,NOUN}',), 1.0000002), (('man{man,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('man{man,NOUN}',), ('tie{tie,NOUN}',), 0.39939716), (('man{man,NOUN}',), ('speech{speech,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('guy{guy,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('red{red,ADJ}',), 1.0000002), (('red{red,ADJ}',), ('tie{tie,NOUN}',), 0.39939716), (('red{red,ADJ}',), ('speech{speech,NOUN}',), 1.0000002), (('shirt{shirt,NOUN}',), ('top{top,NOUN}',), 1.0000001), (('shirt{shirt,NOUN}',), ('makes{make,VERB}',), 0.4382779), (('black{black,ADJ}',), ('tie{tie,NOUN}',), 0.99999976), (('tie{tie,NOUN}',), ('top{top,NOUN}',), 0.7397857), (('tie{tie,NOUN}',), ('makes{make,VERB}',), 0.38195562), (('stands{stand,VERB}',), ('top{top,NOUN}',), 0.4382779), (('stands{stand,VERB}',), ('makes{make,VERB}',), 0.9999999), (('wedding{wedding,NOUN}',), ('guy{guy,NOUN}',), 1.0000002), (('wedding{wedding,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('wedding{wedding,NOUN}',), ('tie{tie,NOUN}',), 0.39939716), (('wedding{wedding,NOUN}',), ('speech{speech,NOUN}',), 1.0000002), (('make{make,VERB}',), ('guy{guy,NOUN}',), 0.5058919), (('make{make,VERB}',), ('red{red,ADJ}',), 0.5058919), (('make{make,VERB}',), ('tie{tie,NOUN}',), 0.5523725), (('make{make,VERB}',), ('speech{speech,NOUN}',), 0.5058919), (('speech{speech,NOUN}',), ('guy{guy,NOUN}',), 1.0000001), (('speech{speech,NOUN}',), ('red{red,ADJ}',), 1.0000001), (('speech{speech,NOUN}',), ('tie{tie,NOUN}',), 0.39939725), (('speech{speech,NOUN}',), ('speech{speech,NOUN}',), 1.0000001)]
# todas [(('guy{guy,NOUN}',), ('man{man,NOUN}',), 1.0000002), (('guy{guy,NOUN}',), ('dressed{dress,VERB}',), 0.43656164), (('guy{guy,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('guy{guy,NOUN}',), ('wedding{wedding,NOUN}',), 1.0000002), (('guy{guy,NOUN}',), ('reception{reception,NOUN}',), 0.26073933), (('guy{guy,NOUN}',), ('make{make,VERB}',), 0.5058919), (('guy{guy,NOUN}',), ('speech{speech,NOUN}',), 1.0000001), (('red{red,ADJ}',), ('man{man,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('dressed{dress,VERB}',), 0.43656164), (('red{red,ADJ}',), ('red{red,ADJ}',), 1.0000002), (('red{red,ADJ}',), ('wedding{wedding,NOUN}',), 1.0000002), (('red{red,ADJ}',), ('reception{reception,NOUN}',), 0.26073933), (('red{red,ADJ}',), ('make{make,VERB}',), 0.5058919), (('red{red,ADJ}',), ('speech{speech,NOUN}',), 1.0000001), (('top{top,NOUN}',), ('shirt{shirt,NOUN}',), 1.0000001), (('top{top,NOUN}',), ('tie{tie,NOUN}',), 0.7397857), (('top{top,NOUN}',), ('stands{stand,VERB}',), 0.4382779), (('top{top,NOUN}',), ('reception{reception,NOUN}',), 0.30064905), (('tie{tie,NOUN}',), ('black{black,ADJ}',), 0.99999976), (('tie{tie,NOUN}',), ('reception{reception,NOUN}',), 0.27013066), (('tie{tie,NOUN}',), ('make{make,VERB}',), 0.5523725), (('makes{make,VERB}',), ('shirt{shirt,NOUN}',), 0.4382779), (('makes{make,VERB}',), ('tie{tie,NOUN}',), 0.38195562), (('makes{make,VERB}',), ('stands{stand,VERB}',), 0.9999999), (('makes{make,VERB}',), ('reception{reception,NOUN}',), 0.33310074), (('speech{speech,NOUN}',), ('man{man,NOUN}',), 1.0000002), (('speech{speech,NOUN}',), ('dressed{dress,VERB}',), 0.43656164), (('speech{speech,NOUN}',), ('red{red,ADJ}',), 1.0000002), (('speech{speech,NOUN}',), ('wedding{wedding,NOUN}',), 1.0000002), (('speech{speech,NOUN}',), ('reception{reception,NOUN}',), 0.26073933), (('speech{speech,NOUN}',), ('make{make,VERB}',), 0.5058919), (('speech{speech,NOUN}',), ('speech{speech,NOUN}',), 1.0000001)]
# {'NOUN_NOUN': 8.937978565692902, 'NOUN_ADJ': 3.0000005960464478, 'NOUN_VERB': 0.8202335238456726, 'NOUN_ADV': 0, 'ADJ_NOUN': 3.3993974030017853, 'ADJ_ADJ': 1.000000238418579, 'ADJ_VERB': 0, 'ADJ_ADV': 0, 'VERB_NOUN': 2.002434253692627, 'VERB_ADJ': 0.5058919191360474, 'VERB_VERB': 0.9999998807907104, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 27 32
# ('man{man,NOUN}',) a ('guy{guy,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 0.9473684210526315
# path_sim: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 0.5
# spath: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 1
# lch: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 2.9444389791664407
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# minimos hyper Synset('man.n.01')
# a->H 0
# b->H 1
#
# ('man{man,NOUN}',) a ('red{red,ADJ}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('man{man,NOUN}',) a ('tie{tie,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.10') Palabra2: Synset('link.n.02') 0.631578947368421
# path_sim: Palabra1:  Synset('man.n.10') Palabra2: Synset('link.n.02') 0.125
# spath: Palabra1:  Synset('man.n.10') Palabra2: Synset('link.n.02') 7
# lch: Palabra1:  Synset('man.n.10') Palabra2: Synset('link.n.02') 1.55814461804655
# minimos hyper Synset('instrumentality.n.03')
# a->H 3
# b->H 4
#
# ('man{man,NOUN}',) a ('speech{speech,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('speech.n.02') 0.4444444444444444
# path_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('speech.n.02') 0.16666666666666666
# spath: Palabra1:  Synset('world.n.08') Palabra2: Synset('speech.n.02') 5
# lch: Palabra1:  Synset('world.n.08') Palabra2: Synset('speech.n.02') 1.845826690498331
# minimos hyper Synset('abstraction.n.06')
# a->H 2
# b->H 3
#
# ('red{red,ADJ}',) a ('guy{guy,NOUN}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# guy{guy,NOUN}
# NOUN
# ('red{red,ADJ}',) a ('red{red,ADJ}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# red{red,ADJ}
# ADJ
# wup_sim: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 1.0
# path_sim: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 1.0
# spath: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 0
# lch: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 0.6931471805599453
# Sinonimo:  red red
# minimos hyper Synset('red.s.01')
# a->H 0
# b->H 0
#
# ('red{red,ADJ}',) a ('tie{tie,NOUN}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# tie{tie,NOUN}
# NOUN
# ('red{red,ADJ}',) a ('speech{speech,NOUN}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# speech{speech,NOUN}
# NOUN
# ('shirt{shirt,NOUN}',) a ('top{top,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 0.8
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 0.2
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 4
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 2.0281482472922856
# minimos hyper Synset('clothing.n.01')
# a->H 2
# b->H 2
#
# ('shirt{shirt,NOUN}',) a ('makes{make,VERB}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('black{black,ADJ}',) a ('tie{tie,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# tie{tie,NOUN}
# NOUN
# ('tie{tie,NOUN}',) a ('top{top,NOUN}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 0.7619047619047619
# path_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 0.16666666666666666
# spath: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 5
# lch: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 1.845826690498331
# minimos hyper Synset('clothing.n.01')
# a->H 3
# b->H 2
#
# ('tie{tie,NOUN}',) a ('makes{make,VERB}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('stands{stand,VERB}',) a ('top{top,NOUN}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# top{top,NOUN}
# NOUN
# ('stands{stand,VERB}',) a ('makes{make,VERB}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# makes{make,VERB}
# VERB
# wup_sim: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 0.5
# path_sim: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 0.2
# spath: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 4
# lch: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 1.6486586255873816
# minimos hyper Synset('evaluate.v.02')
# a->H 1
# b->H 3
#
# ('wedding{wedding,NOUN}',) a ('guy{guy,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.13333333333333333
# path_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.07142857142857142
# spath: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 13
# lch: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.9985288301111273
# minimos hyper Synset('entity.n.01')
# a->H 7
# b->H 6
#
# ('wedding{wedding,NOUN}',) a ('red{red,ADJ}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('wedding{wedding,NOUN}',) a ('tie{tie,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 0.5333333333333333
# path_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 0.125
# spath: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 7
# lch: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 1.55814461804655
# minimos hyper Synset('event.n.01')
# a->H 4
# b->H 3
#
# ('wedding{wedding,NOUN}',) a ('speech{speech,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 0.5882352941176471
# path_sim: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 0.125
# spath: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 7
# lch: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 1.55814461804655
# minimos hyper Synset('act.n.02')
# a->H 5
# b->H 2
#
# ('make{make,VERB}',) a ('guy{guy,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# guy{guy,NOUN}
# NOUN
# ('make{make,VERB}',) a ('red{red,ADJ}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# red{red,ADJ}
# ADJ
# ('make{make,VERB}',) a ('tie{tie,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# tie{tie,NOUN}
# NOUN
# ('make{make,VERB}',) a ('speech{speech,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# speech{speech,NOUN}
# NOUN
# ('speech{speech,NOUN}',) a ('guy{guy,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 0.16666666666666666
# path_sim: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 0.09090909090909091
# spath: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 10
# lch: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 1.2396908869280152
# minimos hyper Synset('entity.n.01')
# a->H 4
# b->H 6
#
# ('speech{speech,NOUN}',) a ('red{red,ADJ}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('speech{speech,NOUN}',) a ('tie{tie,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 0.5714285714285714
# path_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 0.14285714285714285
# spath: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 6
# lch: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 1.6916760106710724
# minimos hyper Synset('event.n.01')
# a->H 3
# b->H 3
#
# ('speech{speech,NOUN}',) a ('speech{speech,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 1.0
# path_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 1.0
# spath: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 0
# lch: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 3.6375861597263857
# Sinonimo:  speech speech
# minimos hyper Synset('address.n.03')
# a->H 0
# b->H 0
#
# sinonimos 2 [('red', 'red'), ('red', 'red'), ('speech', 'speech'), ('speech', 'speech')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 1 [('man', 'guy'), ('man', 'guy'), ('man', 'guy'), ('man', 'guy')]
# relaciones fuertes: [(Synset('man.n.01'), Synset('guy.n.01')), (Synset('man.n.10'), Synset('link.n.02')), (Synset('red.s.01'), Synset('red.s.01')), (Synset('shirt.n.01'), Synset('top.n.10')), (Synset('necktie.n.01'), Synset('top.n.10')), (Synset('wedding.n.01'), Synset('draw.n.03')), (Synset('marriage.n.03'), Synset('address.n.03')), (Synset('address.n.03'), Synset('draw.n.03')), (Synset('address.n.03'), Synset('address.n.03'))]
# verbos:  [('stands', 'makes', 0.5)]
# ('stands', 'makes', 0.5)
# semanticas [2, 0, 0, 1, 0.5]
# verbos a comparar dressed makes
# 2
# Texto:  A young boy runs across a road in front of a sky blue building with barred windows.
# Hipótesis:  A boy sleeps in his bed.
# 19 8
# [0.03495584 0.44087163 0.32060933 0.15039723 0.36782587 0.35962236
#  0.2560764 ]
# [(('young{young,ADJ}',), ('boy{boy,NOUN}',), 1.0000001), (('young{young,ADJ}',), ('sleeps{sleep,VERB}',), 0.36848196), (('young{young,ADJ}',), ('his{-PRON-,ADJ}',), 0.45452678), (('young{young,ADJ}',), ('bed{bed,NOUN}',), 0.50565207), (('boy{boy,NOUN}',), ('sleeps{sleep,VERB}',), 0.68476784), (('boy{boy,NOUN}',), ('bed{bed,NOUN}',), 0.44023618), (('runs{run,VERB}',), ('sleeps{sleep,VERB}',), 0.99999994), (('runs{run,VERB}',), ('bed{bed,NOUN}',), 0.5015302), (('road{road,NOUN}',), ('boy{boy,NOUN}',), 1.0000001), (('road{road,NOUN}',), ('sleeps{sleep,VERB}',), 0.36848196), (('road{road,NOUN}',), ('his{-PRON-,ADJ}',), 0.45452678), (('road{road,NOUN}',), ('bed{bed,NOUN}',), 0.50565207), (('front{front,NOUN}',), ('boy{boy,NOUN}',), 0.45452678), (('front{front,NOUN}',), ('his{-PRON-,ADJ}',), 0.9999998), (('front{front,NOUN}',), ('bed{bed,NOUN}',), 0.42408526), (('sky{sky,NOUN}',), ('boy{boy,NOUN}',), 1.0000001), (('sky{sky,NOUN}',), ('sleeps{sleep,VERB}',), 0.36848196), (('sky{sky,NOUN}',), ('his{-PRON-,ADJ}',), 0.45452678), (('sky{sky,NOUN}',), ('bed{bed,NOUN}',), 0.50565207), (('blue{blue,ADJ}',), ('sleeps{sleep,VERB}',), 0.3214898), (('building{building,NOUN}',), ('sleeps{sleep,VERB}',), 0.37765884), (('barred{barred,ADJ}',), ('boy{boy,NOUN}',), 0.55526817), (('barred{barred,ADJ}',), ('his{-PRON-,ADJ}',), 0.4616082), (('barred{barred,ADJ}',), ('bed{bed,NOUN}',), 0.49101645)]
# todas [(('young{young,ADJ}',), ('boy{boy,NOUN}',), 1.0000001), (('young{young,ADJ}',), ('sleeps{sleep,VERB}',), 0.36848196), (('young{young,ADJ}',), ('his{-PRON-,ADJ}',), 0.45452678), (('young{young,ADJ}',), ('bed{bed,NOUN}',), 0.50565207), (('boy{boy,NOUN}',), ('sleeps{sleep,VERB}',), 0.68476784), (('boy{boy,NOUN}',), ('bed{bed,NOUN}',), 0.44023618), (('runs{run,VERB}',), ('sleeps{sleep,VERB}',), 0.99999994), (('runs{run,VERB}',), ('bed{bed,NOUN}',), 0.5015302), (('road{road,NOUN}',), ('boy{boy,NOUN}',), 1.0000001), (('road{road,NOUN}',), ('sleeps{sleep,VERB}',), 0.36848196), (('road{road,NOUN}',), ('his{-PRON-,ADJ}',), 0.45452678), (('road{road,NOUN}',), ('bed{bed,NOUN}',), 0.50565207), (('front{front,NOUN}',), ('boy{boy,NOUN}',), 0.45452678), (('front{front,NOUN}',), ('his{-PRON-,ADJ}',), 0.9999998), (('front{front,NOUN}',), ('bed{bed,NOUN}',), 0.42408526), (('sky{sky,NOUN}',), ('boy{boy,NOUN}',), 1.0000001), (('sky{sky,NOUN}',), ('sleeps{sleep,VERB}',), 0.36848196), (('sky{sky,NOUN}',), ('his{-PRON-,ADJ}',), 0.45452678), (('sky{sky,NOUN}',), ('bed{bed,NOUN}',), 0.50565207), (('blue{blue,ADJ}',), ('sleeps{sleep,VERB}',), 0.3214898), (('building{building,NOUN}',), ('sleeps{sleep,VERB}',), 0.37765884), (('barred{barred,ADJ}',), ('boy{boy,NOUN}',), 0.55526817), (('barred{barred,ADJ}',), ('his{-PRON-,ADJ}',), 0.4616082), (('barred{barred,ADJ}',), ('bed{bed,NOUN}',), 0.49101645)]
# todas [(('boy{boy,NOUN}',), ('young{young,ADJ}',), 1.0000001), (('boy{boy,NOUN}',), ('boy{boy,NOUN}',), 0.3723686), (('boy{boy,NOUN}',), ('road{road,NOUN}',), 1.0000001), (('boy{boy,NOUN}',), ('front{front,NOUN}',), 0.45452678), (('boy{boy,NOUN}',), ('sky{sky,NOUN}',), 1.0000001), (('boy{boy,NOUN}',), ('blue{blue,ADJ}',), 0.24468647), (('boy{boy,NOUN}',), ('building{building,NOUN}',), 0.32184678), (('boy{boy,NOUN}',), ('barred{barred,ADJ}',), 0.55526817), (('boy{boy,NOUN}',), ('windows{window,NOUN}',), 0.17694958), (('sleeps{sleep,VERB}',), ('boy{boy,NOUN}',), 0.68476784), (('sleeps{sleep,VERB}',), ('runs{run,VERB}',), 0.99999994), (('sleeps{sleep,VERB}',), ('blue{blue,ADJ}',), 0.3214898), (('sleeps{sleep,VERB}',), ('building{building,NOUN}',), 0.37765884), (('sleeps{sleep,VERB}',), ('windows{window,NOUN}',), 0.18536794), (('his{-PRON-,ADJ}',), ('young{young,ADJ}',), 0.45452678), (('his{-PRON-,ADJ}',), ('road{road,NOUN}',), 0.45452678), (('his{-PRON-,ADJ}',), ('front{front,NOUN}',), 0.9999998), (('his{-PRON-,ADJ}',), ('sky{sky,NOUN}',), 0.45452678), (('his{-PRON-,ADJ}',), ('blue{blue,ADJ}',), 0.22955084), (('his{-PRON-,ADJ}',), ('building{building,NOUN}',), 0.26666278), (('his{-PRON-,ADJ}',), ('barred{barred,ADJ}',), 0.4616082), (('his{-PRON-,ADJ}',), ('windows{window,NOUN}',), 0.17080677), (('bed{bed,NOUN}',), ('young{young,ADJ}',), 0.50565207), (('bed{bed,NOUN}',), ('boy{boy,NOUN}',), 0.44023618), (('bed{bed,NOUN}',), ('runs{run,VERB}',), 0.5015302), (('bed{bed,NOUN}',), ('road{road,NOUN}',), 0.50565207), (('bed{bed,NOUN}',), ('front{front,NOUN}',), 0.42408526), (('bed{bed,NOUN}',), ('sky{sky,NOUN}',), 0.50565207), (('bed{bed,NOUN}',), ('blue{blue,ADJ}',), 0.28021634), (('bed{bed,NOUN}',), ('building{building,NOUN}',), 0.23733842), (('bed{bed,NOUN}',), ('barred{barred,ADJ}',), 0.49101645), (('bed{bed,NOUN}',), ('windows{window,NOUN}',), 0.24508734)]
# {'NOUN_NOUN': 4.330152601003647, 'NOUN_ADJ': 1.909053385257721, 'NOUN_VERB': 1.7993906140327454, 'NOUN_ADV': 0, 'ADJ_NOUN': 2.5519368052482605, 'ADJ_ADJ': 0.9161349833011627, 'ADJ_VERB': 0.6899717748165131, 'ADJ_ADV': 0, 'VERB_NOUN': 0.5015301704406738, 'VERB_ADJ': 0, 'VERB_VERB': 0.9999999403953552, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 24 32
# ('young{young,ADJ}',) a ('boy{boy,NOUN}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# boy{boy,NOUN}
# NOUN
# ('young{young,ADJ}',) a ('sleeps{sleep,VERB}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# sleeps{sleep,VERB}
# VERB
# ('young{young,ADJ}',) a ('his{-PRON-,ADJ}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# his{-PRON-,ADJ}
# ADJ
# ('young{young,ADJ}',) a ('bed{bed,NOUN}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# bed{bed,NOUN}
# NOUN
# ('boy{boy,NOUN}',) a ('sleeps{sleep,VERB}',)
# boy{boy,NOUN}
# ['boy{boy', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('boy{boy,NOUN}',) a ('bed{bed,NOUN}',)
# boy{boy,NOUN}
# ['boy{boy', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('layer.n.01') 0.5333333333333333
# path_sim: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('layer.n.01') 0.125
# spath: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('layer.n.01') 7
# lch: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('layer.n.01') 1.55814461804655
# minimos hyper Synset('whole.n.02')
# a->H 5
# b->H 2
#
# ('runs{run,VERB}',) a ('sleeps{sleep,VERB}',)
# runs{run,VERB}
# ['runs{run', 'VERB']
# VERB
# sleeps{sleep,VERB}
# VERB
# wup_sim: Palabra1:  Synset('function.v.01') Palabra2: Synset('sleep.v.02') 0.4
# lch: Palabra1:  Synset('function.v.01') Palabra2: Synset('sleep.v.02') 1.8718021769015913
#
# ('runs{run,VERB}',) a ('bed{bed,NOUN}',)
# runs{run,VERB}
# ['runs{run', 'VERB']
# VERB
# bed{bed,NOUN}
# NOUN
# ('road{road,NOUN}',) a ('boy{boy,NOUN}',)
# road{road,NOUN}
# ['road{road', 'NOUN']
# NOUN
# boy{boy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('male_child.n.01') 0.5
# path_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('male_child.n.01') 0.1111111111111111
# spath: Palabra1:  Synset('road.n.01') Palabra2: Synset('male_child.n.01') 8
# lch: Palabra1:  Synset('road.n.01') Palabra2: Synset('male_child.n.01') 1.4403615823901665
# minimos hyper Synset('whole.n.02')
# a->H 3
# b->H 5
#
# ('road{road,NOUN}',) a ('sleeps{sleep,VERB}',)
# road{road,NOUN}
# ['road{road', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('road{road,NOUN}',) a ('his{-PRON-,ADJ}',)
# road{road,NOUN}
# ['road{road', 'NOUN']
# NOUN
# his{-PRON-,ADJ}
# ADJ
# ('road{road,NOUN}',) a ('bed{bed,NOUN}',)
# road{road,NOUN}
# ['road{road', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 0.7692307692307693
# path_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 0.25
# spath: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 3
# lch: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 2.2512917986064953
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 1
#
# ('front{front,NOUN}',) a ('boy{boy,NOUN}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# boy{boy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('front_man.n.01') Palabra2: Synset('male_child.n.01') 0.6
# path_sim: Palabra1:  Synset('front_man.n.01') Palabra2: Synset('male_child.n.01') 0.14285714285714285
# spath: Palabra1:  Synset('front_man.n.01') Palabra2: Synset('male_child.n.01') 6
# lch: Palabra1:  Synset('front_man.n.01') Palabra2: Synset('male_child.n.01') 1.6916760106710724
# minimos hyper Synset('person.n.01')
# a->H 4
# b->H 2
#
# ('front{front,NOUN}',) a ('his{-PRON-,ADJ}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# his{-PRON-,ADJ}
# ADJ
# ('front{front,NOUN}',) a ('bed{bed,NOUN}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 0.8
# path_sim: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 0.25
# spath: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 3
# lch: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 2.2512917986064953
# minimos hyper Synset('surface.n.01')
# a->H 2
# b->H 1
#
# ('sky{sky,NOUN}',) a ('boy{boy,NOUN}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# boy{boy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('male_child.n.01') 0.3076923076923077
# path_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('male_child.n.01') 0.1
# spath: Palabra1:  Synset('sky.n.01') Palabra2: Synset('male_child.n.01') 9
# lch: Palabra1:  Synset('sky.n.01') Palabra2: Synset('male_child.n.01') 1.3350010667323402
# minimos hyper Synset('physical_entity.n.01')
# a->H 5
# b->H 4
#
# ('sky{sky,NOUN}',) a ('sleeps{sleep,VERB}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('sky{sky,NOUN}',) a ('his{-PRON-,ADJ}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# his{-PRON-,ADJ}
# ADJ
# ('sky{sky,NOUN}',) a ('bed{bed,NOUN}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 0.3076923076923077
# path_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 0.1
# spath: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 9
# lch: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 1.3350010667323402
# minimos hyper Synset('physical_entity.n.01')
# a->H 5
# b->H 4
#
# ('blue{blue,ADJ}',) a ('sleeps{sleep,VERB}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# sleeps{sleep,VERB}
# VERB
# ('building{building,NOUN}',) a ('sleeps{sleep,VERB}',)
# building{building,NOUN}
# ['building{building', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('barred{barred,ADJ}',) a ('boy{boy,NOUN}',)
# barred{barred,ADJ}
# ['barred{barred', 'ADJ']
# ADJ
# boy{boy,NOUN}
# NOUN
# ('barred{barred,ADJ}',) a ('his{-PRON-,ADJ}',)
# barred{barred,ADJ}
# ['barred{barred', 'ADJ']
# ADJ
# his{-PRON-,ADJ}
# ...
# semanticas [2, 0, 0, 0, 1.0]
# verbos a comparar are are
# 99
# Texto:  Three men dressed in suits and ties clasps their raised hands while standing in front of corporate logos.
# Hipótesis:  One of the men is actually sasquatch.
# 20 9
# [-0.00469077  0.41139933  0.36551768  0.39241597  0.34750977  0.30306828
#   0.3428001  -0.01394199]
# [(('men{man,NOUN}',), ('men{man,NOUN}',), 0.5351101), (('men{man,NOUN}',), ('is{be,VERB}',), 0.41881067), (('men{man,NOUN}',), ('actually{actually,ADV}',), 0.34809768), (('men{man,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.41130537), (('dressed{dress,VERB}',), ('is{be,VERB}',), 0.9999998), (('dressed{dress,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.364623), (('suits{suit,NOUN}',), ('men{man,NOUN}',), 0.5554858), (('suits{suit,NOUN}',), ('actually{actually,ADV}',), 0.4214694), (('suits{suit,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.36369997), (('ties{tie,NOUN}',), ('men{man,NOUN}',), 0.56248724), (('ties{tie,NOUN}',), ('is{be,VERB}',), 0.3509324), (('ties{tie,NOUN}',), ('actually{actually,ADV}',), 0.4581477), (('ties{tie,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.4433461), (('clasps{clasp,VERB}',), ('is{be,VERB}',), 0.35461178), (('raised{raise,VERB}',), ('men{man,NOUN}',), 0.6357572), (('raised{raise,VERB}',), ('is{be,VERB}',), 0.434092), (('raised{raise,VERB}',), ('actually{actually,ADV}',), 0.32328144), (('raised{raise,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.4645494), (('hands{hand,NOUN}',), ('actually{actually,ADV}',), 0.3795172), (('hands{hand,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.40918624), (('standing{stand,VERB}',), ('men{man,NOUN}',), 0.529183), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.40925655), (('standing{stand,VERB}',), ('actually{actually,ADV}',), 0.48807302), (('standing{stand,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.5936109), (('front{front,NOUN}',), ('men{man,NOUN}',), 0.5554858), (('front{front,NOUN}',), ('actually{actually,ADV}',), 0.4214694), (('front{front,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.36369997), (('corporate{corporate,ADJ}',), ('men{man,NOUN}',), 0.7139387), (('corporate{corporate,ADJ}',), ('actually{actually,ADV}',), 0.47661063), (('corporate{corporate,ADJ}',), ('sasquatch{sasquatch,NOUN}',), 0.34464937)]
# todas [(('men{man,NOUN}',), ('men{man,NOUN}',), 0.5351101), (('men{man,NOUN}',), ('is{be,VERB}',), 0.41881067), (('men{man,NOUN}',), ('actually{actually,ADV}',), 0.34809768), (('men{man,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.41130537), (('dressed{dress,VERB}',), ('is{be,VERB}',), 0.9999998), (('dressed{dress,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.364623), (('suits{suit,NOUN}',), ('men{man,NOUN}',), 0.5554858), (('suits{suit,NOUN}',), ('actually{actually,ADV}',), 0.4214694), (('suits{suit,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.36369997), (('ties{tie,NOUN}',), ('men{man,NOUN}',), 0.56248724), (('ties{tie,NOUN}',), ('is{be,VERB}',), 0.3509324), (('ties{tie,NOUN}',), ('actually{actually,ADV}',), 0.4581477), (('ties{tie,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.4433461), (('clasps{clasp,VERB}',), ('is{be,VERB}',), 0.35461178), (('raised{raise,VERB}',), ('men{man,NOUN}',), 0.6357572), (('raised{raise,VERB}',), ('is{be,VERB}',), 0.434092), (('raised{raise,VERB}',), ('actually{actually,ADV}',), 0.32328144), (('raised{raise,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.4645494), (('hands{hand,NOUN}',), ('actually{actually,ADV}',), 0.3795172), (('hands{hand,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.40918624), (('standing{stand,VERB}',), ('men{man,NOUN}',), 0.529183), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.40925655), (('standing{stand,VERB}',), ('actually{actually,ADV}',), 0.48807302), (('standing{stand,VERB}',), ('sasquatch{sasquatch,NOUN}',), 0.5936109), (('front{front,NOUN}',), ('men{man,NOUN}',), 0.5554858), (('front{front,NOUN}',), ('actually{actually,ADV}',), 0.4214694), (('front{front,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 0.36369997), (('corporate{corporate,ADJ}',), ('men{man,NOUN}',), 0.7139387), (('corporate{corporate,ADJ}',), ('actually{actually,ADV}',), 0.47661063), (('corporate{corporate,ADJ}',), ('sasquatch{sasquatch,NOUN}',), 0.34464937)]
# todas [(('men{man,NOUN}',), ('men{man,NOUN}',), 0.5351101), (('men{man,NOUN}',), ('suits{suit,NOUN}',), 0.5554858), (('men{man,NOUN}',), ('ties{tie,NOUN}',), 0.56248724), (('men{man,NOUN}',), ('clasps{clasp,VERB}',), 0.26699007), (('men{man,NOUN}',), ('raised{raise,VERB}',), 0.6357572), (('men{man,NOUN}',), ('hands{hand,NOUN}',), 0.39200774), (('men{man,NOUN}',), ('standing{stand,VERB}',), 0.529183), (('men{man,NOUN}',), ('front{front,NOUN}',), 0.5554858), (('men{man,NOUN}',), ('corporate{corporate,ADJ}',), 0.7139387), (('men{man,NOUN}',), ('logos{logo,NOUN}',), 0.3265997), (('is{be,VERB}',), ('men{man,NOUN}',), 0.41881067), (('is{be,VERB}',), ('dressed{dress,VERB}',), 0.9999998), (('is{be,VERB}',), ('suits{suit,NOUN}',), 0.34473705), (('is{be,VERB}',), ('ties{tie,NOUN}',), 0.3509324), (('is{be,VERB}',), ('clasps{clasp,VERB}',), 0.35461178), (('is{be,VERB}',), ('their{-PRON-,ADJ}',), 0.09946774), (('is{be,VERB}',), ('raised{raise,VERB}',), 0.434092), (('is{be,VERB}',), ('hands{hand,NOUN}',), 0.29764256), (('is{be,VERB}',), ('standing{stand,VERB}',), 0.40925655), (('is{be,VERB}',), ('front{front,NOUN}',), 0.34473705), (('actually{actually,ADV}',), ('men{man,NOUN}',), 0.34809768), (('actually{actually,ADV}',), ('suits{suit,NOUN}',), 0.4214694), (('actually{actually,ADV}',), ('ties{tie,NOUN}',), 0.4581477), (('actually{actually,ADV}',), ('hands{hand,NOUN}',), 0.3795172), (('actually{actually,ADV}',), ('standing{stand,VERB}',), 0.48807302), (('actually{actually,ADV}',), ('front{front,NOUN}',), 0.4214694), (('actually{actually,ADV}',), ('corporate{corporate,ADJ}',), 0.47661063), (('actually{actually,ADV}',), ('logos{logo,NOUN}',), 0.2812865), (('sasquatch{sasquatch,NOUN}',), ('men{man,NOUN}',), 0.41130537), (('sasquatch{sasquatch,NOUN}',), ('dressed{dress,VERB}',), 0.364623), (('sasquatch{sasquatch,NOUN}',), ('suits{suit,NOUN}',), 0.36369997), (('sasquatch{sasquatch,NOUN}',), ('ties{tie,NOUN}',), 0.4433461), (('sasquatch{sasquatch,NOUN}',), ('clasps{clasp,VERB}',), 0.27739987), (('sasquatch{sasquatch,NOUN}',), ('raised{raise,VERB}',), 0.4645494), (('sasquatch{sasquatch,NOUN}',), ('hands{hand,NOUN}',), 0.40918624), (('sasquatch{sasquatch,NOUN}',), ('standing{stand,VERB}',), 0.5936109), (('sasquatch{sasquatch,NOUN}',), ('front{front,NOUN}',), 0.36369997), (('sasquatch{sasquatch,NOUN}',), ('logos{logo,NOUN}',), 0.266992)]
# {'NOUN_NOUN': 4.199806600809097, 'NOUN_ADJ': 0, 'NOUN_VERB': 0.7697430551052094, 'NOUN_ADV': 2.028701364994049, 'ADJ_NOUN': 1.0585880875587463, 'ADJ_ADJ': 0, 'ADJ_VERB': 0, 'ADJ_ADV': 0.47661063075065613, 'VERB_NOUN': 2.5877234637737274, 'VERB_ADJ': 0, 'VERB_VERB': 2.197960138320923, 'VERB_ADV': 0.8113544583320618, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 30 38
# ('men{man,NOUN}',) a ('men{man,NOUN}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 1.0
# path_sim: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 1.0
# spath: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 0
# lch: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 3.6375861597263857
# Sinonimo:  men men
# minimos hyper Synset('work_force.n.01')
# a->H 0
# b->H 0
#
# ('men{man,NOUN}',) a ('is{be,VERB}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# is{be,VERB}
# VERB
# ('men{man,NOUN}',) a ('actually{actually,ADV}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('men{man,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 0.25
# path_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 12
# lch: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 1.072636802264849
# minimos hyper Synset('abstraction.n.06')
# a->H 2
# b->H 10
#
# ('dressed{dress,VERB}',) a ('is{be,VERB}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('dress.v.01') Palabra2: Synset('be.v.01') 0.4
# lch: Palabra1:  Synset('dress.v.01') Palabra2: Synset('be.v.01') 1.8718021769015913
#
# ('dressed{dress,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('suits{suit,NOUN}',) a ('men{man,NOUN}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 0.631578947368421
# path_sim: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 0.16666666666666666
# spath: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 5
# lch: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 1.845826690498331
# minimos hyper Synset('person.n.01')
# a->H 4
# b->H 1
#
# ('suits{suit,NOUN}',) a ('actually{actually,ADV}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('suits{suit,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.3
# path_sim: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.06666666666666667
# spath: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 14
# lch: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.9295359586241757
# minimos hyper Synset('psychological_feature.n.01')
# a->H 5
# b->H 9
#
# ('ties{tie,NOUN}',) a ('men{man,NOUN}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 0.631578947368421
# path_sim: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 0.125
# spath: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 7
# lch: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 1.55814461804655
# minimos hyper Synset('instrumentality.n.03')
# a->H 4
# b->H 3
#
# ('ties{tie,NOUN}',) a ('is{be,VERB}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# is{be,VERB}
# VERB
# ('ties{tie,NOUN}',) a ('actually{actually,ADV}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('ties{tie,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.3157894736842105
# path_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.07142857142857142
# spath: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 13
# lch: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.9985288301111273
# minimos hyper Synset('psychological_feature.n.01')
# a->H 4
# b->H 9
#
# ('clasps{clasp,VERB}',) a ('is{be,VERB}',)
# clasps{clasp,VERB}
# ['clasps{clasp', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('clasp.v.01') Palabra2: Synset('be.v.01') 0.3333333333333333
# lch: Palabra1:  Synset('clasp.v.01') Palabra2: Synset('be.v.01') 1.6486586255873816
#
# ('raised{raise,VERB}',) a ('men{man,NOUN}',)
# raised{raise,VERB}
# ['raised{raise', 'VERB']
# VERB
# men{man,NOUN}
# NOUN
# ('raised{raise,VERB}',) a ('is{be,VERB}',)
# raised{raise,VERB}
# ['raised{raise', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('raise.v.24') Palabra2: Synset('embody.v.02') 0.6666666666666666
# path_sim: Palabra1:  Synset('raise.v.24') Palabra2: Synset('embody.v.02') 0.125
# spath: Palabra1:  Synset('raise.v.24') Palabra2: Synset('embody.v.02') 7
# lch: Palabra1:  Synset('raise.v.24') Palabra2: Synset('embody.v.02') 1.1786549963416462
# minimos hyper Synset('convey.v.01')
# a->H 4
# b->H 3
#
# ('raised{raise,VERB}',) a ('actually{actually,ADV}',)
# raised{raise,VERB}
# ['raised{raise', 'VERB']
# VERB
# actually{actually,ADV}
# ADV
# ('raised{raise,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# raised{raise,VERB}
# ['raised{raise', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('hands{hand,NOUN}',) a ('actually{actually,ADV}',)
# hands{hand,NOUN}
# ['hands{hand', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('hands{hand,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# hands{hand,NOUN}
# ['hands{hand', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('hand.n.04') Palabra2: Synset('bigfoot.n.01') 0.5555555555555556
# path_sim: Palabra1:  Synset('hand.n.04') Palabra2: Synset('bigfoot.n.01') 0.1111111111111111
# spath: Palabra1:  Synset('hand.n.04') Palabra2: Synset('bigfoot.n.01') 8
# lch: Palabra1:  Synset('hand.n.04') Palabra2: Synset('bigfoot.n.01') 1.4403615823901665
# minimos hyper Synset('ability.n.02')
# a->H 1
# b->H 7
#
# ('standing{stand,VERB}',) a ('men{man,NOUN}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# men{man,NOUN}
# NOUN
# ('standing{stand,VERB}',) a ('is{be,VERB}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 0.6666666666666666
# path_sim: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 0.3333333333333333
# spath: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 2
# lch: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 2.159484249353372
# minimos hyper Synset('stay.v.01')
# a->H 1
# b->H 1
#
# ('standing{stand,VERB}',) a ('actually{actually,ADV}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# actually{actually,ADV}
# ADV
# ('standing{stand,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('front{front,NOUN}',) a ('men{man,NOUN}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('movement.n.04') Palabra2: Synset('work_force.n.01') 0.6666666666666666
# path_sim: Palabra1:  Synset('movement.n.04') Palabra2: Synset('work_force.n.01') 0.2
# spath: Palabra1:  Synset('movement.n.04') Palabra2: Synset('work_force.n.01') 4
# lch: Palabra1:  Synset('movement.n.04') Palabra2: Synset('work_force.n.01') 2.0281482472922856
# minimos hyper Synset('social_group.n.01')
# a->H 1
# b->H 3
#
# ('front{front,NOUN}',) a ('actually{actually,ADV}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('front{front,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('front.n.03') Palabra2: Synset('bigfoot.n.01') 0.4
# path_sim: Palabra1:  Synset('front.n.03') Palabra2: Synset('bigfoot.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('front.n.03') Palabra2: Synset('bigfoot.n.01') 12
# lch: Palabra1:  Synset('front.n.03') Palabra2: Synset('bigfoot.n.01') 1.072636802264849
# minimos hyper Synset('cognition.n.01')
# a->H 4
# b->H 8
#
# ('corporate{corporate,ADJ}',) a ('men{man,NOUN}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# men{man,NOUN}
# NOUN
# ('corporate{corporate,ADJ}',) a ('actually{actually,ADV}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# actually{actually,ADV}
# ADV
# ('corporate{corporate,ADJ}',) a ('sasquatch{sasquatch,NOUN}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# sasquatch{sasquatch,NOUN}
# NOUN
# sinonimos 1 [('men', 'men'), ('men', 'men')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 0 []
# relaciones fuertes: [(Synset('work_force.n.01'), Synset('work_force.n.01')), (Synset('suit.n.03'), Synset('man.n.03')), (Synset('link.n.02'), Synset('man.n.10')), (Synset('raise.v.24'), Synset('embody.v.02')), (Synset('stand.v.07'), Synset('be.v.12')), (Synset('movement.n.04'), Synset('work_force.n.01'))]
# verbos:  [('dressed', 'is', 0.4), ('clasps', 'is', 0.3333333333333333), ('raised', 'is', 0.6666666666666666), ('standing', 'is', 0.6666666666666666)]
# ('dressed', 'is', 0.4)
# ('clasps', 'is', 0.3333333333333333)
# ('raised', 'is', 0.6666666666666666)
# ('standing', 'is', 0.6666666666666666)
# semanticas [1, 0, 0, 0, 0.6666666666666666]
# verbos a comparar dressed is

# %%
df1 = pd.DataFrame(features, columns=list(todas_relaciones)+list(todos_conteos)+["sinonimos","antonimos","hiperonimos","hiponimos","action_wn","sim verbos","cantidad"])#+list(todas_relacionesT))#,"similaridad_1_2","dif"])
df1
# Out:
#     NOUN_NOUN  NOUN_ADJ  NOUN_VERB  NOUN_ADV  ADJ_NOUN   ADJ_ADJ  ADJ_VERB  \
# 0    8.401281  1.363580   1.149031  0.000000  2.325113  0.454527  0.259114
# 1    8.937979  3.000001   0.820234  0.000000  3.399397  1.000000  0.000000
# 2    4.330153  1.909053   1.799391  0.000000  2.551937  0.916135  0.689972
# 3    0.028963  0.000000   2.676887  0.000000  0.031668  0.000000  0.636757
# 4    3.277409  0.000000   2.061038  0.000000  1.638705  0.000000  1.030519
# ..        ...       ...        ...       ...       ...       ...       ...
# 95   6.566009  1.451477   0.766031  1.412246  2.260360  1.476667  0.357769
# 96   0.415148  0.000000   0.439552  0.000000  0.415147  0.000000  0.439552
# 97   4.000000  0.000000   0.873123  0.000000  0.000000  0.000000  0.000000
# 98   1.729706  0.000000   1.423062  0.000000  0.000000  0.000000  0.000000
# 99   4.199807  0.000000   0.769743  2.028701  1.058588  0.000000  0.000000
#
#      ADJ_ADV  VERB_NOUN  VERB_ADJ  ...  ADV_ADJ_  ADV_VERB_  ADV_ADV_  \
# 0   0.000000   3.174574  0.782569  ...         0          0         0
# 1   0.000000   2.002434  0.505892  ...         0          0         0
# 2   0.000000   0.501530  0.000000  ...         0          0         0
# 3   0.000000   0.119323  0.000000  ...         0          0         0
# 4   0.000000   0.000000  0.000000  ...         0          0         0
# ..       ...        ...       ...  ...       ...        ...       ...
# 95  0.739719   0.000000  0.000000  ...         0          0         0
# 96  0.000000   0.000000  0.000000  ...         0          0         0
# 97  0.000000   2.000000  0.000000  ...         0          0         0
# 98  0.000000   0.861428  0.000000  ...         0          0         0
# 99  0.476611   2.587723  0.000000  ...         0          0         0
#
#     sinonimos  antonimos  hiperonimos  hiponimos  action_wn  sim verbos  \
# 0           0          0            2          3   0.800000    0.233037
# 1           2          0            0          1   0.500000    0.203438
# 2           0          0            0          0   0.400000    0.360803
# 3           2          0            0          1   1.000000    0.252164
# 4           2          0            0          0   0.000000    0.347747
# ..        ...        ...          ...        ...        ...         ...
# 95          1          0            0          2   1.000000    0.236915
# 96          1          0            0          1   1.000000    0.895790
# 97          0          0            0          0   0.400000    0.245138
# 98          2          0            0          0   1.000000    1.000000
# 99          1          0            0          0   0.666667    0.234838
#
#      cantidad
# 0   25.631991
# 1   43.358374
# 2   13.512509
# 3    2.416415
# 4   23.910294
# ..        ...
# 95  22.056425
# 96   2.617666
# 97  10.912521
# 98  11.189399
# 99  17.152626
#
# [100 rows x 39 columns]

# %%
gold_label=prueba.gold_label.values
gold_label
# Out:
# array(['entailment', 'entailment', 'contradiction', 'contradiction',
#        'neutral', 'neutral', 'neutral', 'entailment', 'neutral',
#        'entailment', 'neutral', 'contradiction', 'entailment',
#        'contradiction', 'neutral', 'neutral', 'entailment',
#        'contradiction', 'contradiction', 'entailment', 'entailment',
#        'entailment', 'neutral', 'contradiction', 'entailment', 'neutral',
#        'entailment', 'entailment', 'entailment', 'neutral', 'neutral',
#        'contradiction', 'contradiction', 'entailment', 'contradiction',
#        'neutral', 'entailment', 'neutral', 'neutral', 'entailment',
#        'neutral', 'neutral', 'contradiction', 'neutral', 'entailment',
#        'neutral', 'neutral', 'entailment', 'contradiction', 'neutral',
#        'entailment', 'entailment', 'neutral', 'entailment',
#        'contradiction', 'entailment', 'entailment', 'neutral', 'neutral',
#        'neutral', 'neutral', 'neutral', 'neutral', 'entailment',
#        'entailment', 'contradiction', 'entailment', 'entailment',
#        'neutral', 'contradiction', 'entailment', 'contradiction',
#        'contradiction', 'contradiction', 'neutral', 'entailment',
#        'entailment', 'entailment', 'entailment', 'contradiction',
#        'neutral', 'entailment', 'entailment', 'entailment',
#        'contradiction', 'entailment', 'entailment', 'entailment',
#        'contradiction', 'contradiction', 'contradiction', 'neutral',
#        'entailment', 'entailment', 'contradiction', 'entailment',
#        'entailment', 'contradiction', 'contradiction', 'contradiction'],
#       dtype=object)

# %%
df1["CLASS"]=gold_label

# %%
df1
# Out:
#     NOUN_NOUN  NOUN_ADJ  NOUN_VERB  NOUN_ADV  ADJ_NOUN   ADJ_ADJ  ADJ_VERB  \
# 0    8.401281  1.363580   1.149031  0.000000  2.325113  0.454527  0.259114
# 1    8.937979  3.000001   0.820234  0.000000  3.399397  1.000000  0.000000
# 2    4.330153  1.909053   1.799391  0.000000  2.551937  0.916135  0.689972
# 3    0.028963  0.000000   2.676887  0.000000  0.031668  0.000000  0.636757
# 4    3.277409  0.000000   2.061038  0.000000  1.638705  0.000000  1.030519
# ..        ...       ...        ...       ...       ...       ...       ...
# 95   6.566009  1.451477   0.766031  1.412246  2.260360  1.476667  0.357769
# 96   0.415148  0.000000   0.439552  0.000000  0.415147  0.000000  0.439552
# 97   4.000000  0.000000   0.873123  0.000000  0.000000  0.000000  0.000000
# 98   1.729706  0.000000   1.423062  0.000000  0.000000  0.000000  0.000000
# 99   4.199807  0.000000   0.769743  2.028701  1.058588  0.000000  0.000000
#
#      ADJ_ADV  VERB_NOUN  VERB_ADJ  ...  ADV_VERB_  ADV_ADV_  sinonimos  \
# 0   0.000000   3.174574  0.782569  ...          0         0          0
# 1   0.000000   2.002434  0.505892  ...          0         0          2
# 2   0.000000   0.501530  0.000000  ...          0         0          0
# 3   0.000000   0.119323  0.000000  ...          0         0          2
# 4   0.000000   0.000000  0.000000  ...          0         0          2
# ..       ...        ...       ...  ...        ...       ...        ...
# 95  0.739719   0.000000  0.000000  ...          0         0          1
# 96  0.000000   0.000000  0.000000  ...          0         0          1
# 97  0.000000   2.000000  0.000000  ...          0         0          0
# 98  0.000000   0.861428  0.000000  ...          0         0          2
# 99  0.476611   2.587723  0.000000  ...          0         0          1
#
#     antonimos  hiperonimos  hiponimos  action_wn  sim verbos   cantidad  \
# 0           0            2          3   0.800000    0.233037  25.631991
# 1           0            0          1   0.500000    0.203438  43.358374
# 2           0            0          0   0.400000    0.360803  13.512509
# 3           0            0          1   1.000000    0.252164   2.416415
# 4           0            0          0   0.000000    0.347747  23.910294
# ..        ...          ...        ...        ...         ...        ...
# 95          0            0          2   1.000000    0.236915  22.056425
# 96          0            0          1   1.000000    0.895790   2.617666
# 97          0            0          0   0.400000    0.245138  10.912521
# 98          0            0          0   1.000000    1.000000  11.189399
# 99          0            0          0   0.666667    0.234838  17.152626
#
#             CLASS
# 0      entailment
# 1      entailment
# 2   contradiction
# 3   contradiction
# 4         neutral
# ..            ...
# 95     entailment
# 96     entailment
# 97  contradiction
# 98  contradiction
# 99  contradiction
#
# [100 rows x 40 columns]

# %%
#df1.to_csv("TipoPalabra_conteos_umbral_mean.csv")
#df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_root_difTH_porcentajeR_2.csv")
#df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_root_difTH_porcentajeR_3.csv",index=False)
df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_root_difTH_porcentajeR_MAspromedioMAX.csv",index=False)

# %%
df1.columns
# Out:
# Index(['NOUN_NOUN', 'NOUN_ADJ', 'NOUN_VERB', 'NOUN_ADV', 'ADJ_NOUN', 'ADJ_ADJ',
#        'ADJ_VERB', 'ADJ_ADV', 'VERB_NOUN', 'VERB_ADJ', 'VERB_VERB', 'VERB_ADV',
#        'ADV_NOUN', 'ADV_ADJ', 'ADV_VERB', 'ADV_ADV', 'NOUN_NOUN_', 'NOUN_ADJ_',
#        'NOUN_VERB_', 'NOUN_ADV_', 'ADJ_NOUN_', 'ADJ_ADJ_', 'ADJ_VERB_',
#        'ADJ_ADV_', 'VERB_NOUN_', 'VERB_ADJ_', 'VERB_VERB_', 'VERB_ADV_',
#        'ADV_NOUN_', 'ADV_ADJ_', 'ADV_VERB_', 'ADV_ADV_', 'sinonimos',
#        'antonimos', 'hiperonimos', 'hiponimos', 'action_wn', 'sim verbos',
#        'cantidad', 'CLASS'],
#       dtype='object')

# %%
a=list(todas_relaciones)
a
# Out:
# ['NOUN_NOUN',
#  'NOUN_ADJ',
#  'NOUN_VERB',
#  'NOUN_ADV',
#  'ADJ_NOUN',
#  'ADJ_ADJ',
#  'ADJ_VERB',
#  'ADJ_ADV',
#  'VERB_NOUN',
#  'VERB_ADJ',
#  'VERB_VERB',
#  'VERB_ADV',
#  'ADV_NOUN',
#  'ADV_ADJ',
#  'ADV_VERB',
#  'ADV_ADV']
