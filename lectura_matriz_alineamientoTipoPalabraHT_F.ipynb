# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Lectura de matriz de alineamiento

# %%
df = pd.read_pickle("data/prueba100.pickle")
df
# Out:
#     Main index                                               Text  \
# 0            0  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, we...
# 1            1  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, dr...
# 2            2  [NULL{null,PROPN}, a{a,DET}, young{young,ADJ},...
# 3            3  [NULL{null,NOUN}, an{an,DET}, asian{asian,ADJ}...
# 4            4  [NULL{null,PROPN}, a{a,DET}, child{child,NOUN}...
# ..         ...                                                ...
# 95          95  [NULL{null,PROPN}, a{a,DET}, group{group,NOUN}...
# 96          96  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 97          97  [NULL{null,PROPN}, a{a,DET}, skateboarding{ska...
# 98          98  [NULL{null,ADJ}, four{four,NUM}, children{chil...
# 99          99  [NULL{null,ADJ}, three{three,NUM}, men{man,NOU...
#
#                                             Hipotesis  \
# 0   [NULL{null,PROPN}, a{a,DET}, person{person,NOU...
# 1   [NULL{null,PROPN}, a{a,DET}, guy{guy,NOUN}, in...
# 2   [NULL{null,PROPN}, a{a,DET}, boy{boy,NOUN}, sl...
# 3   [NULL{null,PROPN}, nobody{nobody,NOUN}, is{be,...
# 4   [NULL{null,PROPN}, the{the,DET}, child{child,N...
# ..                                                ...
# 95  [NULL{null,PROPN}, a{a,DET}, bunch{bunch,NOUN}...
# 96  [NULL{null,ADJ}, woman{woman,NOUN}, holds{hold...
# 97  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, pa...
# 98  [NULL{null,PROPN}, the{the,DET}, children{chil...
# 99  [NULL{null,ADJ}, one{one,NUM}, of{of,ADP}, the...
#
#                                                R_Text  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                                 R_Hip  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                               M_Align  \
# 0   [[2.760008, 0.060492776, 0.7027438, 0.20296031...
# 1   [[2.760008, 0.060492776, 0.64837056, 0.2029603...
# 2   [[2.760008, 0.060492776, 0.4078711, 2.2245083,...
# 3   [[2.760008, 1.9305927, 0.10360007, 0.8346571, ...
# 4   [[2.760008, 0.033035405, 0.5160244, 0.10360007...
# ..                                                ...
# 95  [[2.760008, 0.060492776, 0.41359743, 0.0717519...
# 96  [[2.760008, 0.475788, 0.8695118, 0.72379255, 0...
# 97  [[2.760008, 0.060492776, 0.43997452, 1.9583746...
# 98  [[2.760008, 0.033035405, 0.44769567, 0.0726737...
# 99  [[2.760008, 0.38066497, 0.07175191, 0.03303540...
#
#                                   Prediction       Gold_label
# 0      [0.4928643, 0.50155383, 0.0055818837]  [1.0, 0.0, 0.0]
# 1         [0.4695498, 0.3973312, 0.13311893]  [1.0, 0.0, 0.0]
# 2   [1.4341879e-06, 8.787866e-05, 0.9999107]  [0.0, 0.0, 1.0]
# 3      [0.033964496, 0.008023773, 0.9580117]  [0.0, 0.0, 1.0]
# 4    [0.0027733932, 0.9895504, 0.0076761814]  [0.0, 1.0, 0.0]
# ..                                       ...              ...
# 95      [0.8000752, 0.17865694, 0.021267932]  [1.0, 0.0, 0.0]
# 96       [0.7528739, 0.18234292, 0.06478321]  [1.0, 0.0, 0.0]
# 97  [7.513892e-05, 0.0013085654, 0.99861634]  [0.0, 0.0, 1.0]
# 98     [0.034316223, 0.83774996, 0.12793382]  [0.0, 0.0, 1.0]
# 99     [0.0035314807, 0.5047337, 0.49173486]  [0.0, 0.0, 1.0]
#
# [100 rows x 8 columns]

# %%
indice=3

# %%
t=pd.DataFrame(df.at[indice,"Text"][1:])
h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
print(len(t))
print(len(h))
# Out:
# 25
# 3

# %%
ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
ma
# Out:
#                          (nobody{nobody,NOUN},)  (is{be,VERB},)  \
# (an{an,DET},)                          0.176704        0.006358
# (asian{asian,ADJ},)                    1.327478        0.041788
# (woman{woman,NOUN},)                   1.954267        0.019285
# (is{be,VERB},)                         0.253317        0.048234
# (standing{stand,VERB},)                1.613250        0.164248
# (on{on,ADP},)                          0.714248        0.070056
# (a{a,DET},)                            0.125491        0.014831
# (path{path,NOUN},)                     0.733210        0.036198
# (with{with,ADP},)                      0.056232        0.002411
# (a{a,DET},)                            0.125491        0.014831
# (basket{basket,NOUN},)                 0.564102        0.036891
# (on{on,ADP},)                          0.714248        0.070056
# (her{-PRON-,ADJ},)                     1.292833        0.017458
# (head{head,NOUN},)                     0.633590        0.044523
# (looking{look,VERB},)                  1.630809        0.121954
# (into{into,ADP},)                      0.351760        0.021666
# (a{a,DET},)                            0.125491        0.014831
# (mirror{mirror,NOUN},)                 2.424366        0.098696
# (she{-PRON-,PRON},)                    1.841595        0.041299
# (is{be,VERB},)                         0.253317        0.048234
# (holding{hold,VERB},)                  0.909176        0.099258
# (in{in,ADP},)                          0.189520        0.003406
# (her{-PRON-,ADJ},)                     1.292833        0.017458
# (hand{hand,NOUN},)                     0.892039        0.075573
# (.{.,PUNCT},)                          0.159212        0.010017
#
#                          (standing{stand,VERB},)
# (an{an,DET},)                           0.028461
# (asian{asian,ADJ},)                     0.262849
# (woman{woman,NOUN},)                    0.288009
# (is{be,VERB},)                          0.164248
# (standing{stand,VERB},)                 3.772581
# (on{on,ADP},)                           0.817855
# (a{a,DET},)                             0.002110
# (path{path,NOUN},)                      0.938492
# (with{with,ADP},)                       0.026101
# (a{a,DET},)                             0.002110
# (basket{basket,NOUN},)                  0.877390
# (on{on,ADP},)                           0.817855
# (her{-PRON-,ADJ},)                      0.097461
# (head{head,NOUN},)                      0.932348
# (looking{look,VERB},)                   1.184487
# (into{into,ADP},)                       0.706367
# (a{a,DET},)                             0.002110
# (mirror{mirror,NOUN},)                  0.839744
# (she{-PRON-,PRON},)                     0.218581
# (is{be,VERB},)                          0.164248
# (holding{hold,VERB},)                   1.618173
# (in{in,ADP},)                           0.119835
# (her{-PRON-,ADJ},)                      0.097461
# (hand{hand,NOUN},)                      1.236711
# (.{.,PUNCT},)                           0.056419

# %%
print(ma.mean())
print(ma.quantile(0.5))
# Out:
# (nobody{nobody,NOUN},)     0.814183
# (is{be,VERB},)             0.045582
# (standing{stand,VERB},)    0.610880
# dtype: float32
# (nobody{nobody,NOUN},)     0.714248
# (is{be,VERB},)             0.036891
# (standing{stand,VERB},)    0.262849
# Name: 0.5, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(ma, center=0, cmap='Blues_r', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Texto -> Hipótesis

# %% [markdown]
# # General

# %%
def getRelacionesMA(indice,df):
    indices=[]
    todas_relaciones=[]
    print(len(df.at[indice,"Text"]),len(df.at[indice,"Hipotesis"]))
    if len(df.at[indice,"Text"]) > 43:
        t=pd.DataFrame(df.at[indice,"Text"][1:-2])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
    else:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
    ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
    for index,strings in ma.iterrows():
        #print(index)
        if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):
            qu75=strings.max()
            suma=strings.sum()
            indices.append((index,strings.idxmax(),qu75/suma))
            todas_relaciones.append((index,strings.idxmax(),qu75/suma))
    labels=["NOUN","ADJ","VERB","ADV"]
    diccionarioTW = {}
    print(todas_relaciones)
    todas_relaciones=list(set(todas_relaciones))
    for l1 in labels[:]:
        for l2 in labels[:]:
            diccionarioTW[l1+"_"+l2]=[]
    for tr in todas_relaciones:
        print(tr[0],"-",tr[1])
        t_=str(tr[0]).split(",")
        pt=t_[1].split("}")[0]
        h_=str(tr[1]).split(",")
        ph=h_[1].split("}")[0]
        if pt=="PRON":
            pt="NOUN"
        if ph=="PRON":
            ph="NOUN"
        #diccionarioTW[pt+"_"+ph].append(tr[2])
        if pt+"_"+ph in diccionarioTW:
            diccionarioTW[pt+"_"+ph].append(tr[2])
    diccionarioTW_mean={}
    for k in diccionarioTW:
        if len(diccionarioTW[k])!=0:
            diccionarioTW_mean[k]=sum(diccionarioTW[k])#/len(diccionarioTW[k])
        else:
            diccionarioTW_mean[k]=0
    return diccionarioTW_mean

# %%
for c in ma.columns:
    print(ma[c].quantile(0.75))
# Out:
# 1.292832851409912
# 0.07005611062049866
# 0.8773901462554932

# %%
ma.quantile(0.25).values
# Out:
# array([0.18951955, 0.01483139, 0.09746138])

# %%
def getRelacionesMA_corte(indice,df,corte):
    indices=[]
    todas_relaciones=[]
    print(len(df.at[indice,"Text"]),len(df.at[indice,"Hipotesis"]))
    if len(df.at[indice,"Text"]) > 43:
        t=pd.DataFrame(df.at[indice,"Text"][1:-2])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
    else:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
    ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
    c=ma.mean().values #.quantile(corte).values
    for index,strings in ma.iterrows():
        #print(index)
        for l in range(len(c)):
            if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):                
                #print("columnna:",col,strings[col])
                print("umbral",c[l])
                if strings[l] >= c[l]:# >=1:
                    todas_relaciones.append((index,ma.columns[l],strings[l]))
    labels=["NOUN","ADJ","VERB","ADV"]
    diccionarioTW = {}
    print(todas_relaciones)
    #todas_relaciones=list(set(todas_relaciones))
    for l1 in labels[:]:
        for l2 in labels[:]:
            diccionarioTW[l1+"_"+l2]=[]
    for tr in todas_relaciones:
        #print(tr[0],"-",tr[1])
        t_=str(tr[0]).split(",")
        pt=t_[1].split("}")[0]
        h_=str(tr[1]).split(",")
        #print(t_,h_,"h0",h_[0])
        ph=h_[1].split("}")[0]
        if pt=="PRON":
            pt="NOUN"
        if ph=="PRON":
            ph="NOUN"
        #diccionarioTW[pt+"_"+ph].append(tr[2])
        if pt+"_"+ph in diccionarioTW:
            diccionarioTW[pt+"_"+ph].append(tr[2])
    diccionarioTW_mean={}
    diccionarioTW_mean_n={}
    for k in diccionarioTW:
        if len(diccionarioTW[k])!=0:
            diccionarioTW_mean[k]=sum(diccionarioTW[k])#/len(diccionarioTW[k])
            diccionarioTW_mean_n[k+"_"]=len(diccionarioTW[k])#/ma.shape[0]
        else:
            diccionarioTW_mean[k]=0
            diccionarioTW_mean_n[k+"_"]=0
    return diccionarioTW_mean,diccionarioTW_mean_n

# %% [markdown]
# # Lectura de los 100 pares de T y H (muestreo)

# %%
prueba=pd.read_csv("prueba.csv")

# %%
textos = prueba["sentence1"].to_list()
hipotesis = prueba["sentence2"].to_list()
print(textos)
print(hipotesis)
# Out:
# ['A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.', 'A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.', 'A young boy runs across a road in front of a sky blue building with barred windows.', 'An Asian woman is standing on a path with a basket on her head looking into a mirror she is holding in her hand.', 'A child in a maroon shirt playing next to a fountain.', 'man dressed in orange clothing with face covered seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall.', 'An old man with a package poses in front of an advertisement.', 'People dressed in traditional Japanese garb walk in a procession through a courtyard paved with paving stones.', 'Two children play in the snow by the side of the road.', 'Blond-haired girl wearing a bicycle helmet, a black t-shirt that reads "Twizzlers" and a printed dog tag necklace around her neck.', 'A fat woman wearing faint blue top is blowing soap bubble.', 'A father and his daughter are riding a lawn mover down a street while dressed in American colors.', 'Two men are drumming, one is standing and one is sitting down.', 'Three men are carrying a red bag into a boat with another person and boat in the background.', 'A woman wearing a red coat stands on a wood floor in front of several paintings while two girls sit on the floor at her feet.', 'The sun breaks through the trees as a child rides a swing.', 'A man wearing a shite short-sleeved shirt kisses a woman wearing a light pink jacket while standing on a public street.', 'Someone splashing in the water.', 'An elderly lady holding a scruffy dog and smiling contently.', 'An Asian woman in a purple shirt preparing a bowl of food for the younger Asian boy sitting near buy, while an Asian man eats a roll and prepares to take some food up with his chopsticks.', 'A woman is holding a microphone in one hand and her mouth is open.', 'A young girl in a white t-shirt and a blue skirt wearing a light colored hat stands in a river next to a big rock.', 'A gymnast using a set of paralleled bars.', 'A guy with a football, a crowd watching him.', 'Seven young girls are being creative and making posters.', 'An old man in a baseball hat and an old woman in a jean jacket are standing outside, but are covered mostly in shadow.', 'A man is throwing a small white ball at some red cups.', 'Several street vehicles pass by a traditional architecture style of Thailand.', 'Man and a woman at the side of a table covered in books.', 'A group of people wait to cross the street in new york', 'Two guys in blue shirts talking.', 'The child is hanging upside down with his legs over a pole.', 'Four young men stare up at a basketball hoop with no net, in an outdoor, urban basketball court.', 'A group of people celebrating in the street.', 'A man and a woman stand in front of a Christmas tree contemplating a single thought.', 'A casually dressed young blond woman is looking away sadly as couple near her are kissing.', 'Girls giving a presentation for a school class.', 'A man and a child painting a post.', 'A young boy holding a red toy wearing green snowman and reindeer pajamas with an older woman on a couch behind him.', 'A lady with blue jeans and a brown shirt is speaking on her cellphone on the second floor of the mall.', 'A person obscured in shadow in a gymnasium.', 'African woman walking through field.', 'Men are playing rugby while covered in mud.', 'A child with curly blond-hair looks at another child with long brown hair while sitting on a bench.', 'A shirtless man with cropped hair smokes a cigarette and ties a plastic bag.', 'A group of people stares at a wall that is filled with drawings in a building.', 'A girl with curly hair and wearing a patriotic shirt is looking at a monarch butterfly sitting on her left index finger.', 'The blue kayak is being ridden over a small waterfall.', 'A person in a large pink  ...
# ['A person in appropriate institution protection works with meals.', 'a guy in a red top and tie makes a speech', 'A boy sleeps in his bed.', 'Nobody is standing', 'The child is getting wet from the fountain.', 'Two clowns are performing at a mall.', 'A man poses in front of an ad for beer.', 'People dressed in Japanese clothing walk through a courtyard.', 'Kids are enjoying the cold weather.', 'a girl with a helmet wears a dog tag', 'A fat woman is wearing pants.', 'two men cut grass by hand', 'Two people are drumming.', 'A person drives away in a winnebago.', 'Woman takes a break at a museum while her children sit by her feet.', 'The child on the swing is a girl.', 'A man is kissing a woman', 'Someone is having a picnic near the lake.', 'a woman holding a scruffy cat', 'A woman is preparing food for a child.', 'A woman standing at a microphone', 'A girl is wearing a hat.', 'A young gymnast is performing.', 'There is a guy with a basketball.', 'Girls are making posters.', 'An old woman has a light jean jacket.', 'The man playing a game.', 'Vehicles are going down a street in Thailand.', 'People near a lot of reading materials.', 'Some of the people are wearing sunglasses.', 'Two men complimenting each other on their blue shirts.', 'There is an adult upside down.', 'A group of women playing basketball in a gym.', 'There is a celebration going on', 'Two people talk loudly in front of a cactus.', 'A woman looks away after recognizing her ex-boyfriend kissing his new girl.', 'The girls are inside a school.', 'The father and son are repairing the sign.', 'The older woman behind the young boy is his mother.', 'the lady is talking on her phone', 'The person is trying to be sneaky.', 'The african woman is looking for someone in the fields.', 'The men are perfectly free of mud.', 'The school kids are relaxing during recess.', 'The man is not wearing a shirt.', 'A group of people analyze art together', 'A girl captures a butterfly for a science fair project', 'A kayak is being ridden.', 'The person is alone in the middle of the ocean.', 'Young children open presents under a large Christmas tree.', 'A boy pitches the ball.', 'A raven haired woman is seen by the crowd holding a white opened umbrella.', 'A recently engaged couple embrace on the street.', 'A person rides a skateboard.', 'A girl jumping rope on Mars.', 'A woman rises from a chair', 'Three people in nature.', 'A bird is looking for food on a lake.', 'a singer is on american idol', 'An older man is sweeping his patio while a passerby enters a building', 'Two people are in a bike race.', 'The person is a woman.', 'Women are looking at books on sale at a library.', 'The dog is outside.', 'A woman in green opening a box while a half concealed man manipulates a handheld device.', 'The woman is not going to finish the race.', 'A man is making pottery.', 'A guy is riding the bus.', 'A person with a great tatto', 'A woman is wearing a mask', 'Four kids pose on a beach.', 'A woman is putting on mascara.', 'A man eats a hamburger while his friend asks for a bite.', 'The boy sitting on top of his dads truck.', 'A young couple is very much in love.', 'A man in red is holding out his hand.', 'A boy is running outside.', 'A woman is singing on stage.', 'The boy is walking outside.', 'The sports fans are wearing yellow.', 'A wide reciever is trying to make a catch.', 'A man has damaged something.', 'There are people outside.', 'A women observing a camera', 'A girl is playing the piano in her living room.', 'A boy dressed for summer in a green shirt and kahki shorts', 'A dog is on the beach.', 'A skier preparing a trick', 'Two fathers maneuver their baby strollers into a foyer.', 'The man has blue sunglasses.', 'A child does a cannonball into a pool.', 'Laura Bush is giving a talk about the importance of literacy to young people.', 'Men are in wetsuits', 'The batsman is on a different team than the others around the pitching mound.', 'A boy is watching a movie in his living room.', 'a bunch ...

# %%
import nltk, re, os
from nltk.corpus import wordnet as wn
import networkx as nx
from matplotlib import pyplot as plt

# %% [markdown]
# # otro proceso

# %%
def tokenizar(texto,nlp,wn,hipotesis=False):
    sto =['a','and','',' ',None,'A','to','of','or']
    sinonimos=set()
    #print(texto)
    lista=[]
    doc = nlp(texto)
    l=[]
    for token in doc:
        #print(token.text, token.dep_, token.head.text, token.head.pos_)
        #print(str(token.pos_))
        if str(token.pos_) in ['NOUN','ADV','ADJ','VERB','PRON']:
            #print(token.text,token.pos_)
            sinonimos=set()
            if(token.pos_ == 'NOUN' or token.pos_ == 'PRON'):
                w =wn.synsets(token.text,wn.NOUN)                
            elif(token.pos_ == 'VERB'):
                w =wn.synsets(token.text,wn.VERB)
            elif(token.pos_ == 'ADJ'):
                w =wn.synsets(token.text,wn.ADJ)
            elif(token.pos_ == 'ADV'):
                w =wn.synsets(token.text,wn.ADV)
            
            #SINONIMOS
            if w==[]:
                w = w =wn.synsets(token.lemma_)
            for wi in w[:2]:
                #print(wi)
                for sin in wi.lemma_names():
                    sinonimos.add(sin)
                    #print("Checar ",sin)
                    #print("definition:",wi,wi.definition())
                    d_ = nlp(wi.definition())
                    for t in d_:
                        for child in t.children:
                            if child.text not in sto and t.text not in sto:
                                #lista.append((str(t.text)+","+str(t.pos_),str(child.text)+","+str(child.pos_)))
                                #print((str(t.text)+","+str(t.pos_),str(child.text)+","+str(child.pos_)))
                                #if child.pos_ in ['NOUN','ADJ']:
                                    #lista.append((str(sin)+","+str(token.pos_),str(child.text)+","+str(child.pos_)))
                                lista.append((str(sin)+","+str(token.pos_),str(child.text)+",A"))

            for e in sinonimos:
                lista.append((e+",S",str(token.text)+","+str(token.pos_)))
                #lista.append((str(token.text)+",S",e))
            if hipotesis==False:
                # HIPERONIMOS
                for wi in w[:2]:
                    paths = wi.hypernym_paths()
                    #print("CAMINOS",wi,paths)
                    for p in paths:
                        if(len(p)>1):
                            #print("caminos",p)
                            j=0
                            for pi in p[::-1]:
                                #print(pi,token.text)
                                #print(pi.lemma_names())
                                for pis in pi.lemma_names():
                                    lista.append((pis+",H",str(token.text)+","+str(token.pos_)))
                                    #lista.append((str(token.text)+",H",pis))
                                #if j==0:
                                #    primero=pi
                                #    lista.append((str(token.text)+","+str(token.head.pos_),pi))
                                #    j+=1
                                #else:
                                #    print("nodo",pi,pi.definition())
                                #    lista.append((primero,pi))
                                #    primero=pi
                #for p in paths:
                        #    for pi in p:
                        #        print(pi,pi.lemma_names(),pi.definition())
                        #for li in wi.lemma_names():
                        #    lista.append((token.text,li))
                #print(sinonimos)
            
            for child in token.children:
                if child.text not in sto:
                    lista.append((str(token.text)+","+str(token.pos_),str(child.text)+","+str(child.pos_)))
            l=set(lista)
    return list(l)

# %% [markdown]
# # Mod

# %%
def revision(relaciones_alineadas,wn,GH,G):
    faltantes = []
    existentes=[]
    relacion = []
    razonamiento=[]
    palabras_encontradas=[]
    restantes_rel_ali=relaciones_alineadas[:]
    for r_a in relaciones_alineadas:
        max_r=0
        max_root=0
        max_lch=0
        cam_sh=0
        print(r_a[0],"a",r_a[1])
        word_t = str(r_a[0]).split('\'')[1]
        wt = word_t.split('{')[0]
        lt = word_t.split('}')[0].split(',')[0].split('{')[1]
        pt = word_t.split('}')[0].split(',')[1]
        w_in_text= wt + "," + pt
        #print(wt,lt,pt)
        word_h = str(r_a[1]).split('\'')[1]
        wh = word_h.split('{')[0] #palabra tal cual
        lh = word_h.split('}')[0].split(',')[0].split('{')[1] #palabra lematizada
        ph = word_h.split('}')[0].split(',')[1] # pos de la palabra
        word = wh + "," + ph # palabra con el pos correspondiente
        #print(wh,lh,ph)
        if word not in palabras_encontradas:
            #Primero preguntamos si la palabra se encuentra en el grafo de la hipótesis
            if word in GH:
                # la palabra se encuentra en el grafo del texto
                if word in G:
                    print("El token: ",word," se encuentra en el Texto")
                    preds=GH.predecessors(word)
                    for e in preds:
                        po=e.split(",")
                        if(po[-1]=="ADJ" or po[-1]=="ADV"):
                            relacion.append((e,word))
                    existentes.append((word,word,1.0))
                elif wh+",H" in G: # Esto es para validar que exista la relación de hiperonimia
                    #print("Hiperonimo",wh)
                    su=G.successors(wh+",H") # el vinculo se encuentra en el texto
                    for e in su:
                        if e == w_in_text:
                            existentes.append((e,wh+",H",1.0))
                            preds=GH.predecessors(word)
                            for ei in preds:
                                po=ei.split(",")
                                if(po[-1]=="ADJ" or po[-1]=="ADV"):
                                    relacion.append((ei,word))
                            palabras_encontradas.append(word)
                            print("palabras encontradas",palabras_encontradas)
                            break
                elif wh+",S" in G:
                    print("Sinonimo",wh)
                    su=G.successors(wh+",S")
                    for e in su:
                        existentes.append((e,wh+",S",1.0))
                        preds=GH.predecessors(word)
                        for ei in preds:
                            po=ei.split(",")
                            if(po[-1]=="ADJ" or po[-1]=="ADV"):
                                relacion.append((e,e))
                        break
                else: ## buscamos relaciones en el grafo de wordnet
                    if pt == "NOUN" or pt=="PRON":
                        w1_=wn.synsets(wt,wn.NOUN)
                    elif pt == "VERB":
                        w1_=wn.synsets(wt,wn.VERB)
                    elif pt == "ADJ":
                        w1_=wn.synsets(wt,wn.ADJ)
                    elif pt == "ADV":
                        w1_=wn.synsets(wt,wn.ADV)
                    else:
                        w1_=wn.synsets(wt)
                    if ph == "NOUN" or ph=="PRON":
                        w2_=wn.synsets(wh,wn.NOUN)
                    elif ph == "VERB":
                        w2_=wn.synsets(wh,wn.VERB)
                    elif ph == "ADJ":
                        w2_=wn.synsets(wh,wn.ADJ)
                    elif ph == "ADV":
                        w2_=wn.synsets(wh,wn.ADV)
                    else:
                        w2_=wn.synsets(wh)
                    max_r=0
                    sim=0
                    sim_h=0
                    max_lch=0
                    max_root=0
                    cam_sh=0
                    for a in w1_:
                        for b in w2_:
                            sim=a.wup_similarity(b)
                            if sim>max_r:
                                sim_h=b.path_similarity(a, simulate_root=False)
                                if sim_h!=None:
                                    max_r=sim#+sim_h
                                    max_root=sim_h
                                    palabra1=a
                                    palabra2=b
                                    cam_sh=a.shortest_path_distance(b)
                                    if pt==ph:
                                        max_lch=a.lch_similarity(b)
                                    else:
                                        max_lch=0
                                        #print(p1,p2,max_r)
                                else:
                                    sim_h=b.path_similarity(a)    
                                    if pt==ph and a.pos()==b.pos():
                                        max_lch=a.lch_similarity(b)
                                    else:
                                        max_lch=0
                                    cam_sh=a.shortest_path_distance(b)
                                    max_r=sim
                                    max_root=sim_h
                                    palabra1=a
                                    palabra2=b
                    #Guardamos relaciones que no se consideraron como ADJ, ADV y NOUN
                    susc=GH.successors(word)
                    for ei in susc:
                        po=ei.split(",")
                        if(ph=="NOUN" and (po[-1]=="ADJ" or po[-1]=="ADV")):
                            if (ei,word) not in relacion:
                                relacion.append((ei,word))                           
                    if max_r>=0.5:
                        print("Guardado: ",w_in_text,word,"wup: ",max_r,sim,"path: ",sim_h,"lch: ",max_lch,"max_root: ",max_root,"shorthes path: ",cam_sh)
                        existentes.append((w_in_text, word,max_r))
                        razonamiento.append((palabra1,"->",palabra2,palabra1.definition(),max_r))
            else:
                relacion.append((word_t,word_h))
                print("No esta en grafo H:",word)
    print()
    print("Existentes",existentes)
    print("Faltantes",faltantes)
    print("Relaciones a buscar",relacion)
    print()

    print(set(razonamiento))
    return list(set(existentes)),relacion

# %% [markdown]
# # inferencia

# %%
def inferencia(existentes,faltantes,texts,wn):
    falt=faltantes[:]
    
    # HAY UN PROBLEMA CON LOS FALTANTES YA QUE QUE NO EXISTAN QUIERE DECIR QUE LOS TOKENS SE ENCOTRARON
    # POR LO QUE HAY QUE REVISAR 
    # DEBEMOS COMPARAR EL TIPO DE PALABRAS FALTANTES CON EL TIPO DE PALABRAS QUE TENEMOS
    # TALVES SERÍA CORRECTO RELACIONAR SUSTANTIVOS CON ADJETIVOS
    # PERO REVISAR VERBOS CON UNICAMENTE VERBOS
    result=""
    print("fal",falt)
    print("existentes",existentes)
    promedio=0
    if(len(falt)==0):
        for e in existentes:
            promedio+=float(e[2])
        promedio=promedio/len(existentes)
    else:
        promedio=0.0
    
    if(promedio>0.7):
        print("Entailment",promedio)
        result="entailment"
    elif(promedio > 0.45 and promedio<=0.7):
        print("Neutral",promedio)
        result="neutral"
    else:
        print("Contradiction",promedio)
        result="contradiction"
    return result,existentes,falt

# %% [markdown]
# # prueba

# %%
features=[]
length=len(textos)
for i in range(length):
#length=[4]
#for i in length:
    print(i)
    print("Texto: ",textos[i])
    print("Hipótesis: ",hipotesis[i])
    todas_relaciones,todos_conteos=getRelacionesMA_corte(i,df,0.25)
    #print(todas_relaciones)
    features.append(list(todas_relaciones.values())+list(todos_conteos.values()))
# Out:
# 0
# Texto:  A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.
# Hipótesis:  A person in appropriate institution protection works with meals.
# 23 11
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# umbral 0.015641285
# umbral 0.28797138
# umbral 0.042860556
# umbral 0.115715094
# umbral 0.4370141
# umbral 0.5621163
# umbral 0.6156013
# umbral 0.0070479754
# umbral 0.75883335
# umbral 0.032565787
# [(('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('man{man,NOUN}',), ('person{person,NOUN}',), 2.7393045), (('man{man,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.28043467), (('man{man,NOUN}',), ('institution{institution,NOUN}',), 0.68360347), (('man{man,NOUN}',), ('works{work,VERB}',), 0.86454284), (('man{man,NOUN}',), ('with{with,ADP}',), 0.031293392), (('wearing{wear,VERB}',), ('person{person,NOUN}',), 0.30613843), (('wearing{wear,VERB}',), ('protection{protection,NOUN}',), 0.9683174), (('wearing{wear,VERB}',), ('with{with,ADP}',), 0.019864088), (('wearing{wear,VERB}',), ('.{.,PUNCT}',), 0.048838258), (('blue{blue,ADJ}',), ('person{person,NOUN}',), 0.38392273), (('blue{blue,ADJ}',), ('in{in,ADP}',), 0.08334409), (('blue{blue,ADJ}',), ('institution{institution,NOUN}',), 0.7114139), (('blue{blue,ADJ}',), ('protection{protection,NOUN}',), 1.0381266), (('blue{blue,ADJ}',), ('meals{meal,NOUN}',), 0.79603136), (('blue{blue,ADJ}',), ('.{.,PUNCT}',), 0.03307896), (('shirt{shirt,NOUN}',), ('person{person,NOUN}',), 0.5483131), (('shirt{shirt,NOUN}',), ('in{in,ADP}',), 0.06094352), (('shirt{shirt,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.21762419), (('shirt{shirt,NOUN}',), ('institution{institution,NOUN}',), 0.5403721), (('shirt{shirt,NOUN}',), ('protection{protection,NOUN}',), 1.5583643), (('shirt{shirt,NOUN}',), ('with{with,ADP}',), 0.032122858), (('shirt{shirt,NOUN}',), ('meals{meal,NOUN}',), 0.81555146), (('shirt{shirt,NOUN}',), ('.{.,PUNCT}',), 0.07561737), (('black{black,ADJ}',), ('person{person,NOUN}',), 0.4654065), (('black{black,ADJ}',), ('in{in,ADP}',), 0.09151235), (('black{black,ADJ}',), ('appropriate{appropriate,ADJ}',), 0.12750843), (('black{black,ADJ}',), ('institution{institution,NOUN}',), 1.6096103), (('black{black,ADJ}',), ('protection{protection,NOUN}',), 1.1399006), (('black{black,ADJ}',), ('with{with,ADP}',), 0.0127584385), (('black{black,ADJ}',), ('.{.,PUNCT}',), 0.050242342), (('apron{apron,NOUN}',), ('in{in,ADP}',), 0.09680434), (('apron{apron,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.22604023), (('apron{apron,NOUN}',), ('institution{institution,NOUN}',), 0.94798976), (('apron{apron,NOUN}',), ('protection{protection,NOUN}',), 1.5491754), (('apron{apron,NOUN}',), ('works{work,VERB}',), 1.4815819), (('apron{apron,NOUN}',), ('with{with,ADP}',), 0.008705366), (('apron{apron,NOUN}',), ('meals{meal,NOUN}',), 2.1444316), (('apron{apron,NOUN}',), ('.{.,PUNCT}',), 0.07195437), (('eyeglasses{eyeglass,NOUN}',), ('person{person,NOUN}',), 0.46568495), (('eyeglasses{eyeglass,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.2499403), (('eyeglasses{eyeglass,NOUN}',), ('institution{institution,NOUN}',), 1.0152488), (('eyeglasses{eyeglass,NOUN}',), ('protection{protection,NOUN}',), 1.2863016), (('eyeglasses{eyeglass,NOUN}',), ('works{work,VERB}',), 1.5609107), (('eyeglasses{eyeglass,NOUN}',), ('meals{meal,NOUN}',), 1.833542), (('eyeglasses{eyeglass,NOUN}',), ('.{.,PUNCT}',), 0.035649784), (('mask{mask,NOUN}',), ('a{a,DET}',), 0.0182602), (('mask{mask,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.21877745), (('mask{mask,NOUN}',), ('institution{institution,NOUN}',), 0.64354813), (('mask{mask,NOUN}',), ('protection{protection,NOUN}',), 1.6344744), (('mask{mask,NOUN}',), ('works{work,VERB}',), 1.5607735), (('mask{mask,NOUN}',), ('meals{meal,NOUN}',), 1.8941077), (('mask{mask,NOUN}',), ('.{.,PUNCT}',), 0.04253065), (('handling{handle,VERB}',), ('a{a,DET}',), 0.032141738), (('handling{handle,VERB}',), ('person{person,NOUN}',), 0.2892014), (('handling{handle,VERB}',), ('in{in,ADP}',), 0.066501394), (('handling{handle,VERB}',), ('appropriate{appropriate,ADJ}',), 0.3031758), (('handling{handle,VERB}',), ('institution{institution,NOUN}',), 0.57469887), (('handling{handle,VERB}',), ('protection{protection,NOUN}',), 0.79171145), (('handling{handle,VERB}',), ('works{work,VERB}',), 2.0916288), (('handling{handle,VERB}',), ('meals{meal,NOUN}',), 1.7471396), (('handling{handle,VERB}',), ('.{.,PUNCT}',), 0.04730215), (('food{food,N ...
# 1
# Texto:  A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.
# Hipótesis:  a guy in a red top and tie makes a speech
# 22 12
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# umbral 0.023201976
# umbral 0.5171311
# umbral 0.07585429
# umbral 0.023201976
# umbral 0.7527958
# umbral 0.21972463
# umbral 0.020964012
# umbral 0.6405242
# umbral 0.47678712
# umbral 0.023201976
# umbral 1.0375503
# [(('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('man{man,NOUN}',), ('guy{guy,NOUN}',), 3.423489), (('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('man{man,NOUN}',), ('and{and,CCONJ}',), 0.033799753), (('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('dressed{dress,VERB}',), ('guy{guy,NOUN}',), 0.5705536), (('dressed{dress,VERB}',), ('top{top,NOUN}',), 0.69319415), (('dressed{dress,VERB}',), ('and{and,CCONJ}',), 0.02514555), (('dressed{dress,VERB}',), ('tie{tie,NOUN}',), 1.2315246), (('red{red,ADJ}',), ('red{red,ADJ}',), 5.2774463), (('red{red,ADJ}',), ('tie{tie,NOUN}',), 0.7923888), (('shirt{shirt,NOUN}',), ('guy{guy,NOUN}',), 0.79965866), (('shirt{shirt,NOUN}',), ('red{red,ADJ}',), 0.76137096), (('shirt{shirt,NOUN}',), ('top{top,NOUN}',), 0.41330415), (('shirt{shirt,NOUN}',), ('and{and,CCONJ}',), 0.025457522), (('shirt{shirt,NOUN}',), ('tie{tie,NOUN}',), 1.356515), (('black{black,ADJ}',), ('guy{guy,NOUN}',), 0.60708606), (('black{black,ADJ}',), ('in{in,ADP}',), 0.09151235), (('black{black,ADJ}',), ('red{red,ADJ}',), 3.3381805), (('black{black,ADJ}',), ('top{top,NOUN}',), 0.43125343), (('black{black,ADJ}',), ('tie{tie,NOUN}',), 0.66219443), (('tie{tie,NOUN}',), ('a{a,DET}',), 0.0244852), (('tie{tie,NOUN}',), ('guy{guy,NOUN}',), 0.566649), (('tie{tie,NOUN}',), ('a{a,DET}',), 0.0244852), (('tie{tie,NOUN}',), ('red{red,ADJ}',), 0.7923888), (('tie{tie,NOUN}',), ('top{top,NOUN}',), 0.49118018), (('tie{tie,NOUN}',), ('tie{tie,NOUN}',), 2.1544504), (('tie{tie,NOUN}',), ('makes{make,VERB}',), 0.62809175), (('tie{tie,NOUN}',), ('a{a,DET}',), 0.0244852), (('tie{tie,NOUN}',), ('speech{speech,NOUN}',), 1.632478), (('stands{stand,VERB}',), ('in{in,ADP}',), 0.11606273), (('stands{stand,VERB}',), ('top{top,NOUN}',), 0.49188167), (('stands{stand,VERB}',), ('and{and,CCONJ}',), 0.06186468), (('stands{stand,VERB}',), ('tie{tie,NOUN}',), 0.7616982), (('stands{stand,VERB}',), ('makes{make,VERB}',), 0.60041875), (('stands{stand,VERB}',), ('speech{speech,NOUN}',), 1.4440373), (('wedding{wedding,NOUN}',), ('guy{guy,NOUN}',), 1.451425), (('wedding{wedding,NOUN}',), ('in{in,ADP}',), 0.10502019), (('wedding{wedding,NOUN}',), ('red{red,ADJ}',), 1.5915512), (('wedding{wedding,NOUN}',), ('top{top,NOUN}',), 0.2538691), (('wedding{wedding,NOUN}',), ('tie{tie,NOUN}',), 1.178471), (('wedding{wedding,NOUN}',), ('makes{make,VERB}',), 0.7048656), (('wedding{wedding,NOUN}',), ('speech{speech,NOUN}',), 1.8128022), (('reception{reception,NOUN}',), ('in{in,ADP}',), 0.16684818), (('reception{reception,NOUN}',), ('top{top,NOUN}',), 0.22148626), (('reception{reception,NOUN}',), ('tie{tie,NOUN}',), 0.9831245), (('reception{reception,NOUN}',), ('makes{make,VERB}',), 0.96974885), (('reception{reception,NOUN}',), ('speech{speech,NOUN}',), 2.309178), (('make{make,VERB}',), ('a{a,DET}',), 0.0790534), (('make{make,VERB}',), ('guy{guy,NOUN}',), 0.6569229), (('make{make,VERB}',), ('in{in,ADP}',), 0.11904971), (('make{make,VERB}',), ('a{a,DET}',), 0.0790534), (('make{make,VERB}',), ('top{top,NOUN}',), 0.24463844), (('make{make,VERB}',), ('and{and,CCONJ}',), 0.034861006), (('make{make,VERB}',), ('tie{tie,NOUN}',), 1.216042), (('make{make,VERB}',), ('makes{make,VERB}',), 1.4106249), (('make{make,VERB}',), ('a{a,DET}',), 0.0790534), (('make{make,VERB}',), ('speech{speech,NOUN}',), 2.577352), (('speech{speech,NOUN}',), ('a{a,DET}',), 0.13712224), (('speech{speech,NOUN}',), ('guy{guy,NOUN}',), 1.0873796), (('speech{speech,NOUN}',), ('in{in,ADP}',), 0.14727588), (('speech{speech,NOUN}',), ('a{a,DET}',), 0.13712224), (('speech{speech,NOUN}',), ('red{red,ADJ}',), 0.838912), (('speech{speech,NOUN}',), ('and{and,CCONJ}',), 0.06793973), (('speech{speech,NOUN}',), ('tie{tie,NOUN}',), 1.632478), (('speech{speech,NOUN}',), ('makes{make,VERB}',), 2.1349905), (('speech{speech,NOUN}',), ('a{a,DET}',), 0.13712224), (('speech{speech,NOUN}',), ('speech{speech,NOUN}',), 4.903362)]
# 2
# Texto:  A young boy runs across a road in front of a sky blue building with barred windows.
# Hipótesis:  A boy sleeps in his bed.
# 19 8
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# umbral 0.021035017
# umbral 0.56956434
# umbral 0.80937964
# umbral 0.122501336
# umbral 0.24753761
# umbral 0.8613122
# umbral 0.026528288
# [(('young{young,ADJ}',), ('boy{boy,NOUN}',), 2.7248206), (('young{young,ADJ}',), ('his{-PRON-,ADJ}',), 0.90929025), (('boy{boy,NOUN}',), ('a{a,DET}',), 0.07289694), (('boy{boy,NOUN}',), ('boy{boy,NOUN}',), 4.5691986), (('boy{boy,NOUN}',), ('sleeps{sleep,VERB}',), 1.0684676), (('boy{boy,NOUN}',), ('his{-PRON-,ADJ}',), 1.8245916), (('runs{run,VERB}',), ('a{a,DET}',), 0.030134961), (('runs{run,VERB}',), ('sleeps{sleep,VERB}',), 3.661071), (('runs{run,VERB}',), ('in{in,ADP}',), 0.1650992), (('runs{run,VERB}',), ('his{-PRON-,ADJ}',), 0.3470169), (('runs{run,VERB}',), ('bed{bed,NOUN}',), 1.1998608), (('runs{run,VERB}',), ('.{.,PUNCT}',), 0.07411386), (('road{road,NOUN}',), ('a{a,DET}',), 0.02482621), (('road{road,NOUN}',), ('in{in,ADP}',), 0.5121674), (('road{road,NOUN}',), ('bed{bed,NOUN}',), 2.123679), (('road{road,NOUN}',), ('.{.,PUNCT}',), 0.055114232), (('front{front,NOUN}',), ('in{in,ADP}',), 0.28400853), (('front{front,NOUN}',), ('bed{bed,NOUN}',), 1.1050626), (('front{front,NOUN}',), ('.{.,PUNCT}',), 0.069333464), (('sky{sky,NOUN}',), ('sleeps{sleep,VERB}',), 1.4454561), (('sky{sky,NOUN}',), ('in{in,ADP}',), 0.17885883), (('sky{sky,NOUN}',), ('bed{bed,NOUN}',), 2.4027486), (('blue{blue,ADJ}',), ('sleeps{sleep,VERB}',), 1.0149397), (('blue{blue,ADJ}',), ('bed{bed,NOUN}',), 1.6184589), (('blue{blue,ADJ}',), ('.{.,PUNCT}',), 0.03307896), (('building{building,NOUN}',), ('in{in,ADP}',), 0.24241619), (('building{building,NOUN}',), ('bed{bed,NOUN}',), 2.126788), (('barred{barred,ADJ}',), ('a{a,DET}',), 0.03451265), (('barred{barred,ADJ}',), ('sleeps{sleep,VERB}',), 2.6506383), (('barred{barred,ADJ}',), ('his{-PRON-,ADJ}',), 0.39168817), (('barred{barred,ADJ}',), ('bed{bed,NOUN}',), 1.0405141), (('barred{barred,ADJ}',), ('.{.,PUNCT}',), 0.035596002), (('windows{window,NOUN}',), ('a{a,DET}',), 0.04424715), (('windows{window,NOUN}',), ('sleeps{sleep,VERB}',), 1.1739506), (('windows{window,NOUN}',), ('in{in,ADP}',), 0.26995787), (('windows{window,NOUN}',), ('bed{bed,NOUN}',), 2.5531425), (('windows{window,NOUN}',), ('.{.,PUNCT}',), 0.037339795)]
# 3
# Texto:  An Asian woman is standing on a path with a basket on her head looking into a mirror she is holding in her hand.
# Hipótesis:  Nobody is standing
# 26 4
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# umbral 0.8141831
# umbral 0.04558248
# umbral 0.61088026
# [(('asian{asian,ADJ}',), ('nobody{nobody,NOUN}',), 1.3274782), (('woman{woman,NOUN}',), ('nobody{nobody,NOUN}',), 1.9542669), (('is{be,VERB}',), ('is{be,VERB}',), 0.048234075), (('standing{stand,VERB}',), ('nobody{nobody,NOUN}',), 1.6132503), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.16424847), (('standing{stand,VERB}',), ('standing{stand,VERB}',), 3.7725809), (('path{path,NOUN}',), ('standing{stand,VERB}',), 0.93849206), (('basket{basket,NOUN}',), ('standing{stand,VERB}',), 0.87739015), (('her{-PRON-,ADJ}',), ('nobody{nobody,NOUN}',), 1.2928329), (('head{head,NOUN}',), ('standing{stand,VERB}',), 0.9323483), (('looking{look,VERB}',), ('nobody{nobody,NOUN}',), 1.6308092), (('looking{look,VERB}',), ('is{be,VERB}',), 0.12195437), (('looking{look,VERB}',), ('standing{stand,VERB}',), 1.1844865), (('mirror{mirror,NOUN}',), ('nobody{nobody,NOUN}',), 2.424366), (('mirror{mirror,NOUN}',), ('is{be,VERB}',), 0.09869578), (('mirror{mirror,NOUN}',), ('standing{stand,VERB}',), 0.8397438), (('she{-PRON-,PRON}',), ('nobody{nobody,NOUN}',), 1.841595), (('is{be,VERB}',), ('is{be,VERB}',), 0.048234075), (('holding{hold,VERB}',), ('nobody{nobody,NOUN}',), 0.90917647), (('holding{hold,VERB}',), ('is{be,VERB}',), 0.09925847), (('holding{hold,VERB}',), ('standing{stand,VERB}',), 1.6181725), (('her{-PRON-,ADJ}',), ('nobody{nobody,NOUN}',), 1.2928329), (('hand{hand,NOUN}',), ('nobody{nobody,NOUN}',), 0.8920393), (('hand{hand,NOUN}',), ('is{be,VERB}',), 0.07557302), (('hand{hand,NOUN}',), ('standing{stand,VERB}',), 1.2367109)]
# 4
# Texto:  A child in a maroon shirt playing next to a fountain.
# Hipótesis:  The child is getting wet from the fountain.
# 13 10
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# umbral 0.009458934
# umbral 0.61162454
# umbral 0.030154517
# umbral 0.29949486
# umbral 0.638572
# umbral 0.32033747
# umbral 0.009458934
# umbral 0.90339977
# umbral 0.027451418
# [(('child{child,NOUN}',), ('child{child,NOUN}',), 3.7207057), (('child{child,NOUN}',), ('is{be,VERB}',), 0.044593856), (('child{child,NOUN}',), ('getting{get,VERB}',), 0.30784258), (('child{child,NOUN}',), ('wet{wet,NOUN}',), 0.6604464), (('maroon{maroon,ADJ}',), ('child{child,NOUN}',), 0.72174436), (('maroon{maroon,ADJ}',), ('fountain{fountain,NOUN}',), 0.9360565), (('maroon{maroon,ADJ}',), ('.{.,PUNCT}',), 0.0538057), (('shirt{shirt,NOUN}',), ('child{child,NOUN}',), 0.7180546), (('shirt{shirt,NOUN}',), ('wet{wet,NOUN}',), 1.0589019), (('shirt{shirt,NOUN}',), ('.{.,PUNCT}',), 0.07561737), (('playing{play,VERB}',), ('child{child,NOUN}',), 0.62720424), (('playing{play,VERB}',), ('is{be,VERB}',), 0.13306104), (('playing{play,VERB}',), ('getting{get,VERB}',), 1.1285796), (('playing{play,VERB}',), ('wet{wet,NOUN}',), 1.0245728), (('playing{play,VERB}',), ('from{from,ADP}',), 0.43745986), (('playing{play,VERB}',), ('fountain{fountain,NOUN}',), 1.4260062), (('playing{play,VERB}',), ('.{.,PUNCT}',), 0.07135111), (('next{next,ADV}',), ('the{the,DET}',), 0.032499075), (('next{next,ADV}',), ('getting{get,VERB}',), 0.41189674), (('next{next,ADV}',), ('wet{wet,NOUN}',), 0.7904075), (('next{next,ADV}',), ('from{from,ADP}',), 0.96460044), (('next{next,ADV}',), ('the{the,DET}',), 0.032499075), (('next{next,ADV}',), ('fountain{fountain,NOUN}',), 1.4746082), (('fountain{fountain,NOUN}',), ('the{the,DET}',), 0.01177446), (('fountain{fountain,NOUN}',), ('child{child,NOUN}',), 0.67405474), (('fountain{fountain,NOUN}',), ('is{be,VERB}',), 0.052871607), (('fountain{fountain,NOUN}',), ('getting{get,VERB}',), 0.6781827), (('fountain{fountain,NOUN}',), ('wet{wet,NOUN}',), 2.5289824), (('fountain{fountain,NOUN}',), ('from{from,ADP}',), 1.0499238), (('fountain{fountain,NOUN}',), ('the{the,DET}',), 0.01177446), (('fountain{fountain,NOUN}',), ('fountain{fountain,NOUN}',), 5.262477)]
# 5
# Texto:  man dressed in orange clothing with face covered seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall.
# Hipótesis:  Two clowns are performing at a mall.
# 33 9
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# umbral 0.12062943
# umbral 0.7502483
# umbral 0.027499346
# umbral 0.5428157
# umbral 0.31807706
# umbral 0.022220055
# umbral 0.8020246
# umbral 0.039704468
# [(('man{man,NOUN}',), ('two{two,NUM}',), 0.5037433), (('man{man,NOUN}',), ('clowns{clown,NOUN}',), 1.0620116), (('man{man,NOUN}',), ('are{be,VERB}',), 0.038112305), (('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('dressed{dress,VERB}',), ('two{two,NUM}',), 0.15766057), (('dressed{dress,VERB}',), ('clowns{clown,NOUN}',), 1.0876305), (('dressed{dress,VERB}',), ('.{.,PUNCT}',), 0.068661), (('orange{orange,ADJ}',), ('two{two,NUM}',), 0.19320564), (('orange{orange,ADJ}',), ('clowns{clown,NOUN}',), 2.267705), (('orange{orange,ADJ}',), ('are{be,VERB}',), 0.040094014), (('orange{orange,ADJ}',), ('mall{mall,NOUN}',), 0.9647952), (('clothing{clothing,NOUN}',), ('clowns{clown,NOUN}',), 1.1187652), (('clothing{clothing,NOUN}',), ('mall{mall,NOUN}',), 0.8535703), (('clothing{clothing,NOUN}',), ('.{.,PUNCT}',), 0.084554136), (('face{face,NOUN}',), ('clowns{clown,NOUN}',), 0.8787012), (('face{face,NOUN}',), ('are{be,VERB}',), 0.0705923), (('face{face,NOUN}',), ('performing{perform,VERB}',), 0.7066068), (('face{face,NOUN}',), ('at{at,ADP}',), 0.44340074), (('face{face,NOUN}',), ('a{a,DET}',), 0.052500125), (('face{face,NOUN}',), ('.{.,PUNCT}',), 0.05934211), (('covered{cover,VERB}',), ('two{two,NUM}',), 0.12112436), (('covered{cover,VERB}',), ('mall{mall,NOUN}',), 1.6251656), (('covered{cover,VERB}',), ('.{.,PUNCT}',), 0.04328598), (('seemingly{seemingly,ADV}',), ('two{two,NUM}',), 0.2081395), (('seemingly{seemingly,ADV}',), ('clowns{clown,NOUN}',), 0.97819847), (('seemingly{seemingly,ADV}',), ('are{be,VERB}',), 0.09267419), (('seemingly{seemingly,ADV}',), ('performing{perform,VERB}',), 0.95946515), (('seemingly{seemingly,ADV}',), ('at{at,ADP}',), 0.6244178), (('seemingly{seemingly,ADV}',), ('a{a,DET}',), 0.06567784), (('seemingly{seemingly,ADV}',), ('.{.,PUNCT}',), 0.054194946), (('balancing{balancing,NOUN}',), ('clowns{clown,NOUN}',), 2.0483375), (('balancing{balancing,NOUN}',), ('are{be,VERB}',), 0.034783646), (('balancing{balancing,NOUN}',), ('performing{perform,VERB}',), 1.9255873), (('balancing{balancing,NOUN}',), ('at{at,ADP}',), 0.50547063), (('balancing{balancing,NOUN}',), ('a{a,DET}',), 0.03889305), (('balancing{balancing,NOUN}',), ('mall{mall,NOUN}',), 0.9030888), (('balancing{balancing,NOUN}',), ('.{.,PUNCT}',), 0.08027703), (('cane{cane,NOUN}',), ('two{two,NUM}',), 0.17697662), (('cane{cane,NOUN}',), ('clowns{clown,NOUN}',), 2.1429605), (('cane{cane,NOUN}',), ('performing{perform,VERB}',), 0.9584413), (('cane{cane,NOUN}',), ('mall{mall,NOUN}',), 2.0872283), (('cane{cane,NOUN}',), ('.{.,PUNCT}',), 0.044663053), (('being{be,VERB}',), ('are{be,VERB}',), 0.03726884), (('being{be,VERB}',), ('a{a,DET}',), 0.024664633), (('held{hold,VERB}',), ('at{at,ADP}',), 0.3852862), (('be{be,VERB}',), ('are{be,VERB}',), 0.05101802), (('be{be,VERB}',), ('a{a,DET}',), 0.037420195), (('be{be,VERB}',), ('.{.,PUNCT}',), 0.046677314), (('similarly{similarly,ADV}',), ('are{be,VERB}',), 0.03485295), (('similarly{similarly,ADV}',), ('a{a,DET}',), 0.041468114), (('similarly{similarly,ADV}',), ('.{.,PUNCT}',), 0.04452221), (('dressed{dress,VERB}',), ('two{two,NUM}',), 0.15766057), (('dressed{dress,VERB}',), ('clowns{clown,NOUN}',), 1.0876305), (('dressed{dress,VERB}',), ('.{.,PUNCT}',), 0.068661), (('man{man,NOUN}',), ('two{two,NUM}',), 0.5037433), (('man{man,NOUN}',), ('clowns{clown,NOUN}',), 1.0620116), (('man{man,NOUN}',), ('are{be,VERB}',), 0.038112305), (('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('sitting{sit,VERB}',), ('two{two,NUM}',), 0.18239166), (('sitting{sit,VERB}',), ('clowns{clown,NOUN}',), 1.0707021), (('sitting{sit,VERB}',), ('are{be,VERB}',), 0.11806056), (('sitting{sit,VERB}',), ('performing{perform,VERB}',), 1.6377041), (('sitting{sit,VERB}',), ('at{at,ADP}',), 0.6275062), (('sitting{sit,VERB}',), ('.{.,PUNCT}',), 0.066369), (('crossed{cross,VERB}',), ('clowns{clown,NOUN}',), 1.3042568), (('crossed{cross,VERB}',), ('are{be,VERB}',), 0.07000449), (('crossed{cross,VERB}',), ('performing{perform,VERB}',), 1.4001288), (('crossed{cro ...
# 6
# Texto:  An old man with a package poses in front of an advertisement.
# Hipótesis:  A man poses in front of an ad for beer.
# 14 12
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# umbral 0.027767448
# umbral 0.44962114
# umbral 0.46197766
# umbral 0.06826092
# umbral 0.26116693
# umbral 0.040675648
# umbral 0.031673584
# umbral 0.55228186
# umbral 0.35554817
# umbral 0.564345
# umbral 0.024446042
# [(('old{old,ADJ}',), ('man{man,NOUN}',), 1.2075737), (('old{old,ADJ}',), ('in{in,ADP}',), 0.08057333), (('old{old,ADJ}',), ('of{of,ADP}',), 0.06839696), (('old{old,ADJ}',), ('an{an,DET}',), 0.03910696), (('old{old,ADJ}',), ('for{for,ADP}',), 0.87653404), (('old{old,ADJ}',), ('beer{beer,NOUN}',), 1.2101572), (('man{man,NOUN}',), ('a{a,DET}',), 0.045506727), (('man{man,NOUN}',), ('man{man,NOUN}',), 3.2146893), (('man{man,NOUN}',), ('an{an,DET}',), 0.13301374), (('man{man,NOUN}',), ('ad{ad,NOUN}',), 0.84690475), (('man{man,NOUN}',), ('.{.,PUNCT}',), 0.024603078), (('package{package,NOUN}',), ('a{a,DET}',), 0.06476049), (('package{package,NOUN}',), ('poses{pose,VERB}',), 0.8777285), (('package{package,NOUN}',), ('in{in,ADP}',), 0.08570899), (('package{package,NOUN}',), ('front{front,NOUN}',), 0.32956988), (('package{package,NOUN}',), ('of{of,ADP}',), 0.0717113), (('package{package,NOUN}',), ('an{an,DET}',), 0.040920563), (('package{package,NOUN}',), ('ad{ad,NOUN}',), 1.1288989), (('package{package,NOUN}',), ('for{for,ADP}',), 0.4276999), (('package{package,NOUN}',), ('beer{beer,NOUN}',), 2.0878735), (('package{package,NOUN}',), ('.{.,PUNCT}',), 0.02715839), (('poses{pose,VERB}',), ('a{a,DET}',), 0.055900455), (('poses{pose,VERB}',), ('poses{pose,VERB}',), 2.5963767), (('poses{pose,VERB}',), ('in{in,ADP}',), 0.11471576), (('poses{pose,VERB}',), ('front{front,NOUN}',), 0.5826699), (('poses{pose,VERB}',), ('of{of,ADP}',), 0.0539893), (('poses{pose,VERB}',), ('ad{ad,NOUN}',), 1.4173936), (('poses{pose,VERB}',), ('for{for,ADP}',), 1.0717769), (('poses{pose,VERB}',), ('beer{beer,NOUN}',), 1.2933269), (('poses{pose,VERB}',), ('.{.,PUNCT}',), 0.08815411), (('front{front,NOUN}',), ('poses{pose,VERB}',), 0.5826699), (('front{front,NOUN}',), ('in{in,ADP}',), 0.28400853), (('front{front,NOUN}',), ('front{front,NOUN}',), 1.364832), (('front{front,NOUN}',), ('for{for,ADP}',), 0.40487793), (('front{front,NOUN}',), ('.{.,PUNCT}',), 0.069333464), (('advertisement{advertisement,NOUN}',), ('a{a,DET}',), 0.09523904), (('advertisement{advertisement,NOUN}',), ('man{man,NOUN}',), 0.46349478), (('advertisement{advertisement,NOUN}',), ('poses{pose,VERB}',), 1.3920422), (('advertisement{advertisement,NOUN}',), ('in{in,ADP}',), 0.102438234), (('advertisement{advertisement,NOUN}',), ('front{front,NOUN}',), 0.37927774), (('advertisement{advertisement,NOUN}',), ('of{of,ADP}',), 0.16449118), (('advertisement{advertisement,NOUN}',), ('an{an,DET}',), 0.064466305), (('advertisement{advertisement,NOUN}',), ('ad{ad,NOUN}',), 2.146057), (('advertisement{advertisement,NOUN}',), ('for{for,ADP}',), 1.3751279), (('advertisement{advertisement,NOUN}',), ('beer{beer,NOUN}',), 2.043711), (('advertisement{advertisement,NOUN}',), ('.{.,PUNCT}',), 0.035334684)]
# 7
# Texto:  People dressed in traditional Japanese garb walk in a procession through a courtyard paved with paving stones.
# Hipótesis:  People dressed in Japanese clothing walk through a courtyard.
# 19 11
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# umbral 0.26853514
# umbral 0.5604123
# umbral 0.13899331
# umbral 0.91833615
# umbral 0.54278374
# umbral 0.8577497
# umbral 0.24437642
# umbral 0.016493194
# umbral 0.99813163
# umbral 0.03792478
# [(('people{people,NOUN}',), ('people{people,NOUN}',), 2.1025875), (('people{people,NOUN}',), ('a{a,DET}',), 0.07060491), (('dressed{dress,VERB}',), ('people{people,NOUN}',), 0.4737378), (('dressed{dress,VERB}',), ('dressed{dress,VERB}',), 2.1873593), (('dressed{dress,VERB}',), ('clothing{clothing,NOUN}',), 1.8281028), (('dressed{dress,VERB}',), ('.{.,PUNCT}',), 0.068661), (('traditional{traditional,ADJ}',), ('japanese{japanese,ADJ}',), 2.0528014), (('japanese{japanese,ADJ}',), ('people{people,NOUN}',), 0.4571987), (('japanese{japanese,ADJ}',), ('dressed{dress,VERB}',), 0.9085826), (('japanese{japanese,ADJ}',), ('japanese{japanese,ADJ}',), 6.320044), (('japanese{japanese,ADJ}',), ('clothing{clothing,NOUN}',), 0.736859), (('japanese{japanese,ADJ}',), ('a{a,DET}',), 0.02077661), (('japanese{japanese,ADJ}',), ('.{.,PUNCT}',), 0.052214973), (('garb{garb,NOUN}',), ('people{people,NOUN}',), 0.52141476), (('garb{garb,NOUN}',), ('dressed{dress,VERB}',), 1.92744), (('garb{garb,NOUN}',), ('japanese{japanese,ADJ}',), 1.0844102), (('garb{garb,NOUN}',), ('clothing{clothing,NOUN}',), 1.8354858), (('garb{garb,NOUN}',), ('.{.,PUNCT}',), 0.072986245), (('walk{walk,VERB}',), ('dressed{dress,VERB}',), 0.6469032), (('walk{walk,VERB}',), ('in{in,ADP}',), 0.29632303), (('walk{walk,VERB}',), ('clothing{clothing,NOUN}',), 0.59228987), (('walk{walk,VERB}',), ('walk{walk,NOUN}',), 3.9785938), (('walk{walk,VERB}',), ('through{through,ADP}',), 0.9783423), (('walk{walk,VERB}',), ('a{a,DET}',), 0.029906627), (('walk{walk,VERB}',), ('courtyard{courtyard,NOUN}',), 1.2147596), (('walk{walk,VERB}',), ('.{.,PUNCT}',), 0.12841147), (('procession{procession,NOUN}',), ('dressed{dress,VERB}',), 0.68852156), (('procession{procession,NOUN}',), ('in{in,ADP}',), 0.16843237), (('procession{procession,NOUN}',), ('clothing{clothing,NOUN}',), 0.7336338), (('procession{procession,NOUN}',), ('walk{walk,NOUN}',), 2.2488995), (('procession{procession,NOUN}',), ('through{through,ADP}',), 0.6075332), (('procession{procession,NOUN}',), ('courtyard{courtyard,NOUN}',), 1.2940162), (('procession{procession,NOUN}',), ('.{.,PUNCT}',), 0.04997713), (('courtyard{courtyard,NOUN}',), ('dressed{dress,VERB}',), 0.75599474), (('courtyard{courtyard,NOUN}',), ('in{in,ADP}',), 0.4581208), (('courtyard{courtyard,NOUN}',), ('clothing{clothing,NOUN}',), 0.87196004), (('courtyard{courtyard,NOUN}',), ('walk{walk,NOUN}',), 1.2147596), (('courtyard{courtyard,NOUN}',), ('through{through,ADP}',), 0.3620167), (('courtyard{courtyard,NOUN}',), ('courtyard{courtyard,NOUN}',), 3.7990172), (('paved{pave,VERB}',), ('dressed{dress,VERB}',), 0.65001416), (('paved{pave,VERB}',), ('in{in,ADP}',), 0.48615792), (('paved{pave,VERB}',), ('clothing{clothing,NOUN}',), 0.70914394), (('paved{pave,VERB}',), ('walk{walk,NOUN}',), 1.8089684), (('paved{pave,VERB}',), ('through{through,ADP}',), 0.6586629), (('paved{pave,VERB}',), ('a{a,DET}',), 0.018241923), (('paved{pave,VERB}',), ('courtyard{courtyard,NOUN}',), 3.0695388), (('paved{pave,VERB}',), ('.{.,PUNCT}',), 0.05187636), (('paving{pave,VERB}',), ('dressed{dress,VERB}',), 0.61377263), (('paving{pave,VERB}',), ('in{in,ADP}',), 0.21904054), (('paving{pave,VERB}',), ('japanese{japanese,ADJ}',), 1.2298843), (('paving{pave,VERB}',), ('clothing{clothing,NOUN}',), 0.69436234), (('paving{pave,VERB}',), ('walk{walk,NOUN}',), 1.4636577), (('paving{pave,VERB}',), ('through{through,ADP}',), 0.33547294), (('paving{pave,VERB}',), ('courtyard{courtyard,NOUN}',), 2.5599716), (('stones{stone,NOUN}',), ('japanese{japanese,ADJ}',), 1.6638613), (('stones{stone,NOUN}',), ('clothing{clothing,NOUN}',), 0.5963376), (('stones{stone,NOUN}',), ('a{a,DET}',), 0.021233791), (('stones{stone,NOUN}',), ('courtyard{courtyard,NOUN}',), 1.4784123)]
# 8
# Texto:  Two children play in the snow by the side of the road.
# Hipótesis:  Kids are enjoying the cold weather.
# 14 8
# umbral 0.51884794
# umbral 0.012685795
# umbral 0.3306569
# umbral 0.014735515
# umbral 0.55332255
# umbral 0.5174719
# umbral 0.02647985
# umbral 0.51884794
# umbral 0.012685795
# umbral 0.3306569
# umbral 0.014735515
# umbral 0.55332255
# umbral 0.5174719
# umbral 0.02647985
# umbral 0.51884794
# umbral 0.012685795
# umbral 0.3306569
# umbral 0.014735515
# umbral 0.55332255
# umbral 0.5174719
# umbral 0.02647985
# umbral 0.51884794
# umbral 0.012685795
# umbral 0.3306569
# umbral 0.014735515
# umbral 0.55332255
# umbral 0.5174719
# umbral 0.02647985
# umbral 0.51884794
# umbral 0.012685795
# umbral 0.3306569
# umbral 0.014735515
# umbral 0.55332255
# umbral 0.5174719
# umbral 0.02647985
# [(('children{child,NOUN}',), ('kids{kid,NOUN}',), 4.0205507), (('children{child,NOUN}',), ('are{be,VERB}',), 0.048274748), (('children{child,NOUN}',), ('enjoying{enjoy,VERB}',), 0.65594226), (('play{play,VERB}',), ('kids{kid,NOUN}',), 0.687949), (('play{play,VERB}',), ('are{be,VERB}',), 0.05400061), (('play{play,VERB}',), ('enjoying{enjoy,VERB}',), 1.6195196), (('play{play,VERB}',), ('cold{cold,ADJ}',), 0.90246445), (('play{play,VERB}',), ('weather{weather,NOUN}',), 0.963547), (('play{play,VERB}',), ('.{.,PUNCT}',), 0.0857279), (('snow{snow,NOUN}',), ('enjoying{enjoy,VERB}',), 0.71868414), (('snow{snow,NOUN}',), ('the{the,DET}',), 0.03503673), (('snow{snow,NOUN}',), ('cold{cold,ADJ}',), 3.997687), (('snow{snow,NOUN}',), ('weather{weather,NOUN}',), 3.41846), (('snow{snow,NOUN}',), ('.{.,PUNCT}',), 0.087892324), (('side{side,NOUN}',), ('the{the,DET}',), 0.027951961), (('side{side,NOUN}',), ('.{.,PUNCT}',), 0.027750704), (('road{road,NOUN}',), ('enjoying{enjoy,VERB}',), 0.5399561), (('road{road,NOUN}',), ('the{the,DET}',), 0.06824477), (('road{road,NOUN}',), ('cold{cold,ADJ}',), 0.9124772), (('road{road,NOUN}',), ('weather{weather,NOUN}',), 1.0493383), (('road{road,NOUN}',), ('.{.,PUNCT}',), 0.055114232)]
# 9
# Texto:  Blond-haired girl wearing a bicycle helmet, a black t-shirt that reads "Twizzlers" and a printed dog tag necklace around her neck.
# Hipótesis:  a girl with a helmet wears a dog tag
# 30 10
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# umbral 0.028806912
# umbral 0.75627583
# umbral 0.009953827
# umbral 0.028806912
# umbral 0.96309435
# umbral 0.46884185
# umbral 0.028806912
# umbral 0.8504347
# umbral 0.9368075
# [(('blond{blond,ADJ}',), ('girl{girl,NOUN}',), 2.0923069), (('blond{blond,ADJ}',), ('with{with,ADP}',), 0.017509086), (('blond{blond,ADJ}',), ('helmet{helmet,NOUN}',), 1.7169961), (('blond{blond,ADJ}',), ('wears{wear,VERB}',), 0.87260115), (('blond{blond,ADJ}',), ('dog{dog,NOUN}',), 1.0088459), (('haired{haired,ADJ}',), ('girl{girl,NOUN}',), 1.380595), (('haired{haired,ADJ}',), ('with{with,ADP}',), 0.012521546), (('haired{haired,ADJ}',), ('helmet{helmet,NOUN}',), 1.1866988), (('haired{haired,ADJ}',), ('wears{wear,VERB}',), 0.55764914), (('haired{haired,ADJ}',), ('dog{dog,NOUN}',), 0.8851721), (('girl{girl,NOUN}',), ('a{a,DET}',), 0.03230063), (('girl{girl,NOUN}',), ('girl{girl,NOUN}',), 4.7579765), (('girl{girl,NOUN}',), ('with{with,ADP}',), 0.019226756), (('girl{girl,NOUN}',), ('a{a,DET}',), 0.03230063), (('girl{girl,NOUN}',), ('a{a,DET}',), 0.03230063), (('girl{girl,NOUN}',), ('dog{dog,NOUN}',), 1.5369111), (('wearing{wear,VERB}',), ('with{with,ADP}',), 0.019864088), (('wearing{wear,VERB}',), ('helmet{helmet,NOUN}',), 1.4959906), (('wearing{wear,VERB}',), ('wears{wear,VERB}',), 1.0298493), (('bicycle{bicycle,NOUN}',), ('girl{girl,NOUN}',), 1.0950412), (('bicycle{bicycle,NOUN}',), ('helmet{helmet,NOUN}',), 1.9792799), (('bicycle{bicycle,NOUN}',), ('dog{dog,NOUN}',), 2.28535), (('bicycle{bicycle,NOUN}',), ('tag{tag,NOUN}',), 2.5981343), (('helmet{helmet,NOUN}',), ('with{with,ADP}',), 0.02826067), (('helmet{helmet,NOUN}',), ('helmet{helmet,NOUN}',), 4.0930676), (('helmet{helmet,NOUN}',), ('wears{wear,VERB}',), 1.8407792), (('helmet{helmet,NOUN}',), ('dog{dog,NOUN}',), 1.196682), (('helmet{helmet,NOUN}',), ('tag{tag,NOUN}',), 1.5289258), (('black{black,ADJ}',), ('girl{girl,NOUN}',), 1.343003), (('black{black,ADJ}',), ('with{with,ADP}',), 0.0127584385), (('black{black,ADJ}',), ('helmet{helmet,NOUN}',), 1.2379841), (('black{black,ADJ}',), ('wears{wear,VERB}',), 0.66085416), (('t{t,NOUN}',), ('a{a,DET}',), 0.059098095), (('t{t,NOUN}',), ('with{with,ADP}',), 0.038860977), (('t{t,NOUN}',), ('a{a,DET}',), 0.059098095), (('t{t,NOUN}',), ('helmet{helmet,NOUN}',), 1.7959964), (('t{t,NOUN}',), ('wears{wear,VERB}',), 1.139242), (('t{t,NOUN}',), ('a{a,DET}',), 0.059098095), (('t{t,NOUN}',), ('dog{dog,NOUN}',), 1.272677), (('t{t,NOUN}',), ('tag{tag,NOUN}',), 1.4729315), (('shirt{shirt,NOUN}',), ('with{with,ADP}',), 0.032122858), (('shirt{shirt,NOUN}',), ('helmet{helmet,NOUN}',), 2.3413272), (('shirt{shirt,NOUN}',), ('wears{wear,VERB}',), 1.4746046), (('that{that,ADJ}',), ('a{a,DET}',), 0.04694757), (('that{that,ADJ}',), ('a{a,DET}',), 0.04694757), (('that{that,ADJ}',), ('a{a,DET}',), 0.04694757), (('reads{read,VERB}',), ('a{a,DET}',), 0.098470785), (('reads{read,VERB}',), ('with{with,ADP}',), 0.014594785), (('reads{read,VERB}',), ('a{a,DET}',), 0.098470785), (('reads{read,VERB}',), ('helmet{helmet,NOUN}',), 1.1854774), (('reads{read,VERB}',), ('wears{wear,VERB}',), 0.6892313), (('reads{read,VERB}',), ('a{a,DET}',), 0.098470785), (('reads{read,VERB}',), ('dog{dog,NOUN}',), 1.3824284), (('reads{read,VERB}',), ('tag{tag,NOUN}',), 2.117981), (('twizzlers{twizzler,NOUN}',), ('a{a,DET}',), 0.035158508), (('twizzlers{twizzler,NOUN}',), ('girl{girl,NOUN}',), 1.2035328), (('twizzlers{twizzler,NOUN}',), ('a{a,DET}',), 0.035158508), (('twizzlers{twizzler,NOUN}',), ('helmet{helmet,NOUN}',), 1.1636598), (('twizzlers{twizzler,NOUN}',), ('wears{wear,VERB}',), 0.4782337), (('twizzlers{twizzler,NOUN}',), ('a{a,DET}',), 0.035158508), (('twizzlers{twizzler,NOUN}',), ('dog{dog,NOUN}',), 1.3879627), (('twizzlers{twizzler,NOUN}',), ('tag{tag,NOUN}',), 1.8699608), (('printed{printed,ADJ}',), ('a{a,DET}',), 0.035257146), (('printed{printed,ADJ}',), ('a{a,DET}',), 0.035257146), (('printed{printed,ADJ}',), ('helmet{helmet,NOUN}',), 1.0105313), (('printed{printed,ADJ}',), ('a{a,DET}',), 0.035257146), (('printed{printed,ADJ}',), ('tag{tag,NOUN}',), 1.1283535), (('dog{dog,NOUN}',), ('a{a,DET}',), 0.1289273), (('dog{dog,NOUN}',), ('girl{girl,NOUN}',), 1.5369111), (('dog{ ...
# 10
# ...
# 95
# Texto:  A group of men in blue shirts, banded hats, and red bandannas stand in a group.
# Hipótesis:  a bunch of guys in colorful clothes stand together
# 20 10
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# umbral 0.01716898
# umbral 0.33471292
# umbral 0.030928439
# umbral 0.7342454
# umbral 0.045027647
# umbral 0.627091
# umbral 0.46967164
# umbral 0.36255732
# umbral 0.1204938
# [(('group{group,NOUN}',), ('a{a,DET}',), 0.047737908), (('group{group,NOUN}',), ('bunch{bunch,NOUN}',), 1.0267963), (('group{group,NOUN}',), ('of{of,ADP}',), 0.11252676), (('group{group,NOUN}',), ('guys{guy,NOUN}',), 1.7791334), (('group{group,NOUN}',), ('together{together,ADV}',), 0.36162993), (('men{man,NOUN}',), ('a{a,DET}',), 0.054610066), (('men{man,NOUN}',), ('bunch{bunch,NOUN}',), 1.3836303), (('men{man,NOUN}',), ('of{of,ADP}',), 0.08170531), (('men{man,NOUN}',), ('guys{guy,NOUN}',), 4.384147), (('men{man,NOUN}',), ('clothes{clothe,NOUN}',), 0.6983067), (('men{man,NOUN}',), ('together{together,ADV}',), 0.5319377), (('blue{blue,ADJ}',), ('in{in,ADP}',), 0.08334409), (('blue{blue,ADJ}',), ('colorful{colorful,ADJ}',), 2.4574785), (('blue{blue,ADJ}',), ('stand{stand,VERB}',), 0.753816), (('shirts{shirt,NOUN}',), ('bunch{bunch,NOUN}',), 0.53446126), (('shirts{shirt,NOUN}',), ('of{of,ADP}',), 0.041056767), (('shirts{shirt,NOUN}',), ('guys{guy,NOUN}',), 1.255066), (('shirts{shirt,NOUN}',), ('in{in,ADP}',), 0.074413456), (('shirts{shirt,NOUN}',), ('colorful{colorful,ADJ}',), 0.9595202), (('shirts{shirt,NOUN}',), ('clothes{clothe,NOUN}',), 2.01102), (('shirts{shirt,NOUN}',), ('stand{stand,VERB}',), 0.4856087), (('shirts{shirt,NOUN}',), ('together{together,ADV}',), 0.24774726), (('banded{band,VERB}',), ('a{a,DET}',), 0.019234458), (('banded{band,VERB}',), ('bunch{bunch,NOUN}',), 0.5369574), (('banded{band,VERB}',), ('of{of,ADP}',), 0.036302812), (('banded{band,VERB}',), ('guys{guy,NOUN}',), 1.057925), (('banded{band,VERB}',), ('colorful{colorful,ADJ}',), 1.0042797), (('banded{band,VERB}',), ('clothes{clothe,NOUN}',), 0.9554443), (('banded{band,VERB}',), ('stand{stand,VERB}',), 0.5102068), (('banded{band,VERB}',), ('together{together,ADV}',), 0.13751855), (('hats{hat,NOUN}',), ('bunch{bunch,NOUN}',), 0.580725), (('hats{hat,NOUN}',), ('of{of,ADP}',), 0.032308914), (('hats{hat,NOUN}',), ('guys{guy,NOUN}',), 1.3770398), (('hats{hat,NOUN}',), ('colorful{colorful,ADJ}',), 1.6995891), (('hats{hat,NOUN}',), ('clothes{clothe,NOUN}',), 1.6819941), (('hats{hat,NOUN}',), ('stand{stand,VERB}',), 0.5242405), (('hats{hat,NOUN}',), ('together{together,ADV}',), 0.24558575), (('red{red,ADJ}',), ('in{in,ADP}',), 0.04626515), (('red{red,ADJ}',), ('colorful{colorful,ADJ}',), 2.9668818), (('red{red,ADJ}',), ('stand{stand,VERB}',), 0.5298665), (('bandannas{bandanna,NOUN}',), ('bunch{bunch,NOUN}',), 0.46212173), (('bandannas{bandanna,NOUN}',), ('guys{guy,NOUN}',), 0.94399446), (('bandannas{bandanna,NOUN}',), ('in{in,ADP}',), 0.05475428), (('bandannas{bandanna,NOUN}',), ('colorful{colorful,ADJ}',), 1.5356613), (('bandannas{bandanna,NOUN}',), ('clothes{clothe,NOUN}',), 1.6073072), (('bandannas{bandanna,NOUN}',), ('stand{stand,VERB}',), 0.38666856), (('bandannas{bandanna,NOUN}',), ('together{together,ADV}',), 0.14781912), (('stand{stand,VERB}',), ('in{in,ADP}',), 0.14379393), (('stand{stand,VERB}',), ('clothes{clothe,NOUN}',), 0.5545969), (('stand{stand,VERB}',), ('stand{stand,VERB}',), 2.8700168), (('group{group,NOUN}',), ('a{a,DET}',), 0.047737908), (('group{group,NOUN}',), ('bunch{bunch,NOUN}',), 1.0267963), (('group{group,NOUN}',), ('of{of,ADP}',), 0.11252676), (('group{group,NOUN}',), ('guys{guy,NOUN}',), 1.7791334), (('group{group,NOUN}',), ('together{together,ADV}',), 0.36162993)]
# 96
# Texto:  A woman holding a newborn baby.
# Hipótesis:  woman holds baby
# 8 4
# umbral 1.0730822
# umbral 0.38352785
# umbral 1.4585838
# umbral 1.0730822
# umbral 0.38352785
# umbral 1.4585838
# umbral 1.0730822
# umbral 0.38352785
# umbral 1.4585838
# umbral 1.0730822
# umbral 0.38352785
# umbral 1.4585838
# [(('woman{woman,NOUN}',), ('woman{woman,NOUN}',), 3.8512385), (('woman{woman,NOUN}',), ('baby{baby,NOUN}',), 1.6930568), (('holding{hold,VERB}',), ('holds{hold,VERB}',), 1.4375775), (('newborn{newborn,ADJ}',), ('woman{woman,NOUN}',), 1.752863), (('newborn{newborn,ADJ}',), ('holds{hold,VERB}',), 0.5128677), (('newborn{newborn,ADJ}',), ('baby{baby,NOUN}',), 3.9640918), (('baby{baby,NOUN}',), ('woman{woman,NOUN}',), 1.6930568), (('baby{baby,NOUN}',), ('holds{hold,VERB}',), 0.3975036), (('baby{baby,NOUN}',), ('baby{baby,NOUN}',), 4.0617437)]
# 97
# Texto:  A skateboarding youth does a trick on a rail.
# Hipótesis:  A man painting a tree.
# 11 7
# umbral 0.031707592
# umbral 0.38242456
# umbral 1.0330174
# umbral 0.031707592
# umbral 0.70015895
# umbral 0.04275529
# umbral 0.031707592
# umbral 0.38242456
# umbral 1.0330174
# umbral 0.031707592
# umbral 0.70015895
# umbral 0.04275529
# umbral 0.031707592
# umbral 0.38242456
# umbral 1.0330174
# umbral 0.031707592
# umbral 0.70015895
# umbral 0.04275529
# umbral 0.031707592
# umbral 0.38242456
# umbral 1.0330174
# umbral 0.031707592
# umbral 0.70015895
# umbral 0.04275529
# umbral 0.031707592
# umbral 0.38242456
# umbral 1.0330174
# umbral 0.031707592
# umbral 0.70015895
# umbral 0.04275529
# [(('skateboarding{skateboard,VERB}',), ('man{man,NOUN}',), 0.69026446), (('skateboarding{skateboard,VERB}',), ('painting{paint,VERB}',), 2.269264), (('skateboarding{skateboard,VERB}',), ('tree{tree,NOUN}',), 1.2245793), (('skateboarding{skateboard,VERB}',), ('.{.,PUNCT}',), 0.115145214), (('youth{youth,NOUN}',), ('man{man,NOUN}',), 1.4238927), (('youth{youth,NOUN}',), ('tree{tree,NOUN}',), 0.9288787), (('does{do,VERB}',), ('a{a,DET}',), 0.08768483), (('does{do,VERB}',), ('man{man,NOUN}',), 0.6938042), (('does{do,VERB}',), ('painting{paint,VERB}',), 1.9242324), (('does{do,VERB}',), ('a{a,DET}',), 0.08768483), (('does{do,VERB}',), ('tree{tree,NOUN}',), 0.7262974), (('does{do,VERB}',), ('.{.,PUNCT}',), 0.14751881), (('trick{trick,NOUN}',), ('a{a,DET}',), 0.055326235), (('trick{trick,NOUN}',), ('man{man,NOUN}',), 0.44543037), (('trick{trick,NOUN}',), ('painting{paint,VERB}',), 3.8391101), (('trick{trick,NOUN}',), ('a{a,DET}',), 0.055326235), (('trick{trick,NOUN}',), ('tree{tree,NOUN}',), 1.5664136), (('rail{rail,NOUN}',), ('painting{paint,VERB}',), 1.2997526), (('rail{rail,NOUN}',), ('tree{tree,NOUN}',), 2.3075325)]
# 98
# Texto:  Four children are playing in some water.
# Hipótesis:  The children are doing chores.
# 9 7
# umbral 0.005524452
# umbral 0.87833655
# umbral 0.035242874
# umbral 0.39518312
# umbral 0.9061586
# umbral 0.027308691
# umbral 0.005524452
# umbral 0.87833655
# umbral 0.035242874
# umbral 0.39518312
# umbral 0.9061586
# umbral 0.027308691
# umbral 0.005524452
# umbral 0.87833655
# umbral 0.035242874
# umbral 0.39518312
# umbral 0.9061586
# umbral 0.027308691
# umbral 0.005524452
# umbral 0.87833655
# umbral 0.035242874
# umbral 0.39518312
# umbral 0.9061586
# umbral 0.027308691
# [(('children{child,NOUN}',), ('children{child,NOUN}',), 4.0551147), (('children{child,NOUN}',), ('are{be,VERB}',), 0.048274748), (('children{child,NOUN}',), ('chores{chore,NOUN}',), 1.0565162), (('are{be,VERB}',), ('are{be,VERB}',), 0.03777049), (('playing{play,VERB}',), ('are{be,VERB}',), 0.06546676), (('playing{play,VERB}',), ('doing{do,VERB}',), 1.4925318), (('playing{play,VERB}',), ('chores{chore,NOUN}',), 2.450452), (('playing{play,VERB}',), ('.{.,PUNCT}',), 0.07135111), (('water{water,NOUN}',), ('the{the,DET}',), 0.012969736), (('water{water,NOUN}',), ('doing{do,VERB}',), 0.61060596), (('water{water,NOUN}',), ('chores{chore,NOUN}',), 1.9988189), (('water{water,NOUN}',), ('.{.,PUNCT}',), 0.042502314)]
# 99
# Texto:  Three men dressed in suits and ties clasps their raised hands while standing in front of corporate logos.
# Hipótesis:  One of the men is actually sasquatch.
# 20 9
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# umbral 0.17676389
# umbral 0.032310057
# umbral 0.010375739
# umbral 0.7044126
# umbral 0.03919603
# umbral 0.47633818
# umbral 0.69899863
# umbral 0.035264105
# [(('men{man,NOUN}',), ('one{one,NUM}',), 1.236715), (('men{man,NOUN}',), ('of{of,ADP}',), 0.08170531), (('men{man,NOUN}',), ('men{man,NOUN}',), 4.792034), (('men{man,NOUN}',), ('is{be,VERB}',), 0.054809146), (('men{man,NOUN}',), ('actually{actually,ADV}',), 0.8370316), (('men{man,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.1136138), (('dressed{dress,VERB}',), ('men{man,NOUN}',), 0.86627203), (('dressed{dress,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.1477855), (('dressed{dress,VERB}',), ('.{.,PUNCT}',), 0.068661), (('suits{suit,NOUN}',), ('of{of,ADP}',), 0.037813727), (('suits{suit,NOUN}',), ('men{man,NOUN}',), 1.7238415), (('suits{suit,NOUN}',), ('actually{actually,ADV}',), 0.50645465), (('suits{suit,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.5653723), (('suits{suit,NOUN}',), ('.{.,PUNCT}',), 0.07611021), (('ties{tie,NOUN}',), ('men{man,NOUN}',), 0.86022174), (('ties{tie,NOUN}',), ('actually{actually,ADV}',), 0.61327165), (('ties{tie,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.4185706), (('ties{tie,NOUN}',), ('.{.,PUNCT}',), 0.063790575), (('clasps{clasp,VERB}',), ('men{man,NOUN}',), 0.7075903), (('clasps{clasp,VERB}',), ('is{be,VERB}',), 0.060348812), (('clasps{clasp,VERB}',), ('actually{actually,ADV}',), 1.0283796), (('clasps{clasp,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.2757554), (('clasps{clasp,VERB}',), ('.{.,PUNCT}',), 0.050709862), (('their{-PRON-,ADJ}',), ('of{of,ADP}',), 0.055703808), (('raised{raise,VERB}',), ('the{the,DET}',), 0.018232234), (('raised{raise,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.3028688), (('hands{hand,NOUN}',), ('is{be,VERB}',), 0.07423799), (('hands{hand,NOUN}',), ('actually{actually,ADV}',), 0.72941285), (('hands{hand,NOUN}',), ('.{.,PUNCT}',), 0.040258016), (('standing{stand,VERB}',), ('the{the,DET}',), 0.028552579), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.16424847), (('standing{stand,VERB}',), ('actually{actually,ADV}',), 0.89404845), (('standing{stand,VERB}',), ('.{.,PUNCT}',), 0.05641907), (('front{front,NOUN}',), ('the{the,DET}',), 0.04491134), (('front{front,NOUN}',), ('.{.,PUNCT}',), 0.069333464), (('corporate{corporate,ADJ}',), ('one{one,NUM}',), 0.42551926), (('corporate{corporate,ADJ}',), ('of{of,ADP}',), 0.08098395), (('corporate{corporate,ADJ}',), ('men{man,NOUN}',), 1.121951), (('corporate{corporate,ADJ}',), ('is{be,VERB}',), 0.06381738), (('corporate{corporate,ADJ}',), ('actually{actually,ADV}',), 1.1807395), (('corporate{corporate,ADJ}',), ('sasquatch{sasquatch,NOUN}',), 1.4763253), (('logos{logo,NOUN}',), ('of{of,ADP}',), 0.069308355), (('logos{logo,NOUN}',), ('is{be,VERB}',), 0.063146405), (('logos{logo,NOUN}',), ('actually{actually,ADV}',), 1.1391402), (('logos{logo,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.8453801), (('logos{logo,NOUN}',), ('.{.,PUNCT}',), 0.07671367)]

# %%
df1 = pd.DataFrame(features, columns=list(todas_relaciones)+list(todos_conteos))
df1
# Out:
#     NOUN_NOUN  NOUN_ADJ  NOUN_VERB  NOUN_ADV  ADJ_NOUN   ADJ_ADJ  ADJ_VERB  \
# 0   28.645093  1.631951   9.032564  0.000000  6.144412  0.127508  0.000000
# 1   26.671300  3.984223   4.437697  0.000000  2.492923  8.615627  0.000000
# 2   14.880619  1.824592   3.687874  0.000000  5.383794  1.300978  3.665578
# 3    7.112267  0.000000   4.998954  0.000000  3.913144  0.000000  0.000000
# 4   14.623623  0.000000   1.083491  0.000000  1.657801  0.000000  0.000000
# ..        ...       ...        ...       ...       ...       ...       ...
# 95  22.531673  4.194771   1.396518  1.896350  0.000000  5.424360  1.283683
# 96  11.299096  0.000000   0.397504  0.000000  5.716955  0.000000  0.512868
# 97   6.672148  0.000000   5.138863  0.000000  0.000000  0.000000  0.000000
# 98   7.110450  0.000000   0.658881  0.000000  0.000000  0.000000  0.000000
# 99  13.319034  0.000000   0.192194  3.825311  2.598276  0.000000  0.063817
#
#     ADJ_ADV  VERB_NOUN  VERB_ADJ  ...  ADJ_VERB_  ADJ_ADV_  VERB_NOUN_  \
# 0   0.00000   4.677207  0.303176  ...          0         0           6
# 1   0.00000   9.887845  0.000000  ...          0         0          10
# 2   0.00000   1.199861  0.347017  ...          2         0           1
# 3   0.00000   4.153236  0.000000  ...          0         0           3
# 4   0.00000   3.077783  0.000000  ...          0         0           3
# ..      ...        ...       ...  ...        ...       ...         ...
# 95  0.00000   3.104924  1.004280  ...          2         0           4
# 96  0.00000   0.000000  0.000000  ...          1         0           0
# 97  0.00000   3.334945  0.000000  ...          0         0           4
# 98  0.00000   2.450452  0.000000  ...          0         0           1
# 99  1.18074   5.300272  0.000000  ...          1         1           5
#
#     VERB_ADJ_  VERB_VERB_  VERB_ADV_  ADV_NOUN_  ADV_ADJ_  ADV_VERB_  ADV_ADV_
# 0           1           1          0          0         0          0         0
# 1           0           2          0          0         0          0         0
# 2           1           1          0          0         0          0         0
# 3           0           8          0          0         0          0         0
# 4           0           2          0          2         0          1         0
# ..        ...         ...        ...        ...       ...        ...       ...
# 95          1           2          1          0         0          0         0
# 96          0           1          0          0         0          0         0
# 97          0           2          0          0         0          0         0
# 98          0           3          0          0         0          0         0
# 99          0           2          2          0         0          0         0
#
# [100 rows x 32 columns]

# %%
#df1.to_csv("indicadoresTipoPalabra_suma.csv")
df1.to_csv("TipoPalabra_conteos_umbral_mean.csv")

# %%
a=list(todas_relaciones)
a
# Out:
# ['NOUN_NOUN',
#  'NOUN_ADJ',
#  'NOUN_VERB',
#  'NOUN_ADV',
#  'ADJ_NOUN',
#  'ADJ_ADJ',
#  'ADJ_VERB',
#  'ADJ_ADV',
#  'VERB_NOUN',
#  'VERB_ADJ',
#  'VERB_VERB',
#  'VERB_ADV',
#  'ADV_NOUN',
#  'ADV_ADJ',
#  'ADV_VERB',
#  'ADV_ADV']
