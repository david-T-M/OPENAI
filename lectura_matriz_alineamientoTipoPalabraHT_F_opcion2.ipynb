# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Lectura de matriz de alineamiento

# %%
df = pd.read_pickle("data/prueba100.pickle")
df
# Out:
#     Main index                                               Text  \
# 0            0  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, we...
# 1            1  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, dr...
# 2            2  [NULL{null,PROPN}, a{a,DET}, young{young,ADJ},...
# 3            3  [NULL{null,NOUN}, an{an,DET}, asian{asian,ADJ}...
# 4            4  [NULL{null,PROPN}, a{a,DET}, child{child,NOUN}...
# ..         ...                                                ...
# 95          95  [NULL{null,PROPN}, a{a,DET}, group{group,NOUN}...
# 96          96  [NULL{null,PROPN}, a{a,DET}, woman{woman,NOUN}...
# 97          97  [NULL{null,PROPN}, a{a,DET}, skateboarding{ska...
# 98          98  [NULL{null,ADJ}, four{four,NUM}, children{chil...
# 99          99  [NULL{null,ADJ}, three{three,NUM}, men{man,NOU...
#
#                                             Hipotesis  \
# 0   [NULL{null,PROPN}, a{a,DET}, person{person,NOU...
# 1   [NULL{null,PROPN}, a{a,DET}, guy{guy,NOUN}, in...
# 2   [NULL{null,PROPN}, a{a,DET}, boy{boy,NOUN}, sl...
# 3   [NULL{null,PROPN}, nobody{nobody,NOUN}, is{be,...
# 4   [NULL{null,PROPN}, the{the,DET}, child{child,N...
# ..                                                ...
# 95  [NULL{null,PROPN}, a{a,DET}, bunch{bunch,NOUN}...
# 96  [NULL{null,ADJ}, woman{woman,NOUN}, holds{hold...
# 97  [NULL{null,PROPN}, a{a,DET}, man{man,NOUN}, pa...
# 98  [NULL{null,PROPN}, the{the,DET}, children{chil...
# 99  [NULL{null,ADJ}, one{one,NUM}, of{of,ADP}, the...
#
#                                                R_Text  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                                 R_Hip  \
# 0   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 1   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 2   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 3   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 4   [[0.058692623, 0.05556845, -0.059916947, 0.000...
# ..                                                ...
# 95  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 96  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 97  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 98  [[0.058692623, 0.05556845, -0.059916947, 0.000...
# 99  [[0.058692623, 0.05556845, -0.059916947, 0.000...
#
#                                               M_Align  \
# 0   [[2.760008, 0.060492776, 0.7027438, 0.20296031...
# 1   [[2.760008, 0.060492776, 0.64837056, 0.2029603...
# 2   [[2.760008, 0.060492776, 0.4078711, 2.2245083,...
# 3   [[2.760008, 1.9305927, 0.10360007, 0.8346571, ...
# 4   [[2.760008, 0.033035405, 0.5160244, 0.10360007...
# ..                                                ...
# 95  [[2.760008, 0.060492776, 0.41359743, 0.0717519...
# 96  [[2.760008, 0.475788, 0.8695118, 0.72379255, 0...
# 97  [[2.760008, 0.060492776, 0.43997452, 1.9583746...
# 98  [[2.760008, 0.033035405, 0.44769567, 0.0726737...
# 99  [[2.760008, 0.38066497, 0.07175191, 0.03303540...
#
#                                   Prediction       Gold_label
# 0      [0.4928643, 0.50155383, 0.0055818837]  [1.0, 0.0, 0.0]
# 1         [0.4695498, 0.3973312, 0.13311893]  [1.0, 0.0, 0.0]
# 2   [1.4341879e-06, 8.787866e-05, 0.9999107]  [0.0, 0.0, 1.0]
# 3      [0.033964496, 0.008023773, 0.9580117]  [0.0, 0.0, 1.0]
# 4    [0.0027733932, 0.9895504, 0.0076761814]  [0.0, 1.0, 0.0]
# ..                                       ...              ...
# 95      [0.8000752, 0.17865694, 0.021267932]  [1.0, 0.0, 0.0]
# 96       [0.7528739, 0.18234292, 0.06478321]  [1.0, 0.0, 0.0]
# 97  [7.513892e-05, 0.0013085654, 0.99861634]  [0.0, 0.0, 1.0]
# 98     [0.034316223, 0.83774996, 0.12793382]  [0.0, 0.0, 1.0]
# 99     [0.0035314807, 0.5047337, 0.49173486]  [0.0, 0.0, 1.0]
#
# [100 rows x 8 columns]

# %%
indice=80

# %%
t=pd.DataFrame(df.at[indice,"Text"][1:])
h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
print(len(t))
print(len(h))
# Out:
# 27
# 10

# %%
ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
ma
# Out:
#                              (a{a,DET},)  (wide{wide,ADJ},)  \
# (stretching{stretch,VERB},)     0.010386           1.184598
# (high{high,ADJ},)               0.030831           1.153039
# (in{in,ADP},)                   0.005198           0.079509
# (the{the,DET},)                 0.002669           0.020597
# (air{air,NOUN},)                0.013591           0.473266
# (,{,,PUNCT},)                   0.007327           0.033722
# (the{the,DET},)                 0.002669           0.020597
# (player{player,NOUN},)          0.056943           0.444339
# (in{in,ADP},)                   0.005198           0.079509
# (the{the,DET},)                 0.002669           0.020597
# (black{black,ADJ},)             0.001848           0.476267
# (shirt{shirt,NOUN},)            0.008782           0.942430
# (reaches{reach,VERB},)          0.001440           0.363900
# (for{for,ADP},)                 0.035770           0.206066
# (the{the,DET},)                 0.002669           0.020597
# (football{football,NOUN},)      0.105436           1.057040
# (as{as,ADP},)                   0.008247           0.061460
# (the{the,DET},)                 0.002669           0.020597
# (other{other,ADJ},)             0.021638           0.013714
# (stretches{stretch,NOUN},)      0.001330           1.291042
# (toward{toward,ADP},)           0.023740           0.626373
# (him{-PRON-,PRON},)             0.053647           0.188691
# (to{to,PART},)                  0.005802           0.557874
# (steal{steal,VERB},)            0.077465           0.352242
# (it{-PRON-,PRON},)              0.045137           0.178238
# (away{away,ADV},)               0.023773           0.504053
# (.{.,PUNCT},)                   0.007956           0.037075
#
#                              (reciever{reciever,NOUN},)  (is{be,VERB},)  \
# (stretching{stretch,VERB},)                    1.735857        0.149124
# (high{high,ADJ},)                              0.591593        0.013040
# (in{in,ADP},)                                  0.166377        0.003406
# (the{the,DET},)                                0.023781        0.000754
# (air{air,NOUN},)                               1.605788        0.082114
# (,{,,PUNCT},)                                  0.107491        0.008989
# (the{the,DET},)                                0.023781        0.000754
# (player{player,NOUN},)                         1.988677        0.063981
# (in{in,ADP},)                                  0.166377        0.003406
# (the{the,DET},)                                0.023781        0.000754
# (black{black,ADJ},)                            0.638334        0.036005
# (shirt{shirt,NOUN},)                           1.068687        0.013465
# (reaches{reach,VERB},)                         0.511204        0.043780
# (for{for,ADP},)                                0.291421        0.057046
# (the{the,DET},)                                0.023781        0.000754
# (football{football,NOUN},)                     3.542150        0.119300
# (as{as,ADP},)                                  0.029654        0.007620
# (the{the,DET},)                                0.023781        0.000754
# (other{other,ADJ},)                            0.122579        0.015460
# (stretches{stretch,NOUN},)                     1.055358        0.125612
# (toward{toward,ADP},)                          0.667393        0.052017
# (him{-PRON-,PRON},)                            0.408027        0.070099
# (to{to,PART},)                                 0.397471        0.022197
# (steal{steal,VERB},)                           1.576606        0.146226
# (it{-PRON-,PRON},)                             0.666717        0.074399
# (away{away,ADV},)                              1.153097        0.111560
# (.{.,PUNCT},)                                  0.109208        0.010017
#
#                              (trying{try,VERB},)  (to{to,PART},)  \
# (stretching{stretch,VERB},)             1.742519        0.692935
# (high{high,ADJ},)                       0.615026        0.383762
# (in{in,ADP},)                           0.052404        0.121504
# (the{the,DET},)                         0.011835        0.033940
# (air{air,NOUN},)                        1.268169        0.571525
# (,{,,PUNCT},)                           0.033157        0.002385
# (the{the,DET},)                         0.011835        0.033940
# (player{player,NOUN},)                  0.731242        0.260214
# (in{in,ADP},)                           0.052404        0.121504
# (the{the,DET},)                         0.011835        0.033940
# (black{black,ADJ},)                     0.315897        0.138601
# (shirt{shirt,NOUN},)                    0.340892        0.117722
# (reaches{reach,VERB},)                  1.107881        0.788987
# (for{for,ADP},)                         1.370550        0.820893
# (the{the,DET},)                         0.011835        0.033940
# (football{football,NOUN},)              0.827778        0.439612
# (as{as,ADP},)                           0.087630        0.041677
# (the{the,DET},)                         0.011835        0.033940
# (other{other,ADJ},)                     0.072184        0.015661
# (stretches{stretch,NOUN},)              1.197254        0.628782
# (toward{toward,ADP},)                   1.586719        1.376339
# (him{-PRON-,PRON},)                     0.722864        0.135340
# (to{to,PART},)                          0.840172        1.072191
# (steal{steal,VERB},)                    2.137553        0.458721
# (it{-PRON-,PRON},)                      0.581559        0.193255
# (away{away,ADV},)                       1.584928        1.038143
# (.{.,PUNCT},)                           0.043456        0.013748
#
#                              (make{make,VERB},)  (a{a,DET},)  \
# (stretching{stretch,VERB},)            1.572089     0.010386
# (high{high,ADJ},)                      0.792993     0.030831
# (in{in,ADP},)                          0.119050     0.005198
# (the{the,DET},)                        0.015778     0.002669
# (air{air,NOUN},)                       1.243968     0.013591
# (,{,,PUNCT},)                          0.100405     0.007327
# (the{the,DET},)                        0.015778     0.002669
# (player{player,NOUN},)                 1.156313     0.056943
# (in{in,ADP},)                          0.119050     0.005198
# (the{the,DET},)                        0.015778     0.002669
# (black{black,ADJ},)                    0.504512     0.001848
# (shirt{shirt,NOUN},)                   0.692968     0.008782
# (reaches{reach,VERB},)                 0.716231     0.001440
# (for{for,ADP},)                        0.808678     0.035770
# (the{the,DET},)                        0.015778     0.002669
# (football{football,NOUN},)             1.905631     0.105436
# (as{as,ADP},)                          0.067325     0.008247
# (the{the,DET},)                        0.015778     0.002669
# (other{other,ADJ},)                    0.063079     0.021638
# (stretches{stretch,NOUN},)             0.914951     0.001330
# (toward{toward,ADP},)                  0.981130     0.023740
# (him{-PRON-,PRON},)                    0.481920     0.053647
# (to{to,PART},)                         0.539977     0.005802
# (steal{steal,VERB},)                   1.715353     0.077465
# (it{-PRON-,PRON},)                     0.714800     0.045137
# (away{away,ADV},)                      1.099921     0.023773
# (.{.,PUNCT},)                          0.086417     0.007956
#
#                              (catch{catch,NOUN},)  (.{.,PUNCT},)
# (stretching{stretch,VERB},)              1.537340       0.065337
# (high{high,ADJ},)                        0.709181       0.005825
# (in{in,ADP},)                            0.112441       0.016951
# (the{the,DET},)                          0.008679       0.000569
# (air{air,NOUN},)                         1.479097       0.022453
# (,{,,PUNCT},)                            0.071201       0.019622
# (the{the,DET},)                          0.008679       0.000569
# (player{player,NOUN},)                   0.877333       0.058702
# (in{in,ADP},)                            0.112441       0.016951
# (the{the,DET},)                          0.008679       0.000569
# (black{black,ADJ},)                      0.026928       0.050242
# (shirt{shirt,NOUN},)                     0.219078       0.075617
# (reaches{reach,VERB},)                   1.394112       0.015261
# (for{for,ADP},)                          1.165674       0.022266
# (the{the,DET},)                          0.008679       0.000569
# (football{football,NOUN},)               1.246938       0.137182
# (as{as,ADP},)                            0.068848       0.005807
# (the{the,DET},)                          0.008679       0.000569
# (other{other,ADJ},)                      0.052962       0.002815
# (stretches{stretch,NOUN},)               1.318963       0.034301
# (toward{toward,ADP},)                    1.821273       0.033513
# (him{-PRON-,PRON},)                      0.372541       0.038537
# (to{to,PART},)                           0.841484       0.013748
# (steal{steal,VERB},)                     1.504768       0.031208
# (it{-PRON-,PRON},)                       0.392330       0.077643
# (away{away,ADV},)                        1.405069       0.029571
# (.{.,PUNCT},)                            0.060602       0.032226

# %%
print(ma.mean())
print(ma.quantile(0.5))
# Out:
# (a{a,DET},)                   0.020919
# (wide{wide,ADJ},)             0.385460
# (reciever{reciever,NOUN},)    0.693295
# (is{be,VERB},)                0.045653
# (trying{try,VERB},)           0.643386
# (to{to,PART},)                0.355674
# (make{make,VERB},)            0.610209
# (a{a,DET},)                   0.020919
# (catch{catch,NOUN},)          0.623481
# (.{.,PUNCT},)                 0.029949
# dtype: float32
# (a{a,DET},)                   0.008247
# (wide{wide,ADJ},)             0.206066
# (reciever{reciever,NOUN},)    0.408027
# (is{be,VERB},)                0.022197
# (trying{try,VERB},)           0.581559
# (to{to,PART},)                0.138601
# (make{make,VERB},)            0.539977
# (a{a,DET},)                   0.008247
# (catch{catch,NOUN},)          0.372541
# (.{.,PUNCT},)                 0.022266
# Name: 0.5, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(ma, center=0, cmap='Blues_r', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Texto -> Hipótesis, tomando la longitud de la hipótesis en [NOUN,VERB,ADJ,ADV]

# %%
maximo=0
columna_v=""
indice_v=""
for c in ma.columns:
    if("VERB" in str(c)):
        if maximo<ma[c].max():
            maximo=ma[c].max()
            columna_v=str(c).split('\'')[1].split("{")[0]
            indice_v=str(ma[c].idxmax()).split('\'')[1].split("{")[0]
        #print(ma[c].max(),c,ma[c].idxmax())v
print(maximo, columna_v,indice_v)
# Out:
# 2.1375532150268555 trying steal

# %%
ma.quantile(0.25).values
# Out:
# array([0.00266908, 0.03539869, 0.10834929, 0.00551292, 0.04793005,
#        0.03394021, 0.07687081, 0.00266908, 0.05678199, 0.00581618])

# %%
def getRelacionesMA_corte(indice,df,corte):
    indices=[]
    todas_relaciones=[]
    todas_relacionest=[]
    print(len(df.at[indice,"Text"]),len(df.at[indice,"Hipotesis"]))
    if len(df.at[indice,"Text"]) > 42 and len(df.at[indice,"Hipotesis"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h[:41],index=t[:41])
    elif len(df.at[indice,"Text"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t[:41])
    elif len(df.at[indice,"Hipotesis"]) > 42:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h[:41],index=t)
    else:
        t=pd.DataFrame(df.at[indice,"Text"][1:])
        h=pd.DataFrame(df.at[indice,"Hipotesis"][1:])
        ma=pd.DataFrame(df.at[indice,"M_Align"][1:len(t)+1,1:len(h)+1],columns=h,index=t)
    #ma=ma/(ma.sum()).sum()
    c=ma.mean().values #.quantile(corte).values
    for index,strings in ma.iterrows():
        #print(index)
        for l in range(len(c)):
            if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):
                if 'NOUN' in str(ma.columns[l]) or 'VERB' in str(ma.columns[l]) or 'ADJ' in str(ma.columns[l]) or 'PRON' in str(ma.columns[l]) or 'ADV' in str(ma.columns[l]):
                    #print("columnna:",col,strings[col])
                    #print("umbral",c[l],strings[l])
                    if strings[l] >= c[l]:# >=1:
                        todas_relaciones.append((index,ma.columns[l],strings[l]))
    max_verb=0
    i_verbo=""
    c_verb=""
    for c in ma.columns:
        if("VERB" in str(c)):
            if max_verb<ma[c].max():
                max_verb=ma[c].max()
                c_verb=str(c).split('\'')[1].split("{")[0]
                i_verbo=str(ma[c].idxmax()).split('\'')[1].split("{")[0]
    #Dirección contraria
    mat=ma.transpose()
    #print(ma)
    #print(ma.shape)
    #print(mat)
    #print(mat.shape)
    c1=mat.mean().values #.quantile(corte).values
    for index,strings in mat.iterrows():
        for l in range(len(c1)):
            if 'NOUN' in str(index) or 'VERB' in str(index) or 'ADJ' in str(index) or 'PRON' in str(index) or 'ADV' in str(index):                
                if 'NOUN' in str(mat.columns[l]) or 'VERB' in str(mat.columns[l]) or 'ADJ' in str(mat.columns[l]) or 'PRON' in str(mat.columns[l]) or 'ADV' in str(mat.columns[l]):
                    #print("columnna:",col,strings[col])
                    #print("umbral",c[l])
                    if strings[l] >= c1[l]:# >=1:
                        todas_relacionest.append((index,mat.columns[l],strings[l]))
    labels=["NOUN","ADJ","VERB","ADV"]
    diccionarioTW = {}
    print(todas_relaciones)
    #todas_relaciones=list(set(todas_relaciones))
    for l1 in labels[:]:
        for l2 in labels[:]:
            diccionarioTW[l1+"_"+l2]=[]
    for tr in todas_relaciones:
        #print(tr[0],"-",tr[1])
        t_=str(tr[0]).split(",")
        pt=t_[1].split("}")[0]
        h_=str(tr[1]).split(",")
        #print(t_,h_,"h0",h_[0])
        ph=h_[1].split("}")[0]
        if pt=="PRON":
            pt="NOUN"
        if ph=="PRON":
            ph="NOUN"
        #diccionarioTW[pt+"_"+ph].append(tr[2])
        if pt+"_"+ph in diccionarioTW:
            diccionarioTW[pt+"_"+ph].append(tr[2])
    diccionarioTW_mean={}
    diccionarioTW_mean_n={}
    diccionarioTW_rel={}
    for k in diccionarioTW:
        if len(diccionarioTW[k])!=0:
            diccionarioTW_mean[k]=sum(diccionarioTW[k])#/len(diccionarioTW[k])
            diccionarioTW_mean_n[k+"_"]=len(diccionarioTW[k])#/ma.shape[0]
            diccionarioTW_rel[k+"_r"]=sum(diccionarioTW[k])/len(diccionarioTW[k])#/ma.shape[0]
        else:
            diccionarioTW_mean[k]=0
            diccionarioTW_mean_n[k+"_"]=0
            diccionarioTW_rel[k+"_r"]=0
            
    return diccionarioTW_mean,diccionarioTW_mean_n,todas_relaciones,todas_relacionest,diccionarioTW_rel,i_verbo,c_verb

# %% [markdown]
# # Lectura de los 100 pares de T y H (muestreo)

# %%
prueba=pd.read_csv("prueba.csv")

# %%
textos = prueba["sentence1"].to_list()
hipotesis = prueba["sentence2"].to_list()
print(textos)
print(hipotesis)
# Out:
# ['A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.', 'A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.', 'A young boy runs across a road in front of a sky blue building with barred windows.', 'An Asian woman is standing on a path with a basket on her head looking into a mirror she is holding in her hand.', 'A child in a maroon shirt playing next to a fountain.', 'man dressed in orange clothing with face covered seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall.', 'An old man with a package poses in front of an advertisement.', 'People dressed in traditional Japanese garb walk in a procession through a courtyard paved with paving stones.', 'Two children play in the snow by the side of the road.', 'Blond-haired girl wearing a bicycle helmet, a black t-shirt that reads "Twizzlers" and a printed dog tag necklace around her neck.', 'A fat woman wearing faint blue top is blowing soap bubble.', 'A father and his daughter are riding a lawn mover down a street while dressed in American colors.', 'Two men are drumming, one is standing and one is sitting down.', 'Three men are carrying a red bag into a boat with another person and boat in the background.', 'A woman wearing a red coat stands on a wood floor in front of several paintings while two girls sit on the floor at her feet.', 'The sun breaks through the trees as a child rides a swing.', 'A man wearing a shite short-sleeved shirt kisses a woman wearing a light pink jacket while standing on a public street.', 'Someone splashing in the water.', 'An elderly lady holding a scruffy dog and smiling contently.', 'An Asian woman in a purple shirt preparing a bowl of food for the younger Asian boy sitting near buy, while an Asian man eats a roll and prepares to take some food up with his chopsticks.', 'A woman is holding a microphone in one hand and her mouth is open.', 'A young girl in a white t-shirt and a blue skirt wearing a light colored hat stands in a river next to a big rock.', 'A gymnast using a set of paralleled bars.', 'A guy with a football, a crowd watching him.', 'Seven young girls are being creative and making posters.', 'An old man in a baseball hat and an old woman in a jean jacket are standing outside, but are covered mostly in shadow.', 'A man is throwing a small white ball at some red cups.', 'Several street vehicles pass by a traditional architecture style of Thailand.', 'Man and a woman at the side of a table covered in books.', 'A group of people wait to cross the street in new york', 'Two guys in blue shirts talking.', 'The child is hanging upside down with his legs over a pole.', 'Four young men stare up at a basketball hoop with no net, in an outdoor, urban basketball court.', 'A group of people celebrating in the street.', 'A man and a woman stand in front of a Christmas tree contemplating a single thought.', 'A casually dressed young blond woman is looking away sadly as couple near her are kissing.', 'Girls giving a presentation for a school class.', 'A man and a child painting a post.', 'A young boy holding a red toy wearing green snowman and reindeer pajamas with an older woman on a couch behind him.', 'A lady with blue jeans and a brown shirt is speaking on her cellphone on the second floor of the mall.', 'A person obscured in shadow in a gymnasium.', 'African woman walking through field.', 'Men are playing rugby while covered in mud.', 'A child with curly blond-hair looks at another child with long brown hair while sitting on a bench.', 'A shirtless man with cropped hair smokes a cigarette and ties a plastic bag.', 'A group of people stares at a wall that is filled with drawings in a building.', 'A girl with curly hair and wearing a patriotic shirt is looking at a monarch butterfly sitting on her left index finger.', 'The blue kayak is being ridden over a small waterfall.', 'A person in a large pink  ...
# ['A person in appropriate institution protection works with meals.', 'a guy in a red top and tie makes a speech', 'A boy sleeps in his bed.', 'Nobody is standing', 'The child is getting wet from the fountain.', 'Two clowns are performing at a mall.', 'A man poses in front of an ad for beer.', 'People dressed in Japanese clothing walk through a courtyard.', 'Kids are enjoying the cold weather.', 'a girl with a helmet wears a dog tag', 'A fat woman is wearing pants.', 'two men cut grass by hand', 'Two people are drumming.', 'A person drives away in a winnebago.', 'Woman takes a break at a museum while her children sit by her feet.', 'The child on the swing is a girl.', 'A man is kissing a woman', 'Someone is having a picnic near the lake.', 'a woman holding a scruffy cat', 'A woman is preparing food for a child.', 'A woman standing at a microphone', 'A girl is wearing a hat.', 'A young gymnast is performing.', 'There is a guy with a basketball.', 'Girls are making posters.', 'An old woman has a light jean jacket.', 'The man playing a game.', 'Vehicles are going down a street in Thailand.', 'People near a lot of reading materials.', 'Some of the people are wearing sunglasses.', 'Two men complimenting each other on their blue shirts.', 'There is an adult upside down.', 'A group of women playing basketball in a gym.', 'There is a celebration going on', 'Two people talk loudly in front of a cactus.', 'A woman looks away after recognizing her ex-boyfriend kissing his new girl.', 'The girls are inside a school.', 'The father and son are repairing the sign.', 'The older woman behind the young boy is his mother.', 'the lady is talking on her phone', 'The person is trying to be sneaky.', 'The african woman is looking for someone in the fields.', 'The men are perfectly free of mud.', 'The school kids are relaxing during recess.', 'The man is not wearing a shirt.', 'A group of people analyze art together', 'A girl captures a butterfly for a science fair project', 'A kayak is being ridden.', 'The person is alone in the middle of the ocean.', 'Young children open presents under a large Christmas tree.', 'A boy pitches the ball.', 'A raven haired woman is seen by the crowd holding a white opened umbrella.', 'A recently engaged couple embrace on the street.', 'A person rides a skateboard.', 'A girl jumping rope on Mars.', 'A woman rises from a chair', 'Three people in nature.', 'A bird is looking for food on a lake.', 'a singer is on american idol', 'An older man is sweeping his patio while a passerby enters a building', 'Two people are in a bike race.', 'The person is a woman.', 'Women are looking at books on sale at a library.', 'The dog is outside.', 'A woman in green opening a box while a half concealed man manipulates a handheld device.', 'The woman is not going to finish the race.', 'A man is making pottery.', 'A guy is riding the bus.', 'A person with a great tatto', 'A woman is wearing a mask', 'Four kids pose on a beach.', 'A woman is putting on mascara.', 'A man eats a hamburger while his friend asks for a bite.', 'The boy sitting on top of his dads truck.', 'A young couple is very much in love.', 'A man in red is holding out his hand.', 'A boy is running outside.', 'A woman is singing on stage.', 'The boy is walking outside.', 'The sports fans are wearing yellow.', 'A wide reciever is trying to make a catch.', 'A man has damaged something.', 'There are people outside.', 'A women observing a camera', 'A girl is playing the piano in her living room.', 'A boy dressed for summer in a green shirt and kahki shorts', 'A dog is on the beach.', 'A skier preparing a trick', 'Two fathers maneuver their baby strollers into a foyer.', 'The man has blue sunglasses.', 'A child does a cannonball into a pool.', 'Laura Bush is giving a talk about the importance of literacy to young people.', 'Men are in wetsuits', 'The batsman is on a different team than the others around the pitching mound.', 'A boy is watching a movie in his living room.', 'a bunch ...

# %%
import nltk, re, os
from nltk.corpus import wordnet as wn
import networkx as nx
from matplotlib import pyplot as plt

# %% [markdown]
# # Antonimia e hiponimia

# %%
def revision_ant_hipo(relaciones_alineadas,wn):
    sinonimos_words=[]
    antonimos_words=[]
    hyperonyms_words=[]
    hyponyms_words=[]
    relaciones_fuertes=[]
    verbos=[]
    for r_a in relaciones_alineadas[:]:
        sim=0
        sim_h=0
        cam_sh=0
        max_lch=0
        pal_sim_a=""
        pal_sim_b=""
        # pal_simp_a=""
        # pal_simp_b=""
        # pal_simsp_a=""
        # pal_simsp_b=""
        # pal_simlch_a=""
        # pal_simlch_b=""
        print(r_a[0],"a",r_a[1])
        word_t = str(r_a[0]).split('\'')[1]
        wt = word_t.split('{')[0]
        #lt = word_t.split('}')[0].split(',')[0].split('{')[1]
        print(word_t)
        print(word_t.split('}')[0].split(','))
        if len(word_t.split('}')[0].split(','))==2:
            pt = word_t.split('}')[0].split(',')[1]
        else:
            pt=""
        print(pt)
        w_in_text= wt + "," + pt
        #print(wt,lt,pt)
        word_h = str(r_a[1]).split('\'')[1]
        wh = word_h.split('{')[0] #palabra tal cual
        #lh = word_h.split('}')[0].split(',')[0].split('{')[1] #palabra lematizada
        print(word_h)
        if len(word_h.split('}')[0].split(','))==2:
            ph = word_h.split('}')[0].split(',')[1] # pos de la palabra
        else:
            ph=""
        print(ph)
        word = wh + "," + ph # palabra con el pos correspondiente
        #print(wh,lh,ph)
        ## buscamos medidas de las relaciones alineadas a traves de wordnet
        if pt == "NOUN" or pt=="PRON":
            w1_=wn.synsets(wt,wn.NOUN)
        elif pt == "VERB":
            w1_=wn.synsets(wt,wn.VERB)
        elif pt == "ADJ":
            w1_=wn.synsets(wt,wn.ADJ)
        elif pt == "ADV":
            w1_=wn.synsets(wt,wn.ADV)
        else:
            w1_=wn.synsets(wt)
        if ph == "NOUN" or ph=="PRON":
            w2_=wn.synsets(wh,wn.NOUN)
        elif ph == "VERB":
            w2_=wn.synsets(wh,wn.VERB)
        elif ph == "ADJ":
            w2_=wn.synsets(wh,wn.ADJ)
        elif ph == "ADV":
            w2_=wn.synsets(wh,wn.ADV)
        else:
            w2_=wn.synsets(wh)
        for a in w1_:
            for b in w2_:
                if pt==ph:            
                    #print(w_in_text,word)
                    #Busqueda en las definiciones
                    # defiiniciones=[]
                    # if wh in a.definition().split():
                    #     print("yes:",wh,a.definition().split())
                    if a.wup_similarity(b)>sim:
                        sim=a.wup_similarity(b)
                        pal_sim_a=a
                        pal_sim_b=b
                        
                    # if a.path_similarity(b, simulate_root=False)!=None:
                    #     if a.path_similarity(b, simulate_root=False)>sim_h:
                    #         sim_h=b.path_similarity(a, simulate_root=False)
                    #         pal_simp_a=a
                    #         pal_simp_b=b
                    # if a.shortest_path_distance(b)!=None:
                    #     if a.shortest_path_distance(b)>cam_sh:
                    #         cam_sh=a.shortest_path_distance(b)
                    #         pal_simsp_a=a
                    #         pal_simsp_b=b
                    # if a.pos()==b.pos():
                    #     if a.lch_similarity(b)>max_lch:
                    #         max_lch=a.lch_similarity(b)
                    #         pal_simlch_a=a
                    #         pal_simlch_b=b
        if pt==ph:
            if pt=="VERB":
                verbos.append((wt,wh,sim))
            if sim!=0:
                print("wup_sim:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,sim)
                if pal_sim_a.path_similarity(pal_sim_b, simulate_root=False)!=None:
                    print("path_sim:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.path_similarity(pal_sim_b, simulate_root=False))
                if pal_sim_a.shortest_path_distance(pal_sim_b)!=None:
                    print("spath:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.shortest_path_distance(pal_sim_b))
                if pal_sim_a.pos()==pal_sim_b.pos():
                    print("lch:","Palabra1: ",pal_sim_a,"Palabra2:",pal_sim_b,pal_sim_a.lch_similarity(pal_sim_b))
                
                #relaciones fuertes combinando las medidas de wordnet
                #wup nos ayuda a filtrar que tan similares son
                #distancia más corta nos ayuda a identificar que no se encuentren muy lejos en el arbol de wordnet
                #lch similarity ayuda a identificar que en la taxonomia no se encunetren alejados, para los que
                #tienen unj hiperonimo en comun

                if sim>0.5:
                    if pal_sim_a.shortest_path_distance(pal_sim_b)!=None:
                        if pal_sim_a.shortest_path_distance(pal_sim_b)<=7:
                            if pal_sim_a.pos()==pal_sim_b.pos():
                                if pal_sim_a.lch_similarity(pal_sim_b)<2.0:
                                    relaciones_fuertes.append((pal_sim_a,pal_sim_b))
                #else:
                #    relaciones_debiles.append((pal_sim_a,pal_sim_b,-sim))
                #Busqueda de relaciones de sinonimia y antonimia
                synonyms=[]
                antonyms=[]   
                for l in pal_sim_a.lemmas():
                    synonyms.append(l.name())
                    #print(l)
                    if l.antonyms():
                        #print(l.antonyms()[0])
                        antonyms.append(l.antonyms()[0].name())
                if wh in synonyms:
                    print("Sinonimo: ",wt,wh)
                    sinonimos_words.append((wt,wh))
                if wh in antonyms:
                    print("Antonimo: ",wt,wh)
                    antonimos_words.append((wt,wh))
                #Busqueda de relaciones de hiperonimia e hiponimia
                hyperonyms=pal_sim_a.hypernym_paths()
                for p in hyperonyms:
                    if pal_sim_b in p:
                        print("hiperonimo:",pal_sim_a,pal_sim_b,pal_sim_a.shortest_path_distance(pal_sim_b))
                        if(pal_sim_a.shortest_path_distance(pal_sim_b)!=0):
                            hyperonyms_words.append((wt,wh))
                        else:
                            sinonimos_words.append((wt,wh))
                hyponyms=pal_sim_b.hypernym_paths()
                for p in hyponyms:
                    if pal_sim_a in p:
                        print("Hiponimo:",pal_sim_a,pal_sim_b,pal_sim_b.shortest_path_distance(pal_sim_a))
                        if pal_sim_a.shortest_path_distance(pal_sim_b)!=0:
                            hyponyms_words.append((wt,wh))
                for lh in pal_sim_a.lowest_common_hypernyms(pal_sim_b):
                    print("minimos hyper",lh)
                    print("a->H",pal_sim_a.shortest_path_distance(lh))
                    print("b->H",pal_sim_b.shortest_path_distance(lh))
                print()
    print("sinonimos",len(set(sinonimos_words)),sinonimos_words)
    print("antonimos",len(set(antonimos_words)),antonimos_words)
    print("hyperonyms",len(set(hyperonyms_words)),hyperonyms_words)
    print("hyponyms",len(set(hyponyms_words)),hyponyms_words)
    print("relaciones fuertes:",relaciones_fuertes)
    #print("relaciones debiles:",relaciones_debiles)
    print("verbos: ",verbos)
    maxv=0
    for v in verbos:
        print(v)
        if(float(v[2])>maxv):
            maxv=v[2]
            v1=v[0]
            v2=v[1]
    #print(v1,v2)    
    return [len(set(sinonimos_words)),len(set(antonimos_words)),len(set(hyperonyms_words)),len(set(hyponyms_words)),len(set(relaciones_fuertes)),maxv]

# %%
import spacy

nlp = spacy.load("en_core_web_md")
doc = nlp("A man is not dressed in orange clothing seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r=token.text
print(r)
# Out:
# c:\Users\Ninja\anaconda3\lib\site-packages\torch\__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\tensor\python_tensor.cpp:453.)
#   _C._set_default_tensor_type(t)
# A a DET DT det X True True
# man man NOUN NN nsubjpass xxx True False
# is be AUX VBZ auxpass xx True True
# not not PART RB neg xxx True True
# dressed dress VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True True
# orange orange ADJ JJ amod xxxx True False
# clothing clothing NOUN NN pobj xxxx True False
# seemingly seemingly ADV RB advmod xxxx True False
# balancing balance VERB VBG advcl xxxx True False
# on on ADP IN prep xx True True
# a a DET DT det x True True
# cane cane NOUN NN pobj xxxx True False
# being be AUX VBG auxpass xxxx True True
# held hold VERB VBN acl xxxx True False
# be be AUX VB conj xx True True
# a a DET DT det x True True
# similarly similarly ADV RB advmod xxxx True False
# dressed dress VERB VBN amod xxxx True False
# man man NOUN NN attr xxx True False
# sitting sit VERB VBG acl xxxx True False
# crossed cross VERB VBD acl xxxx True False
# legged legged ADJ JJ oprd xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# ground ground NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# a a DET DT det x True True
# shopping shopping NOUN NN compound xxxx True False
# mall mall NOUN NN pobj xxxx True False
# dressed

# %%
import spacy
from spacy import displacy

# nlp = spacy.load("en_core_web_md")
# doc = nlp("A man is not dressed in orange clothing seemingly balancing on a cane being held be a similarly dressed man sitting crossed legged on the ground at a shopping mall")
# displacy.serve(doc, style="dep")

# %%
nlp = spacy.load("en_core_web_md")  # make sure to use larger package!
doc1 = nlp("An old man runs in front of an advertisement.")
doc2 = nlp("A man sleeps in front of an ad for beer.")
for token in doc1:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r_t=token
print(r_t)
for token in doc2:
    #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
    #        token.shape_, token.is_alpha, token.is_stop)
    if token.dep_=="ROOT":
        r_h=token
print(r_h)
# Similarity of two documents
print(doc1, "<->", doc2, doc1.similarity(doc2))
# Similarity of tokens and spans
french_fries = r_t
burgers = r_h
print(french_fries, "<->", burgers, french_fries.similarity(burgers))
# Out:
# An an DET DT det Xx True True
# old old ADJ JJ amod xxx True False
# man man NOUN NN nsubj xxx True False
# runs run VERB VBZ ROOT xxxx True False
# in in ADP IN prep xx True True
# front front NOUN NN pobj xxxx True True
# of of ADP IN prep xx True True
# an an DET DT det xx True True
# advertisement advertisement NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# runs
# sleeps
# An old man runs in front of an advertisement. <-> A man sleeps in front of an ad for beer. 0.9374918953004442
# runs <-> sleeps 0.30534598231315613

# %%
from sentence_transformers import SentenceTransformer, util, InputExample, losses
#Load the model(here we use minilm)
model = SentenceTransformer('all-MiniLM-L6-v2')
#We get the embeddings by calling model.encode()

# %% [markdown]
# # prueba

# %%
features=[]
length=len(textos)
for i in range(length):
#length=[4]
#for i in length:
    print(i)
    print("Texto: ",textos[i])
    print("Hipótesis: ",hipotesis[i])
    doc1 = nlp(textos[i])
    for token in doc1:
        #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        #        token.shape_, token.is_alpha, token.is_stop)
        if token.dep_=="ROOT":
            r_t=token
    doc2 = nlp(hipotesis[i])
    for token in doc2:
        if token.dep_=="ROOT":
            r_h=token
    #print("similaridad: ",doc1.similarity(doc2))
    todas_relaciones,todos_conteos,relaciones_alineadas,relaciones_alineadast,relatip_num,tverb,hverb=getRelacionesMA_corte(i,df,0.25)
    print(todas_relaciones)
    print("Relaciones",len(relaciones_alineadas),len(relaciones_alineadast))
    rel_semanticas=revision_ant_hipo(relaciones_alineadas,wn)
    print("semanticas",rel_semanticas)
    emb1 = model.encode(tverb)
    emb2 = model.encode(hverb)
    #Get the cosine similarity score between sentences
    cos_sim = util.cos_sim(emb1, emb2)
    similitud_verbos=float(cos_sim[0][0])
    print("verbos a comparar",tverb,hverb)
    features.append(list(todas_relaciones.values())+list(todos_conteos.values())+list(relatip_num.values())+rel_semanticas+[len(relaciones_alineadast)/len(relaciones_alineadas),similitud_verbos])
    #len((set(textos[i].split()).intersection(set(hipotesis[i]))))/len(set(textos[i].split()).union(set(hipotesis[i])))]) 
    #+rel_semanticast)#[doc1.similarity(doc2)]+)
# Out:
# 0
# Texto:  A man wearing a blue shirt, black apron, eyeglasses, and a mask is handling food in a tray.
# Hipótesis:  A person in appropriate institution protection works with meals.
# 23 11
# [(('man{man,NOUN}',), ('person{person,NOUN}',), 2.7393045), (('man{man,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.28043467), (('man{man,NOUN}',), ('institution{institution,NOUN}',), 0.68360347), (('man{man,NOUN}',), ('works{work,VERB}',), 0.86454284), (('wearing{wear,VERB}',), ('person{person,NOUN}',), 0.30613843), (('wearing{wear,VERB}',), ('protection{protection,NOUN}',), 0.9683174), (('blue{blue,ADJ}',), ('person{person,NOUN}',), 0.38392273), (('blue{blue,ADJ}',), ('institution{institution,NOUN}',), 0.7114139), (('blue{blue,ADJ}',), ('protection{protection,NOUN}',), 1.0381266), (('blue{blue,ADJ}',), ('meals{meal,NOUN}',), 0.79603136), (('shirt{shirt,NOUN}',), ('person{person,NOUN}',), 0.5483131), (('shirt{shirt,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.21762419), (('shirt{shirt,NOUN}',), ('institution{institution,NOUN}',), 0.5403721), (('shirt{shirt,NOUN}',), ('protection{protection,NOUN}',), 1.5583643), (('shirt{shirt,NOUN}',), ('meals{meal,NOUN}',), 0.81555146), (('black{black,ADJ}',), ('person{person,NOUN}',), 0.4654065), (('black{black,ADJ}',), ('appropriate{appropriate,ADJ}',), 0.12750843), (('black{black,ADJ}',), ('institution{institution,NOUN}',), 1.6096103), (('black{black,ADJ}',), ('protection{protection,NOUN}',), 1.1399006), (('apron{apron,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.22604023), (('apron{apron,NOUN}',), ('institution{institution,NOUN}',), 0.94798976), (('apron{apron,NOUN}',), ('protection{protection,NOUN}',), 1.5491754), (('apron{apron,NOUN}',), ('works{work,VERB}',), 1.4815819), (('apron{apron,NOUN}',), ('meals{meal,NOUN}',), 2.1444316), (('eyeglasses{eyeglass,NOUN}',), ('person{person,NOUN}',), 0.46568495), (('eyeglasses{eyeglass,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.2499403), (('eyeglasses{eyeglass,NOUN}',), ('institution{institution,NOUN}',), 1.0152488), (('eyeglasses{eyeglass,NOUN}',), ('protection{protection,NOUN}',), 1.2863016), (('eyeglasses{eyeglass,NOUN}',), ('works{work,VERB}',), 1.5609107), (('eyeglasses{eyeglass,NOUN}',), ('meals{meal,NOUN}',), 1.833542), (('mask{mask,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.21877745), (('mask{mask,NOUN}',), ('institution{institution,NOUN}',), 0.64354813), (('mask{mask,NOUN}',), ('protection{protection,NOUN}',), 1.6344744), (('mask{mask,NOUN}',), ('works{work,VERB}',), 1.5607735), (('mask{mask,NOUN}',), ('meals{meal,NOUN}',), 1.8941077), (('handling{handle,VERB}',), ('person{person,NOUN}',), 0.2892014), (('handling{handle,VERB}',), ('appropriate{appropriate,ADJ}',), 0.3031758), (('handling{handle,VERB}',), ('institution{institution,NOUN}',), 0.57469887), (('handling{handle,VERB}',), ('protection{protection,NOUN}',), 0.79171145), (('handling{handle,VERB}',), ('works{work,VERB}',), 2.0916288), (('handling{handle,VERB}',), ('meals{meal,NOUN}',), 1.7471396), (('food{food,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.27676764), (('food{food,NOUN}',), ('institution{institution,NOUN}',), 1.2851878), (('food{food,NOUN}',), ('protection{protection,NOUN}',), 1.0151858), (('food{food,NOUN}',), ('works{work,VERB}',), 2.1802423), (('food{food,NOUN}',), ('meals{meal,NOUN}',), 3.2426279), (('tray{tray,NOUN}',), ('appropriate{appropriate,ADJ}',), 0.16236657), (('tray{tray,NOUN}',), ('institution{institution,NOUN}',), 0.8172531), (('tray{tray,NOUN}',), ('works{work,VERB}',), 1.3845124), (('tray{tray,NOUN}',), ('meals{meal,NOUN}',), 1.9848248)]
# {'NOUN_NOUN': 28.645092606544495, 'NOUN_ADJ': 1.6319510489702225, 'NOUN_VERB': 9.03256368637085, 'NOUN_ADV': 0, 'ADJ_NOUN': 6.144411981105804, 'ADJ_ADJ': 0.12750843167304993, 'ADJ_VERB': 0, 'ADJ_ADV': 0, 'VERB_NOUN': 4.677207112312317, 'VERB_ADJ': 0.30317580699920654, 'VERB_VERB': 2.0916287899017334, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 50 45
# ('man{man,NOUN}',) a ('person{person,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 0.8
# path_sim: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 0.5
# spath: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 1
# lch: Palabra1:  Synset('man.n.03') Palabra2: Synset('person.n.01') 2.9444389791664407
# hiperonimo: Synset('man.n.03') Synset('person.n.01') 1
# hiperonimo: Synset('man.n.03') Synset('person.n.01') 1
# minimos hyper Synset('person.n.01')
# a->H 1
# b->H 0
#
# ('man{man,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('man{man,NOUN}',) a ('institution{institution,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 0.6
# path_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 0.2
# spath: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 4
# lch: Palabra1:  Synset('world.n.08') Palabra2: Synset('institution.n.01') 2.0281482472922856
# minimos hyper Synset('group.n.01')
# a->H 1
# b->H 3
#
# ('man{man,NOUN}',) a ('works{work,VERB}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('wearing{wear,VERB}',) a ('person{person,NOUN}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# person{person,NOUN}
# NOUN
# ('wearing{wear,VERB}',) a ('protection{protection,NOUN}',)
# wearing{wear,VERB}
# ['wearing{wear', 'VERB']
# VERB
# protection{protection,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('person{person,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# person{person,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('institution{institution,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# institution{institution,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('protection{protection,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# protection{protection,NOUN}
# NOUN
# ('blue{blue,ADJ}',) a ('meals{meal,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# meals{meal,NOUN}
# NOUN
# ('shirt{shirt,NOUN}',) a ('person{person,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('person.n.01') 0.5
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('person.n.01') 0.1111111111111111
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('person.n.01') 8
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('person.n.01') 1.4403615823901665
# minimos hyper Synset('whole.n.02')
# a->H 5
# b->H 3
#
# ('shirt{shirt,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('shirt{shirt,NOUN}',) a ('institution{institution,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('institution.n.02') 0.5882352941176471
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('institution.n.02') 0.125
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('institution.n.02') 7
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('institution.n.02') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 3
#
# ('shirt{shirt,NOUN}',) a ('protection{protection,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('protective_covering.n.01') 0.75
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('protective_covering.n.01') 0.2
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('protective_covering.n.01') 4
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('protective_covering.n.01') 2.0281482472922856
# minimos hyper Synset('covering.n.02')
# a->H 3
# b->H 1
#
# ('shirt{shirt,NOUN}',) a ('meals{meal,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('meal.n.01') 0.25
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('meal.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('meal.n.01') 12
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('meal.n.01') 1.072636802264849
# minimos hyper Synset('physical_entity.n.01')
# a->H 7
# b->H 5
#
# ('black{black,ADJ}',) a ('person{person,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# person{person,NOUN}
# NOUN
# ('black{black,ADJ}',) a ('appropriate{appropriate,ADJ}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# appropriate{appropriate,ADJ}
# ADJ
# wup_sim: Palabra1:  Synset('black.a.01') Palabra2: Synset('appropriate.a.01') 0.5
# lch: Palabra1:  Synset('black.a.01') Palabra2: Synset('appropriate.a.01') -0.4054651081081644
#
# ('black{black,ADJ}',) a ('institution{institution,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# institution{institution,NOUN}
# NOUN
# ('black{black,ADJ}',) a ('protection{protection,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# protection{protection,NOUN}
# NOUN
# ('apron{apron,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('apron{apron,NOUN}',) a ('institution{institution,NOUN}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('institution.n.02') 0.5882352941176471
# path_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('institution.n.02') 0.125
# spath: Palabra1:  Synset('apron.n.01') Palabra2: Synset('institution.n.02') 7
# lch: Palabra1:  Synset('apron.n.01') Palabra2: Synset('institution.n.02') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 3
#
# ('apron{apron,NOUN}',) a ('protection{protection,NOUN}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('protective_covering.n.01') 0.75
# path_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('protective_covering.n.01') 0.2
# spath: Palabra1:  Synset('apron.n.01') Palabra2: Synset('protective_covering.n.01') 4
# lch: Palabra1:  Synset('apron.n.01') Palabra2: Synset('protective_covering.n.01') 2.0281482472922856
# minimos hyper Synset('covering.n.02')
# a->H 3
# b->H 1
#
# ('apron{apron,NOUN}',) a ('works{work,VERB}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('apron{apron,NOUN}',) a ('meals{meal,NOUN}',)
# apron{apron,NOUN}
# ['apron{apron', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 0.25
# path_sim: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 12
# lch: Palabra1:  Synset('apron.n.01') Palabra2: Synset('meal.n.01') 1.072636802264849
# minimos hyper Synset('physical_entity.n.01')
# a->H 7
# b->H 5
#
# ('eyeglasses{eyeglass,NOUN}',) a ('person{person,NOUN}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# person{person,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('person.n.01') 0.47058823529411764
# path_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('person.n.01') 0.1
# spath: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('person.n.01') 9
# lch: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('person.n.01') 1.3350010667323402
# minimos hyper Synset('whole.n.02')
# a->H 6
# b->H 3
#
# ('eyeglasses{eyeglass,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('eyeglasses{eyeglass,NOUN}',) a ('institution{institution,NOUN}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('institution.n.02') 0.5555555555555556
# path_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('institution.n.02') 0.1111111111111111
# spath: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('institution.n.02') 8
# lch: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('institution.n.02') 1.4403615823901665
# minimos hyper Synset('artifact.n.01')
# a->H 5
# b->H 3
#
# ('eyeglasses{eyeglass,NOUN}',) a ('protection{protection,NOUN}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('protective_covering.n.01') 0.5882352941176471
# path_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('protective_covering.n.01') 0.125
# spath: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('protective_covering.n.01') 7
# lch: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('protective_covering.n.01') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 5
# b->H 2
#
# ('eyeglasses{eyeglass,NOUN}',) a ('works{work,VERB}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('eyeglasses{eyeglass,NOUN}',) a ('meals{meal,NOUN}',)
# eyeglasses{eyeglass,NOUN}
# ['eyeglasses{eyeglass', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('meal.n.01') 0.23529411764705882
# path_sim: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('meal.n.01') 0.07142857142857142
# spath: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('meal.n.01') 13
# lch: Palabra1:  Synset('spectacles.n.01') Palabra2: Synset('meal.n.01') 0.9985288301111273
# minimos hyper Synset('physical_entity.n.01')
# a->H 8
# b->H 5
#
# ('mask{mask,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('mask{mask,NOUN}',) a ('institution{institution,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 0.6666666666666666
# path_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 0.16666666666666666
# spath: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 5
# lch: Palabra1:  Synset('mask.n.01') Palabra2: Synset('institution.n.02') 1.845826690498331
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 3
#
# ('mask{mask,NOUN}',) a ('protection{protection,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 0.9333333333333333
# path_sim: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 0.5
# spath: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 1
# lch: Palabra1:  Synset('mask.n.04') Palabra2: Synset('protective_covering.n.01') 2.9444389791664407
# hiperonimo: Synset('mask.n.04') Synset('protective_covering.n.01') 1
# minimos hyper Synset('protective_covering.n.01')
# a->H 1
# b->H 0
#
# ('mask{mask,NOUN}',) a ('works{work,VERB}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('mask{mask,NOUN}',) a ('meals{meal,NOUN}',)
# mask{mask,NOUN}
# ['mask{mask', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 0.2857142857142857
# path_sim: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 0.09090909090909091
# spath: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 10
# lch: Palabra1:  Synset('mask.n.01') Palabra2: Synset('meal.n.01') 1.2396908869280152
# minimos hyper Synset('physical_entity.n.01')
# a->H 5
# b->H 5
#
# ('handling{handle,VERB}',) a ('person{person,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# person{person,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('appropriate{appropriate,ADJ}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# appropriate{appropriate,ADJ}
# ADJ
# ('handling{handle,VERB}',) a ('institution{institution,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# institution{institution,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('protection{protection,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# protection{protection,NOUN}
# NOUN
# ('handling{handle,VERB}',) a ('works{work,VERB}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# works{work,VERB}
# VERB
# wup_sim: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 0.8
# path_sim: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 0.5
# spath: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 1
# lch: Palabra1:  Synset('manage.v.02') Palabra2: Synset('work.v.17') 2.5649493574615367
# Hiponimo: Synset('manage.v.02') Synset('work.v.17') 1
# minimos hyper Synset('manage.v.02')
# a->H 0
# b->H 1
#
# ('handling{handle,VERB}',) a ('meals{meal,NOUN}',)
# handling{handle,VERB}
# ['handling{handle', 'VERB']
# VERB
# meals{meal,NOUN}
# NOUN
# ('food{food,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('food{food,NOUN}',) a ('institution{institution,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 0.6153846153846154
# path_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 0.16666666666666666
# spath: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 5
# lch: Palabra1:  Synset('food.n.03') Palabra2: Synset('institution.n.03') 1.845826690498331
# minimos hyper Synset('cognition.n.01')
# a->H 2
# b->H 3
#
# ('food{food,NOUN}',) a ('protection{protection,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# protection{protection,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 0.46153846153846156
# path_sim: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 0.125
# spath: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 7
# lch: Palabra1:  Synset('food.n.03') Palabra2: Synset('protection.n.01') 1.55814461804655
# minimos hyper Synset('psychological_feature.n.01')
# a->H 3
# b->H 4
#
# ('food{food,NOUN}',) a ('works{work,VERB}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('food{food,NOUN}',) a ('meals{meal,NOUN}',)
# food{food,NOUN}
# ['food{food', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 0.8333333333333334
# path_sim: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 0.3333333333333333
# spath: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 2
# lch: Palabra1:  Synset('food.n.01') Palabra2: Synset('meal.n.01') 2.538973871058276
# Hiponimo: Synset('food.n.01') Synset('meal.n.01') 2
# minimos hyper Synset('food.n.01')
# a->H 0
# b->H 2
#
# ('tray{tray,NOUN}',) a ('appropriate{appropriate,ADJ}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# appropriate{appropriate,ADJ}
# ADJ
# ('tray{tray,NOUN}',) a ('institution{institution,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# institution{institution,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 0.5882352941176471
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 0.125
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 7
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('institution.n.02') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 3
#
# ('tray{tray,NOUN}',) a ('works{work,VERB}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# works{work,VERB}
# VERB
# ('tray{tray,NOUN}',) a ('meals{meal,NOUN}',)
# tray{tray,NOUN}
# ['tray{tray', 'NOUN']
# NOUN
# meals{meal,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 0.25
# path_sim: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 12
# lch: Palabra1:  Synset('tray.n.01') Palabra2: Synset('meal.n.01') 1.072636802264849
# minimos hyper Synset('physical_entity.n.01')
# a->H 7
# b->H 5
#
# sinonimos 0 []
# antonimos 0 []
# hyperonyms 2 [('man', 'person'), ('man', 'person'), ('mask', 'protection')]
# hyponyms 2 [('handling', 'works'), ('food', 'meals')]
# relaciones fuertes: [(Synset('shirt.n.01'), Synset('institution.n.02')), (Synset('apron.n.01'), Synset('institution.n.02')), (Synset('spectacles.n.01'), Synset('protective_covering.n.01')), (Synset('mask.n.01'), Synset('institution.n.02')), (Synset('food.n.03'), Synset('institution.n.03')), (Synset('tray.n.01'), Synset('institution.n.02'))]
# verbos:  [('handling', 'works', 0.8)]
# ('handling', 'works', 0.8)
# semanticas [0, 0, 2, 2, 6, 0.8]
# verbos a comparar food works
# 1
# Texto:  A man dressed in a red shirt and black tie stands up at a wedding reception to make a speech.
# Hipótesis:  a guy in a red top and tie makes a speech
# 22 12
# [(('man{man,NOUN}',), ('guy{guy,NOUN}',), 3.423489), (('dressed{dress,VERB}',), ('guy{guy,NOUN}',), 0.5705536), (('dressed{dress,VERB}',), ('top{top,NOUN}',), 0.69319415), (('dressed{dress,VERB}',), ('tie{tie,NOUN}',), 1.2315246), (('red{red,ADJ}',), ('red{red,ADJ}',), 5.2774463), (('red{red,ADJ}',), ('tie{tie,NOUN}',), 0.7923888), (('shirt{shirt,NOUN}',), ('guy{guy,NOUN}',), 0.79965866), (('shirt{shirt,NOUN}',), ('red{red,ADJ}',), 0.76137096), (('shirt{shirt,NOUN}',), ('top{top,NOUN}',), 0.41330415), (('shirt{shirt,NOUN}',), ('tie{tie,NOUN}',), 1.356515), (('black{black,ADJ}',), ('guy{guy,NOUN}',), 0.60708606), (('black{black,ADJ}',), ('red{red,ADJ}',), 3.3381805), (('black{black,ADJ}',), ('top{top,NOUN}',), 0.43125343), (('black{black,ADJ}',), ('tie{tie,NOUN}',), 0.66219443), (('tie{tie,NOUN}',), ('guy{guy,NOUN}',), 0.566649), (('tie{tie,NOUN}',), ('red{red,ADJ}',), 0.7923888), (('tie{tie,NOUN}',), ('top{top,NOUN}',), 0.49118018), (('tie{tie,NOUN}',), ('tie{tie,NOUN}',), 2.1544504), (('tie{tie,NOUN}',), ('makes{make,VERB}',), 0.62809175), (('tie{tie,NOUN}',), ('speech{speech,NOUN}',), 1.632478), (('stands{stand,VERB}',), ('top{top,NOUN}',), 0.49188167), (('stands{stand,VERB}',), ('tie{tie,NOUN}',), 0.7616982), (('stands{stand,VERB}',), ('makes{make,VERB}',), 0.60041875), (('stands{stand,VERB}',), ('speech{speech,NOUN}',), 1.4440373), (('wedding{wedding,NOUN}',), ('guy{guy,NOUN}',), 1.451425), (('wedding{wedding,NOUN}',), ('red{red,ADJ}',), 1.5915512), (('wedding{wedding,NOUN}',), ('top{top,NOUN}',), 0.2538691), (('wedding{wedding,NOUN}',), ('tie{tie,NOUN}',), 1.178471), (('wedding{wedding,NOUN}',), ('makes{make,VERB}',), 0.7048656), (('wedding{wedding,NOUN}',), ('speech{speech,NOUN}',), 1.8128022), (('reception{reception,NOUN}',), ('top{top,NOUN}',), 0.22148626), (('reception{reception,NOUN}',), ('tie{tie,NOUN}',), 0.9831245), (('reception{reception,NOUN}',), ('makes{make,VERB}',), 0.96974885), (('reception{reception,NOUN}',), ('speech{speech,NOUN}',), 2.309178), (('make{make,VERB}',), ('guy{guy,NOUN}',), 0.6569229), (('make{make,VERB}',), ('top{top,NOUN}',), 0.24463844), (('make{make,VERB}',), ('tie{tie,NOUN}',), 1.216042), (('make{make,VERB}',), ('makes{make,VERB}',), 1.4106249), (('make{make,VERB}',), ('speech{speech,NOUN}',), 2.577352), (('speech{speech,NOUN}',), ('guy{guy,NOUN}',), 1.0873796), (('speech{speech,NOUN}',), ('red{red,ADJ}',), 0.838912), (('speech{speech,NOUN}',), ('tie{tie,NOUN}',), 1.632478), (('speech{speech,NOUN}',), ('makes{make,VERB}',), 2.1349905), (('speech{speech,NOUN}',), ('speech{speech,NOUN}',), 4.903362)]
# {'NOUN_NOUN': 26.671300008893013, 'NOUN_ADJ': 3.984222948551178, 'NOUN_VERB': 4.437696635723114, 'NOUN_ADV': 0, 'ADJ_NOUN': 2.4929227232933044, 'ADJ_ADJ': 8.615626811981201, 'ADJ_VERB': 0, 'ADJ_ADV': 0, 'VERB_NOUN': 9.887844920158386, 'VERB_ADJ': 0, 'VERB_VERB': 2.011043608188629, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 44 46
# ('man{man,NOUN}',) a ('guy{guy,NOUN}',)
# man{man,NOUN}
# ['man{man', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 0.9473684210526315
# path_sim: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 0.5
# spath: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 1
# lch: Palabra1:  Synset('man.n.01') Palabra2: Synset('guy.n.01') 2.9444389791664407
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# Hiponimo: Synset('man.n.01') Synset('guy.n.01') 1
# minimos hyper Synset('man.n.01')
# a->H 0
# b->H 1
#
# ('dressed{dress,VERB}',) a ('guy{guy,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# guy{guy,NOUN}
# NOUN
# ('dressed{dress,VERB}',) a ('top{top,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# top{top,NOUN}
# NOUN
# ('dressed{dress,VERB}',) a ('tie{tie,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# tie{tie,NOUN}
# NOUN
# ('red{red,ADJ}',) a ('red{red,ADJ}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# red{red,ADJ}
# ADJ
# wup_sim: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 1.0
# path_sim: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 1.0
# spath: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 0
# lch: Palabra1:  Synset('red.s.01') Palabra2: Synset('red.s.01') 0.6931471805599453
# Sinonimo:  red red
# hiperonimo: Synset('red.s.01') Synset('red.s.01') 0
# Hiponimo: Synset('red.s.01') Synset('red.s.01') 0
# minimos hyper Synset('red.s.01')
# a->H 0
# b->H 0
#
# ('red{red,ADJ}',) a ('tie{tie,NOUN}',)
# red{red,ADJ}
# ['red{red', 'ADJ']
# ADJ
# tie{tie,NOUN}
# NOUN
# ('shirt{shirt,NOUN}',) a ('guy{guy,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('guy.n.02') 0.5555555555555556
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('guy.n.02') 0.1111111111111111
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('guy.n.02') 8
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('guy.n.02') 1.4403615823901665
# minimos hyper Synset('artifact.n.01')
# a->H 4
# b->H 4
#
# ('shirt{shirt,NOUN}',) a ('red{red,ADJ}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('shirt{shirt,NOUN}',) a ('top{top,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 0.8
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 0.2
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 4
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('top.n.10') 2.0281482472922856
# minimos hyper Synset('clothing.n.01')
# a->H 2
# b->H 2
#
# ('shirt{shirt,NOUN}',) a ('tie{tie,NOUN}',)
# shirt{shirt,NOUN}
# ['shirt{shirt', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('necktie.n.01') 0.8571428571428571
# path_sim: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('necktie.n.01') 0.25
# spath: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('necktie.n.01') 3
# lch: Palabra1:  Synset('shirt.n.01') Palabra2: Synset('necktie.n.01') 2.2512917986064953
# minimos hyper Synset('garment.n.01')
# a->H 1
# b->H 2
#
# ('black{black,ADJ}',) a ('guy{guy,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# guy{guy,NOUN}
# NOUN
# ('black{black,ADJ}',) a ('red{red,ADJ}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# red{red,ADJ}
# ADJ
# wup_sim: Palabra1:  Synset('black.a.01') Palabra2: Synset('red.s.01') 0.5
#
# ('black{black,ADJ}',) a ('top{top,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# top{top,NOUN}
# NOUN
# ('black{black,ADJ}',) a ('tie{tie,NOUN}',)
# black{black,ADJ}
# ['black{black', 'ADJ']
# ADJ
# tie{tie,NOUN}
# NOUN
# ('tie{tie,NOUN}',) a ('guy{guy,NOUN}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('tie.n.08') Palabra2: Synset('guy.n.03') 0.9090909090909091
# path_sim: Palabra1:  Synset('tie.n.08') Palabra2: Synset('guy.n.03') 0.3333333333333333
# spath: Palabra1:  Synset('tie.n.08') Palabra2: Synset('guy.n.03') 2
# lch: Palabra1:  Synset('tie.n.08') Palabra2: Synset('guy.n.03') 2.538973871058276
# minimos hyper Synset('brace.n.09')
# a->H 1
# b->H 1
#
# ('tie{tie,NOUN}',) a ('red{red,ADJ}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('tie{tie,NOUN}',) a ('top{top,NOUN}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 0.7619047619047619
# path_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 0.16666666666666666
# spath: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 5
# lch: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('top.n.10') 1.845826690498331
# minimos hyper Synset('clothing.n.01')
# a->H 3
# b->H 2
#
# ('tie{tie,NOUN}',) a ('tie{tie,NOUN}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('necktie.n.01') 1.0
# path_sim: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('necktie.n.01') 1.0
# spath: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('necktie.n.01') 0
# lch: Palabra1:  Synset('necktie.n.01') Palabra2: Synset('necktie.n.01') 3.6375861597263857
# Sinonimo:  tie tie
# hiperonimo: Synset('necktie.n.01') Synset('necktie.n.01') 0
# hiperonimo: Synset('necktie.n.01') Synset('necktie.n.01') 0
# Hiponimo: Synset('necktie.n.01') Synset('necktie.n.01') 0
# Hiponimo: Synset('necktie.n.01') Synset('necktie.n.01') 0
# minimos hyper Synset('necktie.n.01')
# a->H 0
# b->H 0
#
# ('tie{tie,NOUN}',) a ('makes{make,VERB}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('tie{tie,NOUN}',) a ('speech{speech,NOUN}',)
# tie{tie,NOUN}
# ['tie{tie', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('address.n.03') 0.5714285714285714
# path_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('address.n.03') 0.14285714285714285
# spath: Palabra1:  Synset('draw.n.03') Palabra2: Synset('address.n.03') 6
# lch: Palabra1:  Synset('draw.n.03') Palabra2: Synset('address.n.03') 1.6916760106710724
# minimos hyper Synset('event.n.01')
# a->H 3
# b->H 3
#
# ('stands{stand,VERB}',) a ('top{top,NOUN}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# top{top,NOUN}
# NOUN
# ('stands{stand,VERB}',) a ('tie{tie,NOUN}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# tie{tie,NOUN}
# NOUN
# ('stands{stand,VERB}',) a ('makes{make,VERB}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# makes{make,VERB}
# VERB
# wup_sim: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 0.5
# path_sim: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 0.2
# spath: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 4
# lch: Palabra1:  Synset('stand.v.06') Palabra2: Synset('make.v.43') 1.6486586255873816
# minimos hyper Synset('evaluate.v.02')
# a->H 1
# b->H 3
#
# ('stands{stand,VERB}',) a ('speech{speech,NOUN}',)
# stands{stand,VERB}
# ['stands{stand', 'VERB']
# VERB
# speech{speech,NOUN}
# NOUN
# ('wedding{wedding,NOUN}',) a ('guy{guy,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.13333333333333333
# path_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.07142857142857142
# spath: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 13
# lch: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('guy.n.01') 0.9985288301111273
# minimos hyper Synset('entity.n.01')
# a->H 7
# b->H 6
#
# ('wedding{wedding,NOUN}',) a ('red{red,ADJ}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('wedding{wedding,NOUN}',) a ('top{top,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('top.n.04') 0.3333333333333333
# path_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('top.n.04') 0.07692307692307693
# spath: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('top.n.04') 12
# lch: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('top.n.04') 1.072636802264849
# minimos hyper Synset('psychological_feature.n.01')
# a->H 5
# b->H 7
#
# ('wedding{wedding,NOUN}',) a ('tie{tie,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 0.5333333333333333
# path_sim: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 0.125
# spath: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 7
# lch: Palabra1:  Synset('wedding.n.01') Palabra2: Synset('draw.n.03') 1.55814461804655
# minimos hyper Synset('event.n.01')
# a->H 4
# b->H 3
#
# ('wedding{wedding,NOUN}',) a ('makes{make,VERB}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('wedding{wedding,NOUN}',) a ('speech{speech,NOUN}',)
# wedding{wedding,NOUN}
# ['wedding{wedding', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 0.5882352941176471
# path_sim: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 0.125
# spath: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 7
# lch: Palabra1:  Synset('marriage.n.03') Palabra2: Synset('address.n.03') 1.55814461804655
# minimos hyper Synset('act.n.02')
# a->H 5
# b->H 2
#
# ('reception{reception,NOUN}',) a ('top{top,NOUN}',)
# reception{reception,NOUN}
# ['reception{reception', 'NOUN']
# NOUN
# top{top,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('reception.n.03') Palabra2: Synset('top.n.08') 0.5882352941176471
# path_sim: Palabra1:  Synset('reception.n.03') Palabra2: Synset('top.n.08') 0.125
# spath: Palabra1:  Synset('reception.n.03') Palabra2: Synset('top.n.08') 7
# lch: Palabra1:  Synset('reception.n.03') Palabra2: Synset('top.n.08') 1.55814461804655
# minimos hyper Synset('artifact.n.01')
# a->H 5
# b->H 2
#
# ('reception{reception,NOUN}',) a ('tie{tie,NOUN}',)
# reception{reception,NOUN}
# ['reception{reception', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('reception.n.03') Palabra2: Synset('link.n.02') 0.6
# path_sim: Palabra1:  Synset('reception.n.03') Palabra2: Synset('link.n.02') 0.1111111111111111
# spath: Palabra1:  Synset('reception.n.03') Palabra2: Synset('link.n.02') 8
# lch: Palabra1:  Synset('reception.n.03') Palabra2: Synset('link.n.02') 1.4403615823901665
# minimos hyper Synset('instrumentality.n.03')
# a->H 4
# b->H 4
#
# ('reception{reception,NOUN}',) a ('makes{make,VERB}',)
# reception{reception,NOUN}
# ['reception{reception', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('reception{reception,NOUN}',) a ('speech{speech,NOUN}',)
# reception{reception,NOUN}
# ['reception{reception', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('reception.n.04') Palabra2: Synset('address.n.03') 0.7142857142857143
# path_sim: Palabra1:  Synset('reception.n.04') Palabra2: Synset('address.n.03') 0.2
# spath: Palabra1:  Synset('reception.n.04') Palabra2: Synset('address.n.03') 4
# lch: Palabra1:  Synset('reception.n.04') Palabra2: Synset('address.n.03') 2.0281482472922856
# minimos hyper Synset('act.n.02')
# a->H 2
# b->H 2
#
# ('make{make,VERB}',) a ('guy{guy,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# guy{guy,NOUN}
# NOUN
# ('make{make,VERB}',) a ('top{top,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# top{top,NOUN}
# NOUN
# ('make{make,VERB}',) a ('tie{tie,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# tie{tie,NOUN}
# NOUN
# ('make{make,VERB}',) a ('makes{make,VERB}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# makes{make,VERB}
# VERB
# wup_sim: Palabra1:  Synset('make.v.01') Palabra2: Synset('make.v.01') 1.0
# path_sim: Palabra1:  Synset('make.v.01') Palabra2: Synset('make.v.01') 1.0
# spath: Palabra1:  Synset('make.v.01') Palabra2: Synset('make.v.01') 0
# lch: Palabra1:  Synset('make.v.01') Palabra2: Synset('make.v.01') 3.258096538021482
# hiperonimo: Synset('make.v.01') Synset('make.v.01') 0
# Hiponimo: Synset('make.v.01') Synset('make.v.01') 0
# minimos hyper Synset('make.v.01')
# a->H 0
# b->H 0
#
# ('make{make,VERB}',) a ('speech{speech,NOUN}',)
# make{make,VERB}
# ['make{make', 'VERB']
# VERB
# speech{speech,NOUN}
# NOUN
# ('speech{speech,NOUN}',) a ('guy{guy,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# guy{guy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 0.16666666666666666
# path_sim: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 0.09090909090909091
# spath: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 10
# lch: Palabra1:  Synset('speech.n.02') Palabra2: Synset('guy.n.01') 1.2396908869280152
# minimos hyper Synset('entity.n.01')
# a->H 4
# b->H 6
#
# ('speech{speech,NOUN}',) a ('red{red,ADJ}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# red{red,ADJ}
# ADJ
# ('speech{speech,NOUN}',) a ('tie{tie,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# tie{tie,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 0.5714285714285714
# path_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 0.14285714285714285
# spath: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 6
# lch: Palabra1:  Synset('address.n.03') Palabra2: Synset('draw.n.03') 1.6916760106710724
# minimos hyper Synset('event.n.01')
# a->H 3
# b->H 3
#
# ('speech{speech,NOUN}',) a ('makes{make,VERB}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# makes{make,VERB}
# VERB
# ('speech{speech,NOUN}',) a ('speech{speech,NOUN}',)
# speech{speech,NOUN}
# ['speech{speech', 'NOUN']
# NOUN
# speech{speech,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 1.0
# path_sim: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 1.0
# spath: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 0
# lch: Palabra1:  Synset('address.n.03') Palabra2: Synset('address.n.03') 3.6375861597263857
# Sinonimo:  speech speech
# hiperonimo: Synset('address.n.03') Synset('address.n.03') 0
# Hiponimo: Synset('address.n.03') Synset('address.n.03') 0
# minimos hyper Synset('address.n.03')
# a->H 0
# b->H 0
#
# sinonimos 4 [('red', 'red'), ('red', 'red'), ('tie', 'tie'), ('tie', 'tie'), ('tie', 'tie'), ('make', 'makes'), ('speech', 'speech'), ('speech', 'speech')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 1 [('man', 'guy'), ('man', 'guy'), ('man', 'guy'), ('man', 'guy')]
# relaciones fuertes: [(Synset('red.s.01'), Synset('red.s.01')), (Synset('necktie.n.01'), Synset('top.n.10')), (Synset('draw.n.03'), Synset('address.n.03')), (Synset('wedding.n.01'), Synset('draw.n.03')), (Synset('marriage.n.03'), Synset('address.n.03')), (Synset('reception.n.03'), Synset('top.n.08')), (Synset('address.n.03'), Synset('draw.n.03'))]
# verbos:  [('stands', 'makes', 0.5), ('make', 'makes', 1.0)]
# ('stands', 'makes', 0.5)
# ('make', 'makes', 1.0)
# semanticas [4, 0, 0, 1, 7, 1.0]
# verbos a comparar speech makes
# 2
# Texto:  A young boy runs across a road in front of a sky blue building with barred windows.
# Hipótesis:  A boy sleeps in his bed.
# 19 8
# [(('young{young,ADJ}',), ('boy{boy,NOUN}',), 2.7248206), (('young{young,ADJ}',), ('his{-PRON-,ADJ}',), 0.90929025), (('boy{boy,NOUN}',), ('boy{boy,NOUN}',), 4.5691986), (('boy{boy,NOUN}',), ('sleeps{sleep,VERB}',), 1.0684676), (('boy{boy,NOUN}',), ('his{-PRON-,ADJ}',), 1.8245916), (('runs{run,VERB}',), ('sleeps{sleep,VERB}',), 3.661071), (('runs{run,VERB}',), ('his{-PRON-,ADJ}',), 0.3470169), (('runs{run,VERB}',), ('bed{bed,NOUN}',), 1.1998608), (('road{road,NOUN}',), ('bed{bed,NOUN}',), 2.123679), (('front{front,NOUN}',), ('bed{bed,NOUN}',), 1.1050626), (('sky{sky,NOUN}',), ('sleeps{sleep,VERB}',), 1.4454561), (('sky{sky,NOUN}',), ('bed{bed,NOUN}',), 2.4027486), (('blue{blue,ADJ}',), ('sleeps{sleep,VERB}',), 1.0149397), (('blue{blue,ADJ}',), ('bed{bed,NOUN}',), 1.6184589), (('building{building,NOUN}',), ('bed{bed,NOUN}',), 2.126788), (('barred{barred,ADJ}',), ('sleeps{sleep,VERB}',), 2.6506383), (('barred{barred,ADJ}',), ('his{-PRON-,ADJ}',), 0.39168817), (('barred{barred,ADJ}',), ('bed{bed,NOUN}',), 1.0405141), (('windows{window,NOUN}',), ('sleeps{sleep,VERB}',), 1.1739506), (('windows{window,NOUN}',), ('bed{bed,NOUN}',), 2.5531425)]
# {'NOUN_NOUN': 14.880619168281555, 'NOUN_ADJ': 1.8245916366577148, 'NOUN_VERB': 3.6878743171691895, 'NOUN_ADV': 0, 'ADJ_NOUN': 5.383793592453003, 'ADJ_ADJ': 1.300978422164917, 'ADJ_VERB': 3.665578007698059, 'ADJ_ADV': 0, 'VERB_NOUN': 1.1998608112335205, 'VERB_ADJ': 0.3470169007778168, 'VERB_VERB': 3.6610710620880127, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 20 20
# ('young{young,ADJ}',) a ('boy{boy,NOUN}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# boy{boy,NOUN}
# NOUN
# ('young{young,ADJ}',) a ('his{-PRON-,ADJ}',)
# young{young,ADJ}
# ['young{young', 'ADJ']
# ADJ
# his{-PRON-,ADJ}
# ADJ
# ('boy{boy,NOUN}',) a ('boy{boy,NOUN}',)
# boy{boy,NOUN}
# ['boy{boy', 'NOUN']
# NOUN
# boy{boy,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('male_child.n.01') 1.0
# path_sim: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('male_child.n.01') 1.0
# spath: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('male_child.n.01') 0
# lch: Palabra1:  Synset('male_child.n.01') Palabra2: Synset('male_child.n.01') 3.6375861597263857
# Sinonimo:  boy boy
# hiperonimo: Synset('male_child.n.01') Synset('male_child.n.01') 0
# hiperonimo: Synset('male_child.n.01') Synset('male_child.n.01') 0
# Hiponimo: Synset('male_child.n.01') Synset('male_child.n.01') 0
# Hiponimo: Synset('male_child.n.01') Synset('male_child.n.01') 0
# minimos hyper Synset('male_child.n.01')
# a->H 0
# b->H 0
#
# ('boy{boy,NOUN}',) a ('sleeps{sleep,VERB}',)
# boy{boy,NOUN}
# ['boy{boy', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('boy{boy,NOUN}',) a ('his{-PRON-,ADJ}',)
# boy{boy,NOUN}
# ['boy{boy', 'NOUN']
# NOUN
# his{-PRON-,ADJ}
# ADJ
# ('runs{run,VERB}',) a ('sleeps{sleep,VERB}',)
# runs{run,VERB}
# ['runs{run', 'VERB']
# VERB
# sleeps{sleep,VERB}
# VERB
# wup_sim: Palabra1:  Synset('function.v.01') Palabra2: Synset('sleep.v.02') 0.4
# lch: Palabra1:  Synset('function.v.01') Palabra2: Synset('sleep.v.02') 1.8718021769015913
#
# ('runs{run,VERB}',) a ('his{-PRON-,ADJ}',)
# runs{run,VERB}
# ['runs{run', 'VERB']
# VERB
# his{-PRON-,ADJ}
# ADJ
# ('runs{run,VERB}',) a ('bed{bed,NOUN}',)
# runs{run,VERB}
# ['runs{run', 'VERB']
# VERB
# bed{bed,NOUN}
# NOUN
# ('road{road,NOUN}',) a ('bed{bed,NOUN}',)
# road{road,NOUN}
# ['road{road', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 0.7692307692307693
# path_sim: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 0.25
# spath: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 3
# lch: Palabra1:  Synset('road.n.01') Palabra2: Synset('layer.n.01') 2.2512917986064953
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 1
#
# ('front{front,NOUN}',) a ('bed{bed,NOUN}',)
# front{front,NOUN}
# ['front{front', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 0.8
# path_sim: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 0.25
# spath: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 3
# lch: Palabra1:  Synset('front.n.04') Palabra2: Synset('bed.n.07') 2.2512917986064953
# minimos hyper Synset('surface.n.01')
# a->H 2
# b->H 1
#
# ('sky{sky,NOUN}',) a ('sleeps{sleep,VERB}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('sky{sky,NOUN}',) a ('bed{bed,NOUN}',)
# sky{sky,NOUN}
# ['sky{sky', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 0.3076923076923077
# path_sim: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 0.1
# spath: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 9
# lch: Palabra1:  Synset('sky.n.01') Palabra2: Synset('bed.n.03') 1.3350010667323402
# minimos hyper Synset('physical_entity.n.01')
# a->H 5
# b->H 4
#
# ('blue{blue,ADJ}',) a ('sleeps{sleep,VERB}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# sleeps{sleep,VERB}
# VERB
# ('blue{blue,ADJ}',) a ('bed{bed,NOUN}',)
# blue{blue,ADJ}
# ['blue{blue', 'ADJ']
# ADJ
# bed{bed,NOUN}
# NOUN
# ('building{building,NOUN}',) a ('bed{bed,NOUN}',)
# building{building,NOUN}
# ['building{building', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('building.n.01') Palabra2: Synset('layer.n.01') 0.7692307692307693
# path_sim: Palabra1:  Synset('building.n.01') Palabra2: Synset('layer.n.01') 0.25
# spath: Palabra1:  Synset('building.n.01') Palabra2: Synset('layer.n.01') 3
# lch: Palabra1:  Synset('building.n.01') Palabra2: Synset('layer.n.01') 2.2512917986064953
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 1
#
# ('barred{barred,ADJ}',) a ('sleeps{sleep,VERB}',)
# barred{barred,ADJ}
# ['barred{barred', 'ADJ']
# ADJ
# sleeps{sleep,VERB}
# VERB
# ('barred{barred,ADJ}',) a ('his{-PRON-,ADJ}',)
# barred{barred,ADJ}
# ['barred{barred', 'ADJ']
# ADJ
# his{-PRON-,ADJ}
# ADJ
# ('barred{barred,ADJ}',) a ('bed{bed,NOUN}',)
# barred{barred,ADJ}
# ['barred{barred', 'ADJ']
# ADJ
# bed{bed,NOUN}
# NOUN
# ('windows{window,NOUN}',) a ('sleeps{sleep,VERB}',)
# windows{window,NOUN}
# ['windows{window', 'NOUN']
# NOUN
# sleeps{sleep,VERB}
# VERB
# ('windows{window,NOUN}',) a ('bed{bed,NOUN}',)
# windows{window,NOUN}
# ['windows{window', 'NOUN']
# NOUN
# bed{bed,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('window.n.02') Palabra2: Synset('layer.n.01') 0.7692307692307693
# path_sim: Palabra1:  Synset('window.n.02') Palabra2: Synset('layer.n.01') 0.25
# spath: Palabra1:  Synset('window.n.02') Palabra2: Synset('layer.n.01') 3
# lch: Palabra1:  Synset('window.n.02') Palabra2: Synset('layer.n.01') 2.2512917986064953
# minimos hyper Synset('artifact.n.01')
# a->H 2
# b->H 1
#
# sinonimos 1 [('boy', 'boy'), ('boy', 'boy'), ('boy', 'boy')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 0 []
# relaciones fuertes: []
# verbos:  [('runs', 'sleeps', 0.4)]
# ('runs', 'sleeps', 0.4)
# semanticas [1, 0, 0, 0, 0, 0.4]
# verbos a comparar runs sleeps
# 3
# Texto:  An Asian woman is standing on a path with a basket on her head looking into a mirror she is holding in her hand.
# Hipótesis:  Nobody is standing
# 26 4
# [(('asian{asian,ADJ}',), ('nobody{nobody,NOUN}',), 1.3274782), (('woman{woman,NOUN}',), ('nobody{nobody,NOUN}',), 1.9542669), (('is{be,VERB}',), ('is{be,VERB}',), 0.048234075), (('standing{stand,VERB}',), ('nobody{nobody,NOUN}',), 1.6132503), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.16424847), (('standing{stand,VERB}',), ('standing{stand,VERB}',), 3.7725809), (('path{path,NOUN}',), ('standing{stand,VERB}',), 0.93849206), (('basket{basket,NOUN}',), ('standing{stand,VERB}',), 0.87739015), (('her{-PRON-,ADJ}',), ('nobody{nobody,NOUN}',), 1.2928329), (('head{head,NOUN}',), ('standing{stand,VERB}',), 0.9323483), (('looking{look,VERB}',), ('nobody{nobody,NOUN}',), 1.6308092), (('looking{look,VERB}',), ('is{be,VERB}',), 0.12195437), (('looking{look,VERB}',), ('standing{stand,VERB}',), 1.1844865), (('mirror{mirror,NOUN}',), ('nobody{nobody,NOUN}',), 2.424366), (('mirror{mirror,NOUN}',), ('is{be,VERB}',), 0.09869578), (('mirror{mirror,NOUN}',), ('standing{stand,VERB}',), 0.8397438), (('she{-PRON-,PRON}',), ('nobody{nobody,NOUN}',), 1.841595), (('is{be,VERB}',), ('is{be,VERB}',), 0.048234075), (('holding{hold,VERB}',), ('nobody{nobody,NOUN}',), 0.90917647), (('holding{hold,VERB}',), ('is{be,VERB}',), 0.09925847), (('holding{hold,VERB}',), ('standing{stand,VERB}',), 1.6181725), (('her{-PRON-,ADJ}',), ('nobody{nobody,NOUN}',), 1.2928329), (('hand{hand,NOUN}',), ('nobody{nobody,NOUN}',), 0.8920393), (('hand{hand,NOUN}',), ('is{be,VERB}',), 0.07557302), (('hand{hand,NOUN}',), ('standing{stand,VERB}',), 1.2367109)]
# {'NOUN_NOUN': 7.112267255783081, 'NOUN_ADJ': 0, 'NOUN_VERB': 4.998954012989998, 'NOUN_ADV': 0, 'ADJ_NOUN': 3.9131438732147217, 'ADJ_ADJ': 0, 'ADJ_VERB': 0, 'ADJ_ADV': 0, 'VERB_NOUN': 4.153235912322998, 'VERB_ADJ': 0, 'VERB_VERB': 7.05716934800148, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 25 23
# ('asian{asian,ADJ}',) a ('nobody{nobody,NOUN}',)
# asian{asian,ADJ}
# ['asian{asian', 'ADJ']
# ADJ
# nobody{nobody,NOUN}
# NOUN
# ('woman{woman,NOUN}',) a ('nobody{nobody,NOUN}',)
# woman{woman,NOUN}
# ['woman{woman', 'NOUN']
# NOUN
# nobody{nobody,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('woman.n.01') Palabra2: Synset('cipher.n.04') 0.6666666666666666
# path_sim: Palabra1:  Synset('woman.n.01') Palabra2: Synset('cipher.n.04') 0.2
# spath: Palabra1:  Synset('woman.n.01') Palabra2: Synset('cipher.n.04') 4
# lch: Palabra1:  Synset('woman.n.01') Palabra2: Synset('cipher.n.04') 2.0281482472922856
# minimos hyper Synset('person.n.01')
# a->H 2
# b->H 2
#
# ('is{be,VERB}',) a ('is{be,VERB}',)
# is{be,VERB}
# ['is{be', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('be.v.01') Palabra2: Synset('be.v.01') 1.0
# ...
# lch: Palabra1:  Synset('whoremaster.n.01') Palabra2: Synset('man.n.03') 1.845826690498331
# minimos hyper Synset('person.n.01')
# a->H 4
# b->H 1
#
# ('trick{trick,NOUN}',) a ('painting{paint,VERB}',)
# trick{trick,NOUN}
# ['trick{trick', 'NOUN']
# NOUN
# painting{paint,VERB}
# VERB
# ('trick{trick,NOUN}',) a ('tree{tree,NOUN}',)
# trick{trick,NOUN}
# ['trick{trick', 'NOUN']
# NOUN
# tree{tree,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('whoremaster.n.01') Palabra2: Synset('tree.n.01') 0.5714285714285714
# path_sim: Palabra1:  Synset('whoremaster.n.01') Palabra2: Synset('tree.n.01') 0.1
# spath: Palabra1:  Synset('whoremaster.n.01') Palabra2: Synset('tree.n.01') 9
# lch: Palabra1:  Synset('whoremaster.n.01') Palabra2: Synset('tree.n.01') 1.3350010667323402
# minimos hyper Synset('organism.n.01')
# a->H 5
# b->H 4
#
# ('rail{rail,NOUN}',) a ('painting{paint,VERB}',)
# rail{rail,NOUN}
# ['rail{rail', 'NOUN']
# NOUN
# painting{paint,VERB}
# VERB
# ('rail{rail,NOUN}',) a ('tree{tree,NOUN}',)
# rail{rail,NOUN}
# ['rail{rail', 'NOUN']
# NOUN
# tree{tree,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('rail.n.05') Palabra2: Synset('tree.n.01') 0.5217391304347826
# path_sim: Palabra1:  Synset('rail.n.05') Palabra2: Synset('tree.n.01') 0.08333333333333333
# spath: Palabra1:  Synset('rail.n.05') Palabra2: Synset('tree.n.01') 11
# lch: Palabra1:  Synset('rail.n.05') Palabra2: Synset('tree.n.01') 1.1526795099383855
# minimos hyper Synset('organism.n.01')
# a->H 7
# b->H 4
#
# sinonimos 0 []
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 0 []
# relaciones fuertes: [(Synset('young_person.n.01'), Synset('tree.n.01')), (Synset('whoremaster.n.01'), Synset('man.n.03'))]
# verbos:  [('skateboarding', 'painting', 0.25), ('does', 'painting', 0.4)]
# ('skateboarding', 'painting', 0.25)
# ('does', 'painting', 0.4)
# semanticas [0, 0, 0, 0, 2, 0.4]
# verbos a comparar trick painting
# 98
# Texto:  Four children are playing in some water.
# Hipótesis:  The children are doing chores.
# 9 7
# [(('children{child,NOUN}',), ('children{child,NOUN}',), 4.0551147), (('children{child,NOUN}',), ('are{be,VERB}',), 0.048274748), (('children{child,NOUN}',), ('chores{chore,NOUN}',), 1.0565162), (('are{be,VERB}',), ('are{be,VERB}',), 0.03777049), (('playing{play,VERB}',), ('are{be,VERB}',), 0.06546676), (('playing{play,VERB}',), ('doing{do,VERB}',), 1.4925318), (('playing{play,VERB}',), ('chores{chore,NOUN}',), 2.450452), (('water{water,NOUN}',), ('doing{do,VERB}',), 0.61060596), (('water{water,NOUN}',), ('chores{chore,NOUN}',), 1.9988189)]
# {'NOUN_NOUN': 7.11044979095459, 'NOUN_ADJ': 0, 'NOUN_VERB': 0.658880703151226, 'NOUN_ADV': 0, 'ADJ_NOUN': 0, 'ADJ_ADJ': 0, 'ADJ_VERB': 0, 'ADJ_ADV': 0, 'VERB_NOUN': 2.4504520893096924, 'VERB_ADJ': 0, 'VERB_VERB': 1.59576902911067, 'VERB_ADV': 0, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 9 11
# ('children{child,NOUN}',) a ('children{child,NOUN}',)
# children{child,NOUN}
# ['children{child', 'NOUN']
# NOUN
# children{child,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('child.n.01') Palabra2: Synset('child.n.01') 1.0
# path_sim: Palabra1:  Synset('child.n.01') Palabra2: Synset('child.n.01') 1.0
# spath: Palabra1:  Synset('child.n.01') Palabra2: Synset('child.n.01') 0
# lch: Palabra1:  Synset('child.n.01') Palabra2: Synset('child.n.01') 3.6375861597263857
# hiperonimo: Synset('child.n.01') Synset('child.n.01') 0
# hiperonimo: Synset('child.n.01') Synset('child.n.01') 0
# Hiponimo: Synset('child.n.01') Synset('child.n.01') 0
# Hiponimo: Synset('child.n.01') Synset('child.n.01') 0
# minimos hyper Synset('child.n.01')
# a->H 0
# b->H 0
#
# ('children{child,NOUN}',) a ('are{be,VERB}',)
# children{child,NOUN}
# ['children{child', 'NOUN']
# NOUN
# are{be,VERB}
# VERB
# ('children{child,NOUN}',) a ('chores{chore,NOUN}',)
# children{child,NOUN}
# ['children{child', 'NOUN']
# NOUN
# chores{chore,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('child.n.03') Palabra2: Synset('job.n.02') 0.14285714285714285
# path_sim: Palabra1:  Synset('child.n.03') Palabra2: Synset('job.n.02') 0.07692307692307693
# spath: Palabra1:  Synset('child.n.03') Palabra2: Synset('job.n.02') 12
# lch: Palabra1:  Synset('child.n.03') Palabra2: Synset('job.n.02') 1.072636802264849
# minimos hyper Synset('entity.n.01')
# a->H 4
# b->H 8
#
# ('are{be,VERB}',) a ('are{be,VERB}',)
# are{be,VERB}
# ['are{be', 'VERB']
# VERB
# are{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('be.v.01') Palabra2: Synset('be.v.01') 1.0
# path_sim: Palabra1:  Synset('be.v.01') Palabra2: Synset('be.v.01') 1.0
# spath: Palabra1:  Synset('be.v.01') Palabra2: Synset('be.v.01') 0
# lch: Palabra1:  Synset('be.v.01') Palabra2: Synset('be.v.01') 3.258096538021482
# hiperonimo: Synset('be.v.01') Synset('be.v.01') 0
# Hiponimo: Synset('be.v.01') Synset('be.v.01') 0
# minimos hyper Synset('be.v.01')
# a->H 0
# b->H 0
#
# ('playing{play,VERB}',) a ('are{be,VERB}',)
# playing{play,VERB}
# ['playing{play', 'VERB']
# VERB
# are{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('play.v.11') Palabra2: Synset('be.v.01') 0.5
# lch: Palabra1:  Synset('play.v.11') Palabra2: Synset('be.v.01') 2.159484249353372
#
# ('playing{play,VERB}',) a ('doing{do,VERB}',)
# playing{play,VERB}
# ['playing{play', 'VERB']
# VERB
# doing{do,VERB}
# VERB
# wup_sim: Palabra1:  Synset('play.v.11') Palabra2: Synset('make.v.01') 0.5
# lch: Palabra1:  Synset('play.v.11') Palabra2: Synset('make.v.01') 2.159484249353372
#
# ('playing{play,VERB}',) a ('chores{chore,NOUN}',)
# playing{play,VERB}
# ['playing{play', 'VERB']
# VERB
# chores{chore,NOUN}
# NOUN
# ('water{water,NOUN}',) a ('doing{do,VERB}',)
# water{water,NOUN}
# ['water{water', 'NOUN']
# NOUN
# doing{do,VERB}
# VERB
# ('water{water,NOUN}',) a ('chores{chore,NOUN}',)
# water{water,NOUN}
# ['water{water', 'NOUN']
# NOUN
# chores{chore,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('water.n.03') Palabra2: Synset('job.n.02') 0.25
# path_sim: Palabra1:  Synset('water.n.03') Palabra2: Synset('job.n.02') 0.07692307692307693
# spath: Palabra1:  Synset('water.n.03') Palabra2: Synset('job.n.02') 12
# lch: Palabra1:  Synset('water.n.03') Palabra2: Synset('job.n.02') 1.072636802264849
# minimos hyper Synset('abstraction.n.06')
# a->H 5
# b->H 7
#
# sinonimos 2 [('children', 'children'), ('children', 'children'), ('are', 'are')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 0 []
# relaciones fuertes: []
# verbos:  [('are', 'are', 1.0), ('playing', 'are', 0.5), ('playing', 'doing', 0.5)]
# ('are', 'are', 1.0)
# ('playing', 'are', 0.5)
# ('playing', 'doing', 0.5)
# semanticas [2, 0, 0, 0, 0, 1.0]
# verbos a comparar playing doing
# 99
# Texto:  Three men dressed in suits and ties clasps their raised hands while standing in front of corporate logos.
# Hipótesis:  One of the men is actually sasquatch.
# 20 9
# [(('men{man,NOUN}',), ('men{man,NOUN}',), 4.792034), (('men{man,NOUN}',), ('is{be,VERB}',), 0.054809146), (('men{man,NOUN}',), ('actually{actually,ADV}',), 0.8370316), (('men{man,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.1136138), (('dressed{dress,VERB}',), ('men{man,NOUN}',), 0.86627203), (('dressed{dress,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.1477855), (('suits{suit,NOUN}',), ('men{man,NOUN}',), 1.7238415), (('suits{suit,NOUN}',), ('actually{actually,ADV}',), 0.50645465), (('suits{suit,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.5653723), (('ties{tie,NOUN}',), ('men{man,NOUN}',), 0.86022174), (('ties{tie,NOUN}',), ('actually{actually,ADV}',), 0.61327165), (('ties{tie,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.4185706), (('clasps{clasp,VERB}',), ('men{man,NOUN}',), 0.7075903), (('clasps{clasp,VERB}',), ('is{be,VERB}',), 0.060348812), (('clasps{clasp,VERB}',), ('actually{actually,ADV}',), 1.0283796), (('clasps{clasp,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.2757554), (('raised{raise,VERB}',), ('sasquatch{sasquatch,NOUN}',), 1.3028688), (('hands{hand,NOUN}',), ('is{be,VERB}',), 0.07423799), (('hands{hand,NOUN}',), ('actually{actually,ADV}',), 0.72941285), (('standing{stand,VERB}',), ('is{be,VERB}',), 0.16424847), (('standing{stand,VERB}',), ('actually{actually,ADV}',), 0.89404845), (('corporate{corporate,ADJ}',), ('men{man,NOUN}',), 1.121951), (('corporate{corporate,ADJ}',), ('is{be,VERB}',), 0.06381738), (('corporate{corporate,ADJ}',), ('actually{actually,ADV}',), 1.1807395), (('corporate{corporate,ADJ}',), ('sasquatch{sasquatch,NOUN}',), 1.4763253), (('logos{logo,NOUN}',), ('is{be,VERB}',), 0.063146405), (('logos{logo,NOUN}',), ('actually{actually,ADV}',), 1.1391402), (('logos{logo,NOUN}',), ('sasquatch{sasquatch,NOUN}',), 1.8453801)]
# {'NOUN_NOUN': 13.319034337997437, 'NOUN_ADJ': 0, 'NOUN_VERB': 0.19219353795051575, 'NOUN_ADV': 3.825311005115509, 'ADJ_NOUN': 2.5982762575149536, 'ADJ_ADJ': 0, 'ADJ_VERB': 0.06381738185882568, 'ADJ_ADV': 1.1807395219802856, 'VERB_NOUN': 5.300272107124329, 'VERB_ADJ': 0, 'VERB_VERB': 0.2245972789824009, 'VERB_ADV': 1.922428011894226, 'ADV_NOUN': 0, 'ADV_ADJ': 0, 'ADV_VERB': 0, 'ADV_ADV': 0}
# Relaciones 28 33
# ('men{man,NOUN}',) a ('men{man,NOUN}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 1.0
# path_sim: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 1.0
# spath: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 0
# lch: Palabra1:  Synset('work_force.n.01') Palabra2: Synset('work_force.n.01') 3.6375861597263857
# Sinonimo:  men men
# hiperonimo: Synset('work_force.n.01') Synset('work_force.n.01') 0
# Hiponimo: Synset('work_force.n.01') Synset('work_force.n.01') 0
# minimos hyper Synset('work_force.n.01')
# a->H 0
# b->H 0
#
# ('men{man,NOUN}',) a ('is{be,VERB}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# is{be,VERB}
# VERB
# ('men{man,NOUN}',) a ('actually{actually,ADV}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('men{man,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# men{man,NOUN}
# ['men{man', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 0.25
# path_sim: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 0.07692307692307693
# spath: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 12
# lch: Palabra1:  Synset('world.n.08') Palabra2: Synset('bigfoot.n.01') 1.072636802264849
# minimos hyper Synset('abstraction.n.06')
# a->H 2
# b->H 10
#
# ('dressed{dress,VERB}',) a ('men{man,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# men{man,NOUN}
# NOUN
# ('dressed{dress,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# dressed{dress,VERB}
# ['dressed{dress', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('suits{suit,NOUN}',) a ('men{man,NOUN}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 0.631578947368421
# path_sim: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 0.16666666666666666
# spath: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 5
# lch: Palabra1:  Synset('suit.n.03') Palabra2: Synset('man.n.03') 1.845826690498331
# minimos hyper Synset('person.n.01')
# a->H 4
# b->H 1
#
# ('suits{suit,NOUN}',) a ('actually{actually,ADV}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('suits{suit,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# suits{suit,NOUN}
# ['suits{suit', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.3
# path_sim: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.06666666666666667
# spath: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 14
# lch: Palabra1:  Synset('lawsuit.n.01') Palabra2: Synset('bigfoot.n.01') 0.9295359586241757
# minimos hyper Synset('psychological_feature.n.01')
# a->H 5
# b->H 9
#
# ('ties{tie,NOUN}',) a ('men{man,NOUN}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# men{man,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 0.631578947368421
# path_sim: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 0.125
# spath: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 7
# lch: Palabra1:  Synset('link.n.02') Palabra2: Synset('man.n.10') 1.55814461804655
# minimos hyper Synset('instrumentality.n.03')
# a->H 4
# b->H 3
#
# ('ties{tie,NOUN}',) a ('actually{actually,ADV}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('ties{tie,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# ties{tie,NOUN}
# ['ties{tie', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.3157894736842105
# path_sim: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.07142857142857142
# spath: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 13
# lch: Palabra1:  Synset('draw.n.03') Palabra2: Synset('bigfoot.n.01') 0.9985288301111273
# minimos hyper Synset('psychological_feature.n.01')
# a->H 4
# b->H 9
#
# ('clasps{clasp,VERB}',) a ('men{man,NOUN}',)
# clasps{clasp,VERB}
# ['clasps{clasp', 'VERB']
# VERB
# men{man,NOUN}
# NOUN
# ('clasps{clasp,VERB}',) a ('is{be,VERB}',)
# clasps{clasp,VERB}
# ['clasps{clasp', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('clasp.v.01') Palabra2: Synset('be.v.01') 0.3333333333333333
# lch: Palabra1:  Synset('clasp.v.01') Palabra2: Synset('be.v.01') 1.6486586255873816
#
# ('clasps{clasp,VERB}',) a ('actually{actually,ADV}',)
# clasps{clasp,VERB}
# ['clasps{clasp', 'VERB']
# VERB
# actually{actually,ADV}
# ADV
# ('clasps{clasp,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# clasps{clasp,VERB}
# ['clasps{clasp', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('raised{raise,VERB}',) a ('sasquatch{sasquatch,NOUN}',)
# raised{raise,VERB}
# ['raised{raise', 'VERB']
# VERB
# sasquatch{sasquatch,NOUN}
# NOUN
# ('hands{hand,NOUN}',) a ('is{be,VERB}',)
# hands{hand,NOUN}
# ['hands{hand', 'NOUN']
# NOUN
# is{be,VERB}
# VERB
# ('hands{hand,NOUN}',) a ('actually{actually,ADV}',)
# hands{hand,NOUN}
# ['hands{hand', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('standing{stand,VERB}',) a ('is{be,VERB}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# is{be,VERB}
# VERB
# wup_sim: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 0.6666666666666666
# path_sim: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 0.3333333333333333
# spath: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 2
# lch: Palabra1:  Synset('stand.v.07') Palabra2: Synset('be.v.12') 2.159484249353372
# minimos hyper Synset('stay.v.01')
# a->H 1
# b->H 1
#
# ('standing{stand,VERB}',) a ('actually{actually,ADV}',)
# standing{stand,VERB}
# ['standing{stand', 'VERB']
# VERB
# actually{actually,ADV}
# ADV
# ('corporate{corporate,ADJ}',) a ('men{man,NOUN}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# men{man,NOUN}
# NOUN
# ('corporate{corporate,ADJ}',) a ('is{be,VERB}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# is{be,VERB}
# VERB
# ('corporate{corporate,ADJ}',) a ('actually{actually,ADV}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# actually{actually,ADV}
# ADV
# ('corporate{corporate,ADJ}',) a ('sasquatch{sasquatch,NOUN}',)
# corporate{corporate,ADJ}
# ['corporate{corporate', 'ADJ']
# ADJ
# sasquatch{sasquatch,NOUN}
# NOUN
# ('logos{logo,NOUN}',) a ('is{be,VERB}',)
# logos{logo,NOUN}
# ['logos{logo', 'NOUN']
# NOUN
# is{be,VERB}
# VERB
# ('logos{logo,NOUN}',) a ('actually{actually,ADV}',)
# logos{logo,NOUN}
# ['logos{logo', 'NOUN']
# NOUN
# actually{actually,ADV}
# ADV
# ('logos{logo,NOUN}',) a ('sasquatch{sasquatch,NOUN}',)
# logos{logo,NOUN}
# ['logos{logo', 'NOUN']
# NOUN
# sasquatch{sasquatch,NOUN}
# NOUN
# wup_sim: Palabra1:  Synset('son.n.02') Palabra2: Synset('bigfoot.n.01') 0.34782608695652173
# path_sim: Palabra1:  Synset('son.n.02') Palabra2: Synset('bigfoot.n.01') 0.0625
# spath: Palabra1:  Synset('son.n.02') Palabra2: Synset('bigfoot.n.01') 15
# lch: Palabra1:  Synset('son.n.02') Palabra2: Synset('bigfoot.n.01') 0.8649974374866046
# minimos hyper Synset('cognition.n.01')
# a->H 7
# b->H 8
#
# sinonimos 1 [('men', 'men'), ('men', 'men')]
# antonimos 0 []
# hyperonyms 0 []
# hyponyms 0 []
# relaciones fuertes: [(Synset('suit.n.03'), Synset('man.n.03')), (Synset('link.n.02'), Synset('man.n.10'))]
# verbos:  [('clasps', 'is', 0.3333333333333333), ('standing', 'is', 0.6666666666666666)]
# ('clasps', 'is', 0.3333333333333333)
# ('standing', 'is', 0.6666666666666666)
# semanticas [1, 0, 0, 0, 2, 0.6666666666666666]
# verbos a comparar standing is

# %%
df1 = pd.DataFrame(features, columns=list(todas_relaciones)+list(todos_conteos)+list(relatip_num)+["sinonimos","antonimos","hiperonimos","hiponimos","relacionesf","dif","action_wn","accion"])#,"similaridad_1_2","dif"])
df1
# Out:
#     NOUN_NOUN  NOUN_ADJ  NOUN_VERB  NOUN_ADV  ADJ_NOUN   ADJ_ADJ  ADJ_VERB  \
# 0   28.645093  1.631951   9.032564  0.000000  6.144412  0.127508  0.000000
# 1   26.671300  3.984223   4.437697  0.000000  2.492923  8.615627  0.000000
# 2   14.880619  1.824592   3.687874  0.000000  5.383794  1.300978  3.665578
# 3    7.112267  0.000000   4.998954  0.000000  3.913144  0.000000  0.000000
# 4   14.623623  0.000000   1.083491  0.000000  1.657801  0.000000  0.000000
# ..        ...       ...        ...       ...       ...       ...       ...
# 95  22.531673  4.194771   1.396518  1.896350  0.000000  5.424360  1.283683
# 96  11.299096  0.000000   0.397504  0.000000  5.716955  0.000000  0.512868
# 97   6.672148  0.000000   5.138863  0.000000  0.000000  0.000000  0.000000
# 98   7.110450  0.000000   0.658881  0.000000  0.000000  0.000000  0.000000
# 99  13.319034  0.000000   0.192194  3.825311  2.598276  0.000000  0.063817
#
#     ADJ_ADV  VERB_NOUN  VERB_ADJ  ...  ADV_VERB_r  ADV_ADV_r  sinonimos  \
# 0   0.00000   4.677207  0.303176  ...    0.000000        0.0          0
# 1   0.00000   9.887845  0.000000  ...    0.000000        0.0          4
# 2   0.00000   1.199861  0.347017  ...    0.000000        0.0          1
# 3   0.00000   4.153236  0.000000  ...    0.000000        0.0          2
# 4   0.00000   3.077783  0.000000  ...    0.411897        0.0          2
# ..      ...        ...       ...  ...         ...        ...        ...
# 95  0.00000   3.104924  1.004280  ...    0.000000        0.0          1
# 96  0.00000   0.000000  0.000000  ...    0.000000        0.0          3
# 97  0.00000   3.334945  0.000000  ...    0.000000        0.0          0
# 98  0.00000   2.450452  0.000000  ...    0.000000        0.0          2
# 99  1.18074   5.300272  0.000000  ...    0.000000        0.0          1
#
#     antonimos  hiperonimos  hiponimos  relacionesf       dif  action_wn  \
# 0           0            2          2            6  0.800000   0.900000
# 1           0            0          1            7  1.000000   1.045455
# 2           0            0          0            0  0.400000   1.000000
# 3           0            0          0            2  1.000000   0.920000
# 4           0            0          0            1  0.500000   0.809524
# ..        ...          ...        ...          ...       ...        ...
# 95          0            0          2            2  1.000000   0.650000
# 96          0            0          1            0  1.000000   0.444444
# 97          0            0          0            2  0.400000   0.923077
# 98          0            0          0            0  1.000000   1.222222
# 99          0            0          0            2  0.666667   1.178571
#
#       accion
# 0   0.235279
# 1   0.182328
# 2   0.360803
# 3   1.000000
# 4   0.459732
# ..       ...
# 95  1.000000
# 96  0.895790
# 97  0.265505
# 98  0.577761
# 99  0.252164
#
# [100 rows x 56 columns]

# %%
gold_label=prueba.gold_label.values
gold_label
# Out:
# array(['entailment', 'entailment', 'contradiction', 'contradiction',
#        'neutral', 'neutral', 'neutral', 'entailment', 'neutral',
#        'entailment', 'neutral', 'contradiction', 'entailment',
#        'contradiction', 'neutral', 'neutral', 'entailment',
#        'contradiction', 'contradiction', 'entailment', 'entailment',
#        'entailment', 'neutral', 'contradiction', 'entailment', 'neutral',
#        'entailment', 'entailment', 'entailment', 'neutral', 'neutral',
#        'contradiction', 'contradiction', 'entailment', 'contradiction',
#        'neutral', 'entailment', 'neutral', 'neutral', 'entailment',
#        'neutral', 'neutral', 'contradiction', 'neutral', 'entailment',
#        'neutral', 'neutral', 'entailment', 'contradiction', 'neutral',
#        'entailment', 'entailment', 'neutral', 'entailment',
#        'contradiction', 'entailment', 'entailment', 'neutral', 'neutral',
#        'neutral', 'neutral', 'neutral', 'neutral', 'entailment',
#        'entailment', 'contradiction', 'entailment', 'entailment',
#        'neutral', 'contradiction', 'entailment', 'contradiction',
#        'contradiction', 'contradiction', 'neutral', 'entailment',
#        'entailment', 'entailment', 'entailment', 'contradiction',
#        'neutral', 'entailment', 'entailment', 'entailment',
#        'contradiction', 'entailment', 'entailment', 'entailment',
#        'contradiction', 'contradiction', 'contradiction', 'neutral',
#        'entailment', 'entailment', 'contradiction', 'entailment',
#        'entailment', 'contradiction', 'contradiction', 'contradiction'],
#       dtype=object)

# %%
df1["CLASS"]=gold_label

# %%
df1
# Out:
#     NOUN_NOUN  NOUN_ADJ  NOUN_VERB  NOUN_ADV  ADJ_NOUN   ADJ_ADJ  ADJ_VERB  \
# 0   28.645093  1.631951   9.032564  0.000000  6.144412  0.127508  0.000000
# 1   26.671300  3.984223   4.437697  0.000000  2.492923  8.615627  0.000000
# 2   14.880619  1.824592   3.687874  0.000000  5.383794  1.300978  3.665578
# 3    7.112267  0.000000   4.998954  0.000000  3.913144  0.000000  0.000000
# 4   14.623623  0.000000   1.083491  0.000000  1.657801  0.000000  0.000000
# ..        ...       ...        ...       ...       ...       ...       ...
# 95  22.531673  4.194771   1.396518  1.896350  0.000000  5.424360  1.283683
# 96  11.299096  0.000000   0.397504  0.000000  5.716955  0.000000  0.512868
# 97   6.672148  0.000000   5.138863  0.000000  0.000000  0.000000  0.000000
# 98   7.110450  0.000000   0.658881  0.000000  0.000000  0.000000  0.000000
# 99  13.319034  0.000000   0.192194  3.825311  2.598276  0.000000  0.063817
#
#     ADJ_ADV  VERB_NOUN  VERB_ADJ  ...  ADV_ADV_r  sinonimos  antonimos  \
# 0   0.00000   4.677207  0.303176  ...        0.0          0          0
# 1   0.00000   9.887845  0.000000  ...        0.0          4          0
# 2   0.00000   1.199861  0.347017  ...        0.0          1          0
# 3   0.00000   4.153236  0.000000  ...        0.0          2          0
# 4   0.00000   3.077783  0.000000  ...        0.0          2          0
# ..      ...        ...       ...  ...        ...        ...        ...
# 95  0.00000   3.104924  1.004280  ...        0.0          1          0
# 96  0.00000   0.000000  0.000000  ...        0.0          3          0
# 97  0.00000   3.334945  0.000000  ...        0.0          0          0
# 98  0.00000   2.450452  0.000000  ...        0.0          2          0
# 99  1.18074   5.300272  0.000000  ...        0.0          1          0
#
#     hiperonimos  hiponimos  relacionesf       dif  action_wn    accion  \
# 0             2          2            6  0.800000   0.900000  0.235279
# 1             0          1            7  1.000000   1.045455  0.182328
# 2             0          0            0  0.400000   1.000000  0.360803
# 3             0          0            2  1.000000   0.920000  1.000000
# 4             0          0            1  0.500000   0.809524  0.459732
# ..          ...        ...          ...       ...        ...       ...
# 95            0          2            2  1.000000   0.650000  1.000000
# 96            0          1            0  1.000000   0.444444  0.895790
# 97            0          0            2  0.400000   0.923077  0.265505
# 98            0          0            0  1.000000   1.222222  0.577761
# 99            0          0            2  0.666667   1.178571  0.252164
#
#             CLASS
# 0      entailment
# 1      entailment
# 2   contradiction
# 3   contradiction
# 4         neutral
# ..            ...
# 95     entailment
# 96     entailment
# 97  contradiction
# 98  contradiction
# 99  contradiction
#
# [100 rows x 57 columns]

# %%
#df1.to_csv("TipoPalabra_conteos_umbral_mean.csv")
#df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_root_difTH_porcentajeR_2.csv")
df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_root_difTH_porcentajeR_3.csv",index=False)
#df1.to_csv("TipoPalabra_conteos_umbral_mean_relsemanf_sim0.8.csv")

# %%
a=list(todas_relaciones)
a
# Out:
# ['NOUN_NOUN',
#  'NOUN_ADJ',
#  'NOUN_VERB',
#  'NOUN_ADV',
#  'ADJ_NOUN',
#  'ADJ_ADJ',
#  'ADJ_VERB',
#  'ADJ_ADV',
#  'VERB_NOUN',
#  'VERB_ADJ',
#  'VERB_VERB',
#  'VERB_ADV',
#  'ADV_NOUN',
#  'ADV_ADJ',
#  'ADV_VERB',
#  'ADV_ADV']
