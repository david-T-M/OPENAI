# %% [markdown]
# # Librerías necesarias para usar la API de GPT

# %%
import os
import json
import openai
openai.organization = "org-6Oyy5fn0u4jtC45zlAKl6e6y"
openai.api_key = "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"
#openai.Model.list()

# %% [markdown]
# ## Lista de los modelos disponibles para usar

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7f9b6635e860> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "davinci",
#       "object": "model",
#       "created": 1649359874,
#       "owned_by": "openai",
#       "permission": [
#         {
#           "id": "modelperm-uJaD4C9nXA6tPNoBII9hcYF4",
#           "object": "model_permission",
#           "created": 1692634268,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "davinci",
#       "parent": null
#     },
#     {
#       "id": "gpt-3.5-turbo-16k-0613",
#       "object": "model",
#       "created": 1685474247,
#       "owned_by": "openai",
#       "permission": [
#         {
# ...

# %% [markdown]
# ## Elección de modelo y envío de solicitud
# - GPT 3.5 Turbo y utilizando la función de complementar
#
# Para poder aprovechar la respuesta, podemos solicitar una estructura definida (json) a partir de los conceptos relevantes

# %%
response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo", messages=[{"role": "user", "content": "Give me, the referent, the meaning and verb of the sentence: The man is walking on the grass. in format json"}])
            #model="gpt-4", messages=[{"role": "user", "content": "¿Cúal es tu misión?"}])

print(response.choices[0].message.content)
# Out:
# {
#   "referent": "The man",
#   "meaning": "is engaged in the act of walking",
#   "verb": "is walking"
# }

# %% [markdown]
# ## Podemos obtener todo el contenido que devolvió la solicitud
# - Ahí viene el número de tokens enviados y recibidos

# %%
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7wFnALHa9f8PmE8LAmENh0WNCDaG7 at 0x7f9b662ae900> JSON: {
#   "id": "chatcmpl-7wFnALHa9f8PmE8LAmENh0WNCDaG7",
#   "object": "chat.completion",
#   "created": 1694118084,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"referent\": \"The man\",\n  \"meaning\": \"is engaged in the act of walking\",\n  \"verb\": \"is walking\"\n}"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 33,
#     "completion_tokens": 32,
#     "total_tokens": 65
#   }
# }

# %% [markdown]
# ## Con la función load podemos pasarle la respuesta para cargar la información en un diccionario para un facil acceso

# %%
datos_diccionario = json.loads(response.choices[0].message.content)
datos_diccionario
# Out:
# {'sentence': 'The man is walking on the grass.',
#  'referent': 'The man',
#  'meaning': 'The man is engaged in the action of walking and is doing so on the surface of the grass.'}

# %%
datos_diccionario["meaning"]
# Out:
# 'The man is engaged in the action of walking and is doing so on the surface of the grass.'

# %% [markdown]
# # Podemos usar GPT 4

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "Give me, the referent, the meaning and verb of the sentence: The man is walking on the grass. in format json"}])

print(response.choices[0].message.content)
# Out:
# {
#   "Referent": "The man",
#   "Meaning": "A person identified as a man is moving across a patch of grass, likely in a leisurely way, or possibly in a hurried way depending on context not provided.",
#   "Verb": "is walking"
# }

# %%
datos_diccionario1 = json.loads(response.choices[0].message.content)
datos_diccionario1
# Out:
# {'Referent': 'The man',
#  'Meaning': 'A person identified as a man is moving across a patch of grass, likely in a leisurely way, or possibly in a hurried way depending on context not provided.',
#  'Verb': 'is walking'}

# %%
response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7wFfXhciVdwOpAsrwZNXDz1BNAqm1 at 0x7f9b661faf40> JSON: {
#   "id": "chatcmpl-7wFfXhciVdwOpAsrwZNXDz1BNAqm1",
#   "object": "chat.completion",
#   "created": 1694117611,
#   "model": "gpt-4-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"Referent\": \"The man\",\n  \"Meaning\": \"A person identified as a man is moving across a patch of grass, likely in a leisurely way, or possibly in a hurried way depending on context not provided.\",\n  \"Verb\": \"is walking\"\n}"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 33,
#     "completion_tokens": 58,
#     "total_tokens": 91
#   }
# }

# %%
datos_diccionario1["Meaning"]
# Out:
# 'A person identified as a man is moving across a patch of grass, likely in a leisurely way, or possibly in a hurried way depending on context not provided.'

# %% [markdown]
# # Probar con la implicatura T->H para obtener las relaciones posibles identificadas en el T y H

# %% [markdown]
# ## Neutral

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "Give me, all realtions of words beetwen sentence 1 'A person on a horse jumps over a broken down airplane.' and sentence 2: 'A person is training his horse for a competition.' in format json"}])

print(response.choices[0].message.content)
# Out:
# [
#   {
#     "source_sentence": "A person on a horse jumps over a broken down airplane.",
#     "target_sentence": "A person is training his horse for a competition.",
#     "relations": [
#       {
#         "word_1": "person",
#         "relation": "same",
#         "word_2": "person"
#       },
#       {
#         "word_1": "horse",
#         "relation": "same",
#         "word_2": "horse"
#       },
#       {
#         "word_1": "jumps",
#         "relation": "different",
#         "word_2": "training"
#       },
#       {
#         "word_1": "broken down airplane",
#         "relation": "different",
#         "word_2": "competition"
#       }
#     ]
#   }
# ]

# %%
datos_TH = json.loads(response.choices[0].message.content)
datos_TH
# Out:
# [{'source_sentence': 'A person on a horse jumps over a broken down airplane.',
#   'target_sentence': 'A person is training his horse for a competition.',
#   'relations': [{'word_1': 'person', 'relation': 'same', 'word_2': 'person'},
#    {'word_1': 'horse', 'relation': 'same', 'word_2': 'horse'},
#    {'word_1': 'jumps', 'relation': 'different', 'word_2': 'training'},
#    {'word_1': 'broken down airplane',
#     'relation': 'different',
#     'word_2': 'competition'}]}]

# %% [markdown]
# ## Entailment

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "Give me, all realtions of words beetwen sentence 1 'A man in a lavender shirt holds a young child in his lap while holding a Dog book in his hands.' and sentence 2: 'A man is holding a book.' in format json"}])

print(response.choices[0].message.content)
# Out:
# {
#   "Entities": [
#     {
#       "Sentence 1": "A man in a lavender shirt holds a young child in his lap while holding a Dog book in his hands.",
#       "Sentence 2": "A man is holding a book.",
#       "Common": "Man, Holding, Book"
#     }
#   ],
#   "Actions": [
#     {
#       "Sentence 1": "holds",
#       "Sentence 2": "is holding",
#       "Relation": "Same action, different tenses"
#     },
#     {
#       "Sentence 1": "Holds a young child in his lap",
#       "Sentence 2": "",
#       "Relation": "Unique to Sentence 1"
#     },
#     {
#       "Sentence 1": "holds a Dog book in his hands",
#       "Sentence 2": "is holding a book",
#       "Relation": "Similar action, specific object in Sentence 1"
#     }
#   ],
#   "Objects": [
#     {
#       "Sentence 1": "A young child, a Dog book",
#       "Sentence 2": "A book",
#       "Common": "Book"
#     },
#     {
#       "Sentence 1": "A young child",
#       "Sentence 2": "",
#       "Relation": "Unique to Sentence 1"
# ...

# %%
datos_TH_E = json.loads(response.choices[0].message.content)
datos_TH_E
# Out:
# {'Entities': [{'Sentence 1': 'A man in a lavender shirt holds a young child in his lap while holding a Dog book in his hands.',
#    'Sentence 2': 'A man is holding a book.',
#    'Common': 'Man, Holding, Book'}],
#  'Actions': [{'Sentence 1': 'holds',
#    'Sentence 2': 'is holding',
#    'Relation': 'Same action, different tenses'},
#   {'Sentence 1': 'Holds a young child in his lap',
#    'Sentence 2': '',
#    'Relation': 'Unique to Sentence 1'},
#   {'Sentence 1': 'holds a Dog book in his hands',
#    'Sentence 2': 'is holding a book',
#    'Relation': 'Similar action, specific object in Sentence 1'}],
#  'Objects': [{'Sentence 1': 'A young child, a Dog book',
#    'Sentence 2': 'A book',
#    'Common': 'Book'},
#   {'Sentence 1': 'A young child',
#    'Sentence 2': '',
#    'Relation': 'Unique to Sentence 1'},
#   {'Sentence 1': 'A Dog book',
#    'Sentence 2': 'A book',
#    'Relation': 'Specific object in Sentence 1, general object in Sentence 2'}]}

# %% [markdown]
# ## Contradiction

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "Give me, all realtions of words beetwen sentence 1 'A man in an orange ski suit top with black bottoms has finished performing a trick and is in midair.' and sentence 2: 'A man in an orange ski suit top is standing with his hands behind his back.' in format json"}])

print(response.choices[0].message.content)
# Out:
# {
# "Sentence1": {
# "Subject": ["A man"],
# "Description of Subject": ["in an orange ski suit top with black bottoms"],
# "Action": ["has finished performing a trick", "is in midair"]
# },
# "Sentence2": {
# "Subject": ["A man"],
# "Description of Subject": ["in an orange ski suit top"],
# "Action": ["is standing with his hands behind his back"]
# },
# "Commonality": {
# "Subject": ["A man"],
# "Description of Subject": ["in an orange ski suit top"]
# },
# "Differences": {
# "Sentence1": {
# "Description of Subject": ["with black bottoms"],
# "Action": ["has finished performing a trick", "is in midair"]
# },
# "Sentence2": {
# "Action": ["is standing with his hands behind his back"]
# }
# }
# }

# %%
datos_TH_C = json.loads(response.choices[0].message.content)
datos_TH_C
# Out:
# {'Sentence1': {'Subject': ['A man'],
#   'Description of Subject': ['in an orange ski suit top with black bottoms'],
#   'Action': ['has finished performing a trick', 'is in midair']},
#  'Sentence2': {'Subject': ['A man'],
#   'Description of Subject': ['in an orange ski suit top'],
#   'Action': ['is standing with his hands behind his back']},
#  'Commonality': {'Subject': ['A man'],
#   'Description of Subject': ['in an orange ski suit top']},
#  'Differences': {'Sentence1': {'Description of Subject': ['with black bottoms'],
#    'Action': ['has finished performing a trick', 'is in midair']},
#   'Sentence2': {'Action': ['is standing with his hands behind his back']}}}

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "sentence 1 'A man in an orange ski suit top with black bottoms has finished performing a trick and is in midair.' and sentence 2: 'A man in an orange ski suit top is standing with his hands behind his back.' sentence 1 entail sentence 2?"}])

print(response.choices[0].message.content)
# Out:
# No, sentence 1 does not entail sentence 2.

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "What is the Referent and the Meaning in the next sentences: sentence 1 'A man in an orange ski suit top with black bottoms has finished performing a trick and is in midair.' and sentence 2: 'A man in an orange ski suit top is standing with his hands behind his back.'"}])

print(response.choices[0].message.content)
# Out:
# Sentence 1:
# Referent - The referent in this sentence is "A man in an orange ski suit top with black bottoms." The referent points to a specific entity in the real or imagined world.
# Meaning - The sentence describes an action performed by the referent. It states the man, who is wearing an orange ski suit top and black bottoms, has just completed a trick and is currently off the ground (in midair).
#
# Sentence 2:
# Referent - The referent in this sentence is "A man in an orange ski suit top." Again, this refers to a specific entity.
# Meaning - The sentence describes the pose or stance of the referent. The man wearing the orange ski suit top is standing with his hands positioned behind his back.

# %%
response = openai.ChatCompletion.create(
            model="gpt-4", messages=[{"role": "user", "content": "Tokenize the next sentences and give me what token from sentence 1 is hyperonym or hyponym which token from sentence 2. sentence 1 'A man in an orange ski suit top with black bottoms has finished performing a trick and is in midair.' and sentence 2: 'A man in an orange ski suit top is standing with his hands behind his back.'"}])

print(response.choices[0].message.content)
# Out:
# Sentence 1 Tokens: A, man, in, an, orange, ski, suit, top, with, black, bottoms, has, finished, performing, a, trick, and, is, in, midair.
#
# Sentence 2 Tokens: A, man, in, an, orange, ski, suit, top, is, standing, with, his, hands, behind, his, back.
#
# "Man" in sentence 1 is a hyperonym to "Man" in sentence 2.
# On the other hand, "performing a trick and is in midair" in Sentence 1 act as a hyponym to "is standing with his hands behind his back" in Sentence 2 as they both reflect actions done by the man but the first one is more specific.
