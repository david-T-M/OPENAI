# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import preprocessing

# %% [markdown]
# # TRAIN

# %%
for i in range(45):
    if i==0:
        train = pd.read_csv('salida/resultados/SICK/TRAIN_'+str(i+1)+'.csv.csv')
    else:
        temp = pd.read_csv('salida/resultados/SICK/TRAIN_'+str(i+1)+'.csv.csv')
        train=pd.concat([train,temp])

# %%
#train["suma"]=train["suma"]+train["antonimos"]

# %%
train.boxplot(by="CLASS",column=["suma"])
# Out:
# <Axes: title={'center': 'suma'}, xlabel='CLASS'>

# %%
train.boxplot(by="CLASS",column=["suma"])
# Out:
# <Axes: title={'center': 'suma'}, xlabel='CLASS'>

# %%
train=train.drop(["entropias","antonimos"],axis=1)
train
# Out:
#         suma  distancias  mutual_info   m_earth  max_info_p  relaciones  \
# 0   0.000000     0.00000     0.000000  0.000000    0.000000           1
# 1   0.114918   100.71223     1.711384  0.369471    0.114918           1
# 2   0.000000     0.00000     0.000000  0.000000    0.000000           1
# 3   1.064229   380.85742    18.322292  4.431219    0.195273           0
# 4   2.867368   241.05775    20.902023  4.989589    0.332594           2
# ..       ...         ...          ...       ...         ...         ...
# 34  0.924950   391.77950    18.350202  4.146894    0.135612           0
# 35  2.549616   343.11250    29.332251  5.025132    0.363223           0
# 36  3.173033   369.60180    34.950960  6.838347    0.257784           1
# 37  1.804459   204.06305    14.874765  3.171687    0.401213           0
# 38  1.960967   208.00665    15.977217  2.398580    0.353400           1
#
#     sim_faltantes          CLASS
# 0        1.000000  CONTRADICTION
# 1        0.114918  CONTRADICTION
# 2        1.000000     ENTAILMENT
# 3        0.177042  CONTRADICTION
# 4        0.471261  CONTRADICTION
# ..            ...            ...
# 34       0.177094  CONTRADICTION
# 35       0.407879  CONTRADICTION
# 36       0.398060  CONTRADICTION
# 37       0.369778  CONTRADICTION
# 38       0.406888  CONTRADICTION
#
# [4439 rows x 8 columns]

# %%
X = np.array(train.drop(['CLASS'],axis=1))
y_ = np.array(train['CLASS'])

# %%
# SICK
y_train=[]
for i in y_:
    if i == "ENTAILMENT":
        y_train.append(1)
    else:
        y_train.append(0)

# %%
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)
X = X_scaled
X_train=X

# %%
train.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # DEV

# %%
for i in range(5):
    if i==0:
        dev = pd.read_csv('salida/resultados/SICK/DEV_'+str(i+1)+'.csv.csv')
    else:
        temp = pd.read_csv('salida/resultados/SICK/DEV_'+str(i+1)+'.csv.csv')
        dev=pd.concat([dev,temp])

# %%
#dev["suma"]=dev["suma"]+dev["antonimos"]

# %%
dev=dev.drop(["entropias","antonimos"],axis=1)
dev
# Out:
#         suma  distancias  mutual_info   m_earth  max_info_p  relaciones  \
# 0   1.074424  127.826540     6.906301  1.720222    0.278522           0
# 1   2.011933  193.265750    15.422091  2.632271    0.296344           2
# 2   0.378545   60.185406     1.897469  0.247676    0.378545           1
# 3   1.660813  270.395660     7.607406  1.297392    0.415203           2
# 4   0.000000    0.000000     0.000000  0.000000    0.000000           0
# ..       ...         ...          ...       ...         ...         ...
# 90  0.986909  156.993200    10.616691  2.130698    0.199834           1
# 91  0.302330   73.981760     3.260589  0.495572    0.404658           0
# 92  1.608502  277.959170    21.247575  3.813996    0.197763           0
# 93  0.595234  170.758440     6.351086  1.874976    0.205298           2
# 94  4.102182  214.049320    31.926925  7.137955    0.357369           1
#
#     sim_faltantes          CLASS
# 0        0.352328  CONTRADICTION
# 1        0.458316  CONTRADICTION
# 2        0.378546  CONTRADICTION
# 3        0.538831  CONTRADICTION
# 4        1.000000  CONTRADICTION
# ..            ...            ...
# 90       0.287339  CONTRADICTION
# 91       0.260126  CONTRADICTION
# 92       0.246701  CONTRADICTION
# 93       0.162272  CONTRADICTION
# 94       0.478485  CONTRADICTION
#
# [495 rows x 8 columns]

# %%
X_dev = np.array(dev.drop(['CLASS'],axis=1))
y_d = np.array(dev['CLASS'])

# %%
# SICK
y_dev=[]
for i in y_d:
    if i == "ENTAILMENT":
        y_dev.append(1)
    else:
        y_dev.append(0)

# %%
scaler = preprocessing.StandardScaler().fit(X_dev)
X_scaled = scaler.transform(X_dev)
X_dev = X_scaled

# %% [markdown]
# # TEST

# %%
for i in range(50):
    if i==0:
        test = pd.read_csv('salida/resultados/SICK/TEST_'+str(i+1)+'.csv.csv')
    else:
        temp = pd.read_csv('salida/resultados/SICK/TEST_'+str(i+1)+'.csv.csv')
        test=pd.concat([test,temp])

# %%
#test["suma"]=test["suma"]+test["antonimos"]

# %%
test=test.drop(["entropias","antonimos"],axis=1)
test
# Out:
#         suma  distancias  mutual_info    m_earth  max_info_p  relaciones  \
# 0   4.966659  348.627660    34.533986   7.224745    0.313013           1
# 1   3.762295  322.391720    28.020195   6.795347    0.368469           0
# 2   4.527484  188.073120    26.025844   5.007468    0.459162           1
# 3   0.000000    0.000000     0.000000   0.000000    0.000000           0
# 4   0.473630   45.112247     1.714587   0.262647    0.473630           0
# ..       ...         ...          ...        ...         ...         ...
# 1   2.238598  195.129700    22.072410   2.996832    0.368855           1
# 2   0.748086  172.961210    10.085201   3.234199    0.248313           1
# 3   0.536706  162.101380     5.211209   0.640615    0.178902           3
# 4   8.014608  545.806150    62.260364  12.531210    0.420467           2
# 5   6.846042  447.995730    62.611202  11.392518    0.349478           0
#
#     sim_faltantes          CLASS
# 0        0.428688  CONTRADICTION
# 1        0.487296  CONTRADICTION
# 2        0.580983  CONTRADICTION
# 3        1.000000     ENTAILMENT
# 4        0.473630  CONTRADICTION
# ..            ...            ...
# 1        0.342264  CONTRADICTION
# 2        0.210610  CONTRADICTION
# 3        0.212080  CONTRADICTION
# 4        0.568003  CONTRADICTION
# 5        0.583053  CONTRADICTION
#
# [4906 rows x 8 columns]

# %%
X_t = np.array(test.drop(['CLASS'],axis=1))
y_t = np.array(test['CLASS'])

# %%
# SICK
y_test=[]
for i in y_t:
    if i == "ENTAILMENT":
        y_test.append(1)
    else:
        y_test.append(0)

# %%
scaler = preprocessing.StandardScaler().fit(X_t)
X_scaled = scaler.transform(X_t)
X_test = X_scaled

# %% [markdown]
# # MODELO DE REGRESIÓN LÓGISTICA

# %%
model = linear_model.LogisticRegression(penalty="l2", C=1)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
model.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.decision_function(X)
# Out:
# array([-0.41292048, -1.98763958, -0.41292048, ..., -5.0982134 ,
#        -2.93630869, -3.41430518])

# %%
labels=train.columns[:-1]
labels
# Out:
# Index(['suma', 'distancias', 'mutual_info', 'm_earth', 'max_info_p',
#        'relaciones', 'sim_faltantes'],
#       dtype='object')

# %%
model.classes_
# Out:
# array([0, 1])

# %%
model.coef_[0]
# Out:
# array([ 0.4273449 , -1.55354221, -0.11684581,  0.03414511, -0.47301083,
#        -0.44601248,  0.00282554])

# %%
coeficientes=model.coef_[0]

# %%
print("Maximo,minimo ",np.argmax(coeficientes),labels[np.argmax(coeficientes)],np.argmin(coeficientes),labels[np.argmin(coeficientes)])
# Out:
# Maximo,minimo  0 suma 1 distancias

# %%
n_columns=train.shape[1]-1

# %%
n_columns
# Out:
# 7

# %%
import matplotlib.pyplot as plt
import numpy as np

x_v = np.arange(0,n_columns,1)
y_v = coeficientes

plt.bar(x_v,y_v)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Coeficientes')
plt.show()

# %%
predictions = model.predict(X_dev)

# %%
print(confusion_matrix(y_dev, predictions))
# Out:
# [[279  73]
#  [ 51  92]]

# %%
print(confusion_matrix(y_dev, predictions))
# Out:
# [[279  73]
#  [ 51  92]]

# %%
print("acccuracy: ",round(accuracy_score(y_dev,predictions),2))
print("precision: ",round(precision_score(y_dev,predictions),2))
print("recall",round(recall_score(y_dev,predictions),2))
print("f1_score: ",round(f1_score(y_dev,predictions),2))
# Out:
# acccuracy:  0.75
# precision:  0.56
# recall 0.64
# f1_score:  0.6

# %%
print("acccuracy: ",round(accuracy_score(y_dev,predictions),2))
print("precision: ",round(precision_score(y_dev,predictions),2))
print("recall",round(recall_score(y_dev,predictions),2))
print("f1_score: ",round(f1_score(y_dev,predictions),2))
# Out:
# acccuracy:  0.75
# precision:  0.56
# recall 0.64
# f1_score:  0.6

# %%
predictions = model.predict(X_test)

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[2750  752]
#  [ 479  925]]

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[2750  752]
#  [ 479  925]]

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions),2))
print("recall",round(recall_score(y_test,predictions),2))
print("f1_score: ",round(f1_score(y_test,predictions),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.75
# precision:  0.55
# recall 0.66
# f1_score:  0.6
# matthews_score:  0.42

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions),2))
print("recall",round(recall_score(y_test,predictions),2))
print("f1_score: ",round(f1_score(y_test,predictions),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.75
# precision:  0.55
# recall 0.66
# f1_score:  0.6
# matthews_score:  0.42

# %%
X_train.shape
# Out:
# (4439, 7)

# %%
X_cv=np.concatenate((X_train, X_test), axis=0)
Y_cv=np.concatenate((y_train, y_test), axis=0)

# %%
validation_size = 0.20
X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.550000 (0.048039)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.660000 (0.046336)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.600000 (0.040830)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='matthews_corrcoef')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.420000 (0.050980)
